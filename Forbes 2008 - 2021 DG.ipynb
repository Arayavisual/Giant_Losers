# %%
import pandas as pd
import numpy as np
import os
import warnings
warnings.filterwarnings('ignore')

# %%
data08 = pd.read_csv('aroissues-forbes-global-2000-2008-2019/Forbes Global 2000 - 2008.csv')
data09 = pd.read_csv('aroissues-forbes-global-2000-2008-2019/Forbes Global 2000 - 2009.csv')
data10 = pd.read_csv('aroissues-forbes-global-2000-2008-2019/Forbes Global 2000 - 2010.csv')
data11 = pd.read_csv('aroissues-forbes-global-2000-2008-2019/Forbes Global 2000 - 2011.csv')
data12 = pd.read_csv('aroissues-forbes-global-2000-2008-2019/Forbes Global 2000 - 2012.csv')
data13 = pd.read_csv('aroissues-forbes-global-2000-2008-2019/Forbes Global 2000 - 2013.csv')
data14 = pd.read_csv('aroissues-forbes-global-2000-2008-2019/Forbes Global 2000 - 2014.csv')
data15 = pd.read_csv('aroissues-forbes-global-2000-2008-2019/Forbes Global 2000 - 2015.csv')
data16 = pd.read_csv('aroissues-forbes-global-2000-2008-2019/Forbes Global 2000 - 2016.csv')
data17 = pd.read_csv('aroissues-forbes-global-2000-2008-2019/Forbes Global 2000 - 2017.csv')
data19 = pd.read_csv('aroissues-forbes-global-2000-2008-2019/Forbes Global 2000 - 2019.csv')
data20 = pd.read_csv('aroissues-forbes-global-2000-2008-2019/Forbes Global 2000  - 2020.csv')
data21 = pd.read_csv('aroissues-forbes-global-2000-2008-2019/Forbes Global 2000 - 2021.csv')

# %%
data18 = pd.read_csv('aroissues-forbes-global-2000-2008-2019/Forbes Global 2000 - 2018.csv', error_bad_lines=False)

# %%
# checking list of files to resolve the issue with reading 2020 csv
for f in os.listdir("aroissues-forbes-global-2000-2008-2019"):
    print(f)
#file had two spaces after 2000
# Out:
# combined.csv
# Forbes Global 2000  - 2020.csv
# Forbes Global 2000  - 2020.xlsx
# Forbes Global 2000 - 2008.csv
# Forbes Global 2000 - 2009.csv
# Forbes Global 2000 - 2010.csv
# Forbes Global 2000 - 2011.csv
# Forbes Global 2000 - 2012.csv
# Forbes Global 2000 - 2013.csv
# Forbes Global 2000 - 2014.csv
# Forbes Global 2000 - 2015.csv
# Forbes Global 2000 - 2016.csv
# Forbes Global 2000 - 2017.csv
# Forbes Global 2000 - 2018.csv
# Forbes Global 2000 - 2019.csv
# Forbes Global 2000 - 2021.csv
# Forbes Global 2000 - 2021.xlsx

# %%
# checking type of data (currency)
data20
# Out:
#       Rank                         Company Country/Territory     Sales  \
# 0        1                            ICBC             China  $177.2 B
# 1        2         China Construction Bank             China  $162.1 B
# 2        3                  JPMorgan Chase     United States  $142.9 B
# 3        4              Berkshire Hathaway     United States  $254.6 B
# 4        5      Agricultural Bank of China             China  $148.7 B
# ...    ...                             ...               ...       ...
# 1995  1995              Founder Securities             China    $1.4 B
# 1996  1995    Merlin Properties SOCIMI S.A             Spain    $594 M
# 1997  1998                           Heico     United States    $2.1 B
# 1998  1999                      W.P. Carey     United States    $1.2 B
# 1999  1999  Zhejiang Century Huatong Group             China    $2.2 B
#
#        Profits      Assets Market Value      Sector             Industry  Year
# 0      $45.3 B  $4,322.5 B     $242.3 B  Financials          Major Banks  2020
# 1      $38.9 B    $3,822 B     $203.8 B  Financials          Major Banks  2020
# 2        $30 B  $3,139.4 B     $291.7 B  Financials          Major Banks  2020
# 3      $81.4 B    $817.7 B     $455.4 B  Financials  Investment Services  2020
# 4      $30.9 B  $3,697.5 B     $147.2 B  Financials       Regional Banks  2020
# ...        ...         ...          ...         ...                  ...   ...
# 1995  $114.7 M     $18.6 B       $8.3 B  Financials  Investment Services  2020
# 1996  $630.9 M     $14.9 B       $4.3 B  Financials  Investment Services  2020
# 1997  $370.5 M      $3.1 B      $11.8 B         NaN                  NaN  2020
# 1998  $305.2 M     $14.1 B      $11.3 B         NaN                  NaN  2020
# 1999  $364.8 M      $4.7 B      $12.1 B         NaN                  NaN  2020
#
# [2000 rows x 10 columns]

# %%
data20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Rank               2000 non-null   int64
#  1   Company            2000 non-null   object
#  2   Country/Territory  2000 non-null   object
#  3   Sales              2000 non-null   object
#  4   Profits            2000 non-null   object
#  5   Assets             2000 non-null   object
#  6   Market Value       2000 non-null   object
#  7   Sector             1766 non-null   object
#  8   Industry           1767 non-null   object
#  9   Year               2000 non-null   int64
# dtypes: int64(2), object(8)
# memory usage: 156.4+ KB

# %%
# PLEASE READ:

# Data Clean-up
    # renamed columns are incorrect. double check when using copy/paste
    # currency columns need to either be in the same units or reflected in value. Millions vs Billions
        # 08 in billions
        # 09 in billions
        # 10 in billions
        # 11 in billions
        # 12 in billions
        # 13 in billions
        # 14 in billions
        # 15 in billions
        # 16 in billions
        # 17 in billions
        # 18 in billions
        # 19 in billions
        # 20 in billions and millions
        # 21 in billions and millions
    # currency values string format to match for analyzing

# Post Data Clean-up
    # Reformat currency columns to $ and ,

# %%
# Removing $ from the values
data20["Sales"] = data20["Sales"].str.replace('$','')
data20["Profits"] = data20["Profits"].str.replace('$','')
data20["Assets"] = data20["Assets"].str.replace('$','')
data20["Market Value"] = data20["Market Value"].str.replace('$','')

# %%
# Checking formatting was successful
data20.head()
# Out:
#    Rank                     Company Country/Territory    Sales Profits  \
# 0     1                        ICBC             China  177.2 B  45.3 B
# 1     2     China Construction Bank             China  162.1 B  38.9 B
# 2     3              JPMorgan Chase     United States  142.9 B    30 B
# 3     4          Berkshire Hathaway     United States  254.6 B  81.4 B
# 4     5  Agricultural Bank of China             China  148.7 B  30.9 B
#
#       Assets Market Value      Sector             Industry  Year
# 0  4,322.5 B      242.3 B  Financials          Major Banks  2020
# 1    3,822 B      203.8 B  Financials          Major Banks  2020
# 2  3,139.4 B      291.7 B  Financials          Major Banks  2020
# 3    817.7 B      455.4 B  Financials  Investment Services  2020
# 4  3,697.5 B      147.2 B  Financials       Regional Banks  2020

# %%
# Convert M values to B and removing the characters
value = {'M':"*0.001",'B':'',',':''}
data20['Sales']= data20['Sales'].replace(value,regex=True).map(pd.eval)
data20['Sales'] = round(data20['Sales'],2) # necessary?
data20['Profits']= data20['Profits'].replace(value,regex=True).map(pd.eval)
data20['Profits'] = round(data20['Profits'],2) # necessary?
data20['Assets']= data20['Assets'].replace(value,regex=True).map(pd.eval)
data20['Assets'] = round(data20['Assets'],2) # necessary?
data20['Market Value']= data20['Market Value'].replace(value,regex=True).map(pd.eval)
data20['Market Value'] = round(data20['Market Value'],2) # necessary?

# %%
# Checking formatting was successful
data20
# Out:
#       Rank                         Company Country/Territory   Sales  Profits  \
# 0        1                            ICBC             China  177.20    45.30
# 1        2         China Construction Bank             China  162.10    38.90
# 2        3                  JPMorgan Chase     United States  142.90    30.00
# 3        4              Berkshire Hathaway     United States  254.60    81.40
# 4        5      Agricultural Bank of China             China  148.70    30.90
# ...    ...                             ...               ...     ...      ...
# 1995  1995              Founder Securities             China    1.40     0.11
# 1996  1995    Merlin Properties SOCIMI S.A             Spain    0.59     0.63
# 1997  1998                           Heico     United States    2.10     0.37
# 1998  1999                      W.P. Carey     United States    1.20     0.31
# 1999  1999  Zhejiang Century Huatong Group             China    2.20     0.36
#
#       Assets  Market Value      Sector             Industry  Year
# 0     4322.5         242.3  Financials          Major Banks  2020
# 1     3822.0         203.8  Financials          Major Banks  2020
# 2     3139.4         291.7  Financials          Major Banks  2020
# 3      817.7         455.4  Financials  Investment Services  2020
# 4     3697.5         147.2  Financials       Regional Banks  2020
# ...      ...           ...         ...                  ...   ...
# 1995    18.6           8.3  Financials  Investment Services  2020
# 1996    14.9           4.3  Financials  Investment Services  2020
# 1997     3.1          11.8         NaN                  NaN  2020
# 1998    14.1          11.3         NaN                  NaN  2020
# 1999     4.7          12.1         NaN                  NaN  2020
#
# [2000 rows x 10 columns]

# %%
# checking type of data (currency)
data21
# Out:
#       Rank                                      Name        Country     Sales  \
# 0        1                                      ICBC          China  $190.5 B
# 1        2                            JPMorgan Chase  United States  $136.2 B
# 2        3                        Berkshire Hathaway  United States  $245.5 B
# 3        4                   China Construction Bank          China  $173.5 B
# 4        5  Saudi Arabian Oil Company (Saudi Aramco)   Saudi Arabia  $229.7 B
# ...    ...                                       ...            ...       ...
# 1995  1996                                     JTEKT          Japan   $13.1 B
# 1996  1997                 Insurance Australia Group      Australia    $5.4 B
# 1997  1997                         Sumec Corporation          China     $13 B
# 1998  1999                               Gold Fields   South Africa    $3.9 B
# 1999  1999                                    Paycom  United States    $841 M
#
#         Profit      Assets Market Value  Year
# 0      $45.8 B  $4,914.7 B     $249.5 B  2021
# 1      $40.4 B  $3,689.3 B     $464.8 B  2021
# 2      $42.5 B    $873.7 B     $624.4 B  2021
# 3      $39.3 B  $4,301.7 B     $210.4 B  2021
# 4      $49.3 B    $510.3 B   $1,897.2 B  2021
# ...        ...         ...          ...   ...
# 1995  $-34.9 M       $25 B       $3.5 B  2021
# 1996   $-212 M      $7.1 B       $9.3 B  2021
# 1997   $79.2 M      $7.5 B       $1.3 B  2021
# 1998  $718.1 M      $2.6 B       $8.9 B  2021
# 1999  $143.4 M         NaN        $24 B  2021
#
# [2000 rows x 8 columns]

# %%
data21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          2000 non-null   int64
#  1   Name          2000 non-null   object
#  2   Country       2000 non-null   object
#  3   Sales         2000 non-null   object
#  4   Profit        2000 non-null   object
#  5   Assets        1999 non-null   object
#  6   Market Value  2000 non-null   object
#  7   Year          2000 non-null   int64
# dtypes: int64(2), object(6)
# memory usage: 125.1+ KB

# %%
# Removing $ from the values
data21["Sales"] = data21["Sales"].str.replace('$','')
data21["Profit"] = data21["Profit"].str.replace('$','')
data21["Assets"] = data21["Assets"].str.replace('$','')
data21["Market Value"] = data21["Market Value"].str.replace('$','')

# %%
# Replaced one NaN value with 0 to allow for formatting
data21 = data21.fillna(0)

# %%
# Convert M values to B and removing the characters
value = {'M':"*0.001",'B':'',',':''}
data21['Sales']= data21['Sales'].replace(value,regex=True).map(pd.eval)
data21['Sales'] = round(data21['Sales'],2) # necessary?
data21['Profit']= data21['Profit'].replace(value,regex=True).map(pd.eval)
data21['Profit'] = round(data21['Profit'],2) # necessary?
data21['Assets']= data21['Assets'].replace(value,regex=True).map(pd.eval)
data21['Assets'] = round(data21['Assets'],2) # necessary?
data21['Market Value']= data21['Market Value'].replace(value,regex=True).map(pd.eval)
data21['Market Value'] = round(data21['Market Value'],2) # necessary?

# %%
# Checking formatting was successful
data21
# Out:
#       Rank                                      Name        Country   Sales  \
# 0        1                                      ICBC          China  190.50
# 1        2                            JPMorgan Chase  United States  136.20
# 2        3                        Berkshire Hathaway  United States  245.50
# 3        4                   China Construction Bank          China  173.50
# 4        5  Saudi Arabian Oil Company (Saudi Aramco)   Saudi Arabia  229.70
# ...    ...                                       ...            ...     ...
# 1995  1996                                     JTEKT          Japan   13.10
# 1996  1997                 Insurance Australia Group      Australia    5.40
# 1997  1997                         Sumec Corporation          China   13.00
# 1998  1999                               Gold Fields   South Africa    3.90
# 1999  1999                                    Paycom  United States    0.84
#
#       Profit  Assets  Market Value  Year
# 0      45.80  4914.7         249.5  2021
# 1      40.40  3689.3         464.8  2021
# 2      42.50   873.7         624.4  2021
# 3      39.30  4301.7         210.4  2021
# 4      49.30   510.3        1897.2  2021
# ...      ...     ...           ...   ...
# 1995   -0.03    25.0           3.5  2021
# 1996   -0.21     7.1           9.3  2021
# 1997    0.08     7.5           1.3  2021
# 1998    0.72     2.6           8.9  2021
# 1999    0.14     0.0          24.0  2021
#
# [2000 rows x 8 columns]

# %%
# Changing 0 back to NaN value in case needed
data21.replace(0,np.nan, inplace=True)

# %%
# Checking if formatting was successful
data21
# Out:
#       Rank                                      Name        Country   Sales  \
# 0        1                                      ICBC          China  190.50
# 1        2                            JPMorgan Chase  United States  136.20
# 2        3                        Berkshire Hathaway  United States  245.50
# 3        4                   China Construction Bank          China  173.50
# 4        5  Saudi Arabian Oil Company (Saudi Aramco)   Saudi Arabia  229.70
# ...    ...                                       ...            ...     ...
# 1995  1996                                     JTEKT          Japan   13.10
# 1996  1997                 Insurance Australia Group      Australia    5.40
# 1997  1997                         Sumec Corporation          China   13.00
# 1998  1999                               Gold Fields   South Africa    3.90
# 1999  1999                                    Paycom  United States    0.84
#
#       Profit  Assets  Market Value  Year
# 0      45.80  4914.7         249.5  2021
# 1      40.40  3689.3         464.8  2021
# 2      42.50   873.7         624.4  2021
# 3      39.30  4301.7         210.4  2021
# 4      49.30   510.3        1897.2  2021
# ...      ...     ...           ...   ...
# 1995   -0.03    25.0           3.5  2021
# 1996   -0.21     7.1           9.3  2021
# 1997    0.08     7.5           1.3  2021
# 1998    0.72     2.6           8.9  2021
# 1999    0.14     NaN          24.0  2021
#
# [2000 rows x 8 columns]

# %%
# Checking all data years to rename columns in the correct order
data14.head()
# Out:
#                       Company      Sector             Industry      Continent  \
# 0                        ICBC  Financials          Major Banks           Asia
# 1     China Construction Bank  Financials       Regional Banks           Asia
# 2  Agricultural Bank of China  Financials       Regional Banks           Asia
# 3              JPMorgan Chase  Financials          Major Banks  North America
# 4          Berkshire Hathaway  Financials  Investment Services  North America
#
#          Country  Market Value  Sales  Profits  Assets  Rank  Year
# 0          China         215.6  148.7     42.7  3124.9     1  2014
# 1          China         174.4  121.3     34.2  2449.5     2  2014
# 2          China         141.1  136.4     27.0  2405.4     3  2014
# 3  United States         229.7  105.7     17.3  2435.3     4  2014
# 4  United States         309.1  178.8     19.5   493.4     5  2014

# %%
# Should column names for the currencies reflect billions?

# %%
# rename the columns for concat
data08.columns = ['Company', 'Industry', 'Country', 'Market Value',
       'Profits', 'Assets', 'Sales', 'Rank', 'Year']
data09.columns = ['Company', 'Industry', 'Country', 'Market Value', 'Profits', 'Assets',
       'Sales', 'Rank', 'Year']
data10.columns = ['Company', 'Industry', 'Country', 'Market Value', 'Sales', 'Profits',
       'Assets', 'Rank', 'Year']
data11.columns = ['Company', 'Industry', 'Country', 'Market Value', 'Sales', 'Profits',
       'Assets', 'Rank', 'Year']
data15.columns = ['Company', 'Market Value', 'Sales', 'Profits', 'Assets', 'Rank', 'Sector',
       'Industry', 'Continent', 'Country', 'Year']
data16.columns = ['Company', 'Market Value', 'Sales', 'Profits', 'Assets', 'Rank', 'Sector',
       'Industry', 'Continent', 'Country', 'Year']
data17.columns = ['Company', 'Market Value', 'Sales', 'Profits', 'Assets', 'Rank', 'Sector',
       'Industry', 'Continent', 'Country', 'Year']
data18.columns = ['Company', 'Market Value', 'Sales', 'Profits', 'Assets', 'Rank', 'Sector',
       'Industry', 'Continent', 'Country', 'Year']
data19.columns = ['Company', 'Market Value', 'Sales', 'Profits', 'Assets', 'Rank', 'Sector',
       'Industry', 'Continent', 'Country', 'Year']
data20.columns = ['Rank', 'Company', 'Country', 'Sales', 'Profits', 'Assets',
       'Market Value', 'Sector', 'Industry', 'Year']
data21.columns = ['Rank', 'Company', 'Country', 'Sales', 'Profits', 'Assets', 'Market Value',
       'Year']

# %%
#combine the dataset together 
frames = [data08, data09, data10, data11, data12, data13, data14, data15, data16, data17, data18, data19, data20, data21]

result = pd.concat(frames)

# %%
# Displaying new df
result
# Out:
#                         Company              Industry         Country  \
# 0                 HSBC Holdings               Banking  United Kingdom
# 1              General Electric         Conglomerates   United States
# 2               Bank of America               Banking   United States
# 3                JPMorgan Chase               Banking   United States
# 4                    ExxonMobil  Oil & Gas Operations   United States
# ...                         ...                   ...             ...
# 1995                      JTEKT                   NaN           Japan
# 1996  Insurance Australia Group                   NaN       Australia
# 1997          Sumec Corporation                   NaN           China
# 1998                Gold Fields                   NaN    South Africa
# 1999                     Paycom                   NaN   United States
#
#       Market Value  Profits   Assets   Sales    Rank  Year Sector Continent
# 0           180.81    19.13  2348.98  146.50     1.0  2008    NaN       NaN
# 1           330.93    22.21   795.34  172.74     2.0  2008    NaN       NaN
# 2           176.53    14.98  1715.75  119.19     3.0  2008    NaN       NaN
# 3           136.88    15.37  1562.15  116.35     4.0  2008    NaN       NaN
# 4           465.51    40.61   242.08  358.60     5.0  2008    NaN       NaN
# ...            ...      ...      ...     ...     ...   ...    ...       ...
# 1995          3.50    -0.03    25.00   13.10  1996.0  2021    NaN       NaN
# 1996          9.30    -0.21     7.10    5.40  1997.0  2021    NaN       NaN
# 1997          1.30     0.08     7.50   13.00  1997.0  2021    NaN       NaN
# 1998          8.90     0.72     2.60    3.90  1999.0  2021    NaN       NaN
# 1999         24.00     0.14      NaN    0.84  1999.0  2021    NaN       NaN
#
# [28002 rows x 11 columns]

# %%
#result.to_csv("aroissues-forbes-global-2000-2008-2019/combined.csv")

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28002 entries, 0 to 1999
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company       28002 non-null  object
#  1   Industry      25514 non-null  object
#  2   Country       28000 non-null  object
#  3   Market Value  27993 non-null  float64
#  4   Profits       27988 non-null  float64
#  5   Assets        27987 non-null  float64
#  6   Sales         27984 non-null  float64
#  7   Rank          28000 non-null  float64
#  8   Year          28002 non-null  int64
#  9   Sector        13493 non-null  object
#  10  Continent     11993 non-null  object
# dtypes: float64(5), int64(1), object(5)
# memory usage: 2.6+ MB

# %%
# find US data
us = result.loc[result["Country"] == "United States"]

# %%
us.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7882 entries, 1 to 1999
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company       7882 non-null   object
#  1   Industry      7146 non-null   object
#  2   Country       7882 non-null   object
#  3   Market Value  7882 non-null   float64
#  4   Profits       7875 non-null   float64
#  5   Assets        7881 non-null   float64
#  6   Sales         7880 non-null   float64
#  7   Rank          7882 non-null   float64
#  8   Year          7882 non-null   int64
#  9   Sector        3839 non-null   object
#  10  Continent     3420 non-null   object
# dtypes: float64(5), int64(1), object(5)
# memory usage: 738.9+ KB

# %%
# Checking columns
us.columns
# Out:
# Index(['Company', 'Industry', 'Country', 'Market Value', 'Profits', 'Assets',
#        'Sales', 'Rank', 'Year', 'Sector', 'Continent'],
#       dtype='object')

# %%
# Removing columns
us.drop(columns=['Sector','Continent'], inplace=True)

# %%
# Checking removal was successful
us
# Out:
#                    Company                Industry        Country  \
# 1         General Electric           Conglomerates  United States
# 2          Bank of America                 Banking  United States
# 3           JPMorgan Chase                 Banking  United States
# 4               ExxonMobil    Oil & Gas Operations  United States
# 9       Berkshire Hathaway  Diversified Financials  United States
# ...                    ...                     ...            ...
# 1982    Slack Technologies                     NaN  United States
# 1985  Penn National Gaming                     NaN  United States
# 1990         Pinnacle Bank                     NaN  United States
# 1994               HubSpot                     NaN  United States
# 1999                Paycom                     NaN  United States
#
#       Market Value  Profits   Assets   Sales    Rank  Year
# 1           330.93    22.21   795.34  172.74     2.0  2008
# 2           176.53    14.98  1715.75  119.19     3.0  2008
# 3           136.88    15.37  1562.15  116.35     4.0  2008
# 4           465.51    40.61   242.08  358.60     5.0  2008
# 9           216.65    13.21   273.16  118.25    10.0  2008
# ...            ...      ...      ...     ...     ...   ...
# 1982         24.60    -0.30    22.70    0.90  1983.0  2021
# 1985         15.60    -0.67    46.00    3.60  1986.0  2021
# 1990          7.00     0.31     7.30    1.30  1990.0  2021
# 1994         24.10    -0.08    12.00    0.88  1995.0  2021
# 1999         24.00     0.14      NaN    0.84  1999.0  2021
#
# [7882 rows x 9 columns]

# %%
# Identifying unique companies
companies = us["Company"].unique()

# %%
# Number of Companies
len(companies)
# Out:
# 1262

# %%
# Converting to df
companies = pd.DataFrame(companies)

# %%
# Displaying full list of companies
companies.to_markdown()
# Out:
# "|      | 0                                                      |\n|-----:|:-------------------------------------------------------|\n|    0 | General Electric                                       |\n|    1 | Bank of America                                        |\n|    2 | JPMorgan Chase                                         |\n|    3 | ExxonMobil                                             |\n|    4 | Berkshire Hathaway                                     |\n|    5 | AT&T                                                   |\n|    6 | Wal-Mart Stores                                        |\n|    7 | Chevron                                                |\n|    8 | American Intl Group                                    |\n|    9 | ConocoPhillips                                         |\n|   10 | Goldman Sachs Group                                    |\n|   11 | Citigroup                                              |\n|   12 | Procter & Gamble                                       |\n|   13 | IBM                                                    |\n|   14 | Wells Fargo                                            |\n|   15 | Verizon Communications                                 |\n|   16 | Wachovia                                               |\n|   17 | Hewlett-Packard                                        |\n|   18 | Pfizer                                                 |\n|   19 | Johnson & Johnson                                      |\n|   20 | Microsoft                                              |\n|   21 | MetLife                                                |\n|   22 | Morgan Stanley                                         |\n|   23 | Time Warner                                            |\n|   24 | Altria Group                                           |\n|   25 | Cisco Systems                                          |\n|   26 | Intel                                                  |\n|   27 | Lehman Bros Holdings                                   |\n|   28 | Boeing                                                 |\n|   29 | American Express                                       |\n|   30 | United Technologies                                    |\n|   31 | UnitedHealth Group                                     |\n|   32 | Prudential Financial                                   |\n|   33 | US Bancorp                                             |\n|   34 | Walt Disney                                            |\n|   35 | Coca-Cola                                              |\n|   36 | CVS Caremark                                           |\n|   37 | Comcast                                                |\n|   38 | Home Depot                                             |\n|   39 | Allstate                                               |\n|   40 | PepsiCo                                                |\n|   41 | Caterpillar                                            |\n|   42 | News Corp                                              |\n|   43 | Valero Energy                                          |\n|   44 | WellPoint                                              |\n|   45 | Kraft Foods                                            |\n|   46 | Marathon Oil                                           |\n|   47 | Travelers Cos                                          |\n|   48 | Target                                                 |\n|   49 | Merck & Co                                             |\n|   50 | Abbott Laboratories                                    |\n|   51 | Dow Chemical                                           |\n|   52 | Wyeth                                                  |\n|   53 | Hartford Finl Service                                  |\n|   54 | Oracle                                                 |\n|   55 | Apple                                                  |\n|   56 | Occidental Petroleum                                   |\n|   57 | Bank of New York Mellon               ...

# %%
# Grouping by years for companies
years = us.groupby("Year")["Company"].unique()

# %%
# list of companies by year
years.head()
# Out:
# Year
# 2008    [General Electric, Bank of America, JPMorgan C...
# 2009    [General Electric, ExxonMobil, AT&T, Wal-Mart ...
# 2010    [JPMorgan Chase, General Electric, Bank of Ame...
# 2011    [JPMorgan Chase, General Electric, ExxonMobil,...
# 2012    [Exxon Mobil, JPMorgan Chase, General Electric...
# Name: Company, dtype: object

# %%
# Displaying full info as dictionary
print(years.to_dict())
# Out:
# {2008: array(['General Electric', 'Bank of America', 'JPMorgan Chase',
#        'ExxonMobil', 'Berkshire Hathaway', 'AT&T', 'Wal-Mart Stores',
#        'Chevron', 'American Intl Group', 'ConocoPhillips',
#        'Goldman Sachs Group', 'Citigroup', 'Procter & Gamble', 'IBM',
#        'Wells Fargo', 'Verizon Communications', 'Wachovia',
#        'Hewlett-Packard', 'Pfizer', 'Johnson & Johnson', 'Microsoft',
#        'MetLife', 'Morgan Stanley', 'Time Warner', 'Altria Group',
#        'Cisco Systems', 'Intel', 'Lehman Bros Holdings', 'Boeing',
#        'American Express', 'United Technologies', 'UnitedHealth Group',
#        'Prudential Financial', 'US Bancorp', 'Walt Disney', 'Coca-Cola',
#        'CVS Caremark', 'Comcast', 'Home Depot', 'Allstate', 'PepsiCo',
#        'Caterpillar', 'News Corp', 'Valero Energy', 'WellPoint',
#        'Kraft Foods', 'Marathon Oil', 'Travelers Cos', 'Target',
#        'Merck & Co', 'Abbott Laboratories', 'Dow Chemical', 'Wyeth',
#        'Hartford Finl Service', 'Oracle', 'Apple', 'Occidental Petroleum',
#        'Bank of New York Mellon', 'Dell', 'EI du Pont de Nemours',
#        'Lockheed Martin', 'Honeywell International', "Lowe's Cos",
#        'Exelon', 'Loews', '3M', 'Alcoa', 'Archer Daniels', 'Google',
#        "McDonald's", 'Deere & Co', 'Freeport Copper', 'Amgen',
#        'Eli Lilly & Co', 'Aetna', 'Devon Energy', 'Northrop Grumman',
#        'Walgreen', 'Aflac', 'Bristol-Myers Squibb', 'General Dynamics',
#        'Capital One Financial', 'Hess', 'FedEx', 'Anadarko Petroleum',
#        'Union Pacific', 'SunTrust Banks', 'Emerson Electric',
#        'Dominion Resources', 'State Street', 'Southern Co',
#        'Cardinal Health', 'Burlington Santa Fe', 'Raytheon', 'Chubb',
#        'Costco Wholesale', 'Medtronic', 'PNC Financial Services',
#        'Apache', 'FPL Group', 'BB&T', 'Duke Energy', 'Johnson Controls',
#        'Liberty Media', 'Anheuser-Busch Cos', 'Kroger', 'McKesson',
#        'Qualcomm', 'Kimberly-Clark', 'EMC', 'Viacom',
#        'United Parcel Service', 'Regions Financial', 'Lincoln National',
#        'Halliburton', 'FirstEnergy', 'Pub Svc Enterprise', 'CBS',
#        'American Electric', 'Illinois Tool Works', 'Best Buy',
#        'Texas Instruments', 'Medco Health', 'Entergy', 'DirecTV Group',
#        'Cigna', 'Principal Financial', 'Edison International',
#        'Sears Holdings', 'International Paper', 'Baxter International',
#        'Norfolk Southern', 'Genworth Financial', 'CSX', 'NIKE',
#        'Chesapeake Energy', 'Charles Schwab', 'Merrill Lynch', 'PG&E',
#        'Xerox', 'Danaher', 'Constellation Energy', 'Qwest Communications',
#        'Williams Cos', 'Fifth Third Bancorp', 'Monsanto', "Macy's",
#        'Colgate-Palmolive', 'Automatic Data', 'Safeway', 'Sempra Energy',
#        'Waste Management', 'Paccar', 'Ameriprise Financial',
#        'General Mills', 'Marsh & McLennan', 'MGM Mirage', 'Fannie Mae',
#        'Weyerhaeuser', 'Progressive', 'Coca-Cola Enterprises',
#        'Reynolds American', 'Consolidated Edison', 'Thermo Fisher',
#        'Omnicom Group', 'Sysco', 'Textron', 'Corning', 'XTO Energy',
#        'Nucor', 'Praxair', 'National Oilwell Varco', 'Ford Motor',
#        'US Steel', 'KeyCorp', 'Applied Materials', 'Freddie Mac',
#        'JC Penney', 'PPL', 'Air Prods & Chems', 'Kellogg', 'Baker Hughes',
#        'General Motors', 'Humana', 'Sprint Nextel', 'Electronic Data Sys',
#        "Kohl's", 'Northern Trust', 'Unum Group', 'Staples', 'Aon',
#        'L-3 Communications', 'Sun Microsystems', 'Eaton', 'Murphy Oil',
#        'BlackRock', 'Clear Channel Commun', 'Calpine', 'Motorola',
#        'Washington Mutual', 'Mosaic', 'ProLogis', 'Franklin Resources',
#        'National City', 'Sunoco', 'Yahoo', 'ConAgra Foods',
#        'Progress Energy', 'Spectra Energy', 'Gap', 'Supervalu',
#        'HJ Heinz', 'PPG Industries', 'Xcel Energy', 'Schering-Plough',
#        'El Paso', 'DISH Network', 'DTE Energy', 'Goodyear',
#        'Southwest Airlines', 'Assurant', 'Ebay', 'TJX Cos',
#        'EOG Resources', 'M&T Bank', 'Yum Brands', 'Computer Sciences',
#        'Parker-Hannifin', 'Marriott International', 'Ameren',
#        'Fortune Brands', 'Whirlpool', 'AmerisourceBergen', 'Sara Lee',
#        'Becton, Dickinson', 'Amazon.com', 'Discover Financial Services',
#        'ITT', 'Stryker', 'Gannett', 'Simon Property Group', 'Cummins',
#        'Owens-Illinois', 'Pepsi Bottling Group', 'NRG Energy',
#        'Rohm and Haas', 'NYSE Euronext', 'AES', 'Boston Scientific',
#        'SLM', 'AMR', 'CME Group', 'Nationwide Financial',
#        'Gilead Sciences', 'Express Scripts', 'Comerica', 'Liberty Global',
#        'McGraw-Hill Cos', 'Campbell Soup', 'Fluor', 'Symantec',
#        'Vornado Realty', 'Molson Coors Brewing', 'Precision Castparts',
#        'Eastman Kodak', 'Marshall & Ilsley', 'UAL', 'Starbucks',
#        'Avon Products', 'Smith International', 'Host Hotels & Resorts',
#        'MasterCard', 'Coventry Health Care', 'Tesoro',
#        'Countrywide Financial', 'Noble Energy', 'Dover', 'Masco',
#        'TD Ameritrade Holding', 'Equity Residential',
#        'Cincinnati Financial', 'Legg Mason', 'Reliant Energy',
#        'WR Berkley', 'Starwood Hotels', 'Annaly Capital Mgmt',
#        'CenterPoint Energy', 'Western Union', 'Limited Brands',
#        'Agilent Technologies', 'Boston Properties', 'Peabody Energy',
#        'Newmont Mining', 'Zimmer Holdings', 'Nordstrom', 'Avnet',
#        'Embarq', 'Zions Bancorp', 'Harley-Davidson', 'Genzyme',
#        'Wm Wrigley Jr', 'Terex', 'VF', 'Biogen Idec',
#        'Continental Airlines', 'Pepco Holdings', 'Mirant', 'Manpower',
#        'Fidelity National Info', 'Mohawk Industries', 'CA', 'NiSource',
#        'Quest Diagnostics', 'Delta Air Lines', 'Allergan',
#        'Rockwell Automation', 'Safeco', 'Tyson Foods', 'CIT Group',
#        'Oneok', 'Goodrich', 'Fiserv', 'Pitney Bowes', 'Genuine Parts',
#        'General Growth Prop', 'Hudson City Bancorp', 'Public Storage',
#        'RR Donnelley & Sons', 'Nvidia', 'Western Digital',
#        'Adobe Systems', 'Bed Bath & Beyond', 'Sovereign Bancorp',
#        'Navistar Intl', 'Sherwin-Williams', 'Arrow Electronics',
#        'Allegheny Technologies', 'SAIC', 'Celanese', 'Estee Lauder Cos',
#        'Jacobs Engineering', 'AutoZone', 'Torchmark',
#        'Northwest Airlines', 'Trane', 'Virgin Media', 'Ingram Micro',
#        'Ecolab', 'St Jude Medical', 'MEMC Electronic',
#        'Newell Rubbermaid', 'BJ Services', 'Hertz Global Holdings',
#        'Rockwell Collins', 'US Airways Group', 'Mattel',
#        'American Finl Group', 'Office Depot', 'Delphi', 'Forest Labs',
#        'Allegheny Energy', 'HCP', 'Cameron International',
#        'Commerce Bancorp', 'Rite Aid', 'CH Robinson Worldwide',
#        'AutoNation', 'Las Vegas Sands', 'Clorox', 'Leucadia National',
#        'Windstream', 'Cablevision', 'Vulcan Materials', 'T Rowe Price',
#        'Crown Holdings', 'SL Green Realty', 'Tele & Data Systems',
#        'TRW Automotive Hldgs', 'Coach', 'Integrys Energy Group',
#        'Ensco International', 'Micron Technology', 'Juniper Networks',
#        'IAC/InterActiveCorp', 'Harris', 'Wisconsin Energy',
#        'AK Steel Holding', 'Laboratory Corp Amer', 'WW Grainger',
#        'New York Community', 'Huntsman', 'Intl Game Technology',
#        'MeadWestvaco', 'Kimco Realty', "Moody's", 'DaVita', 'Lear',
#        'Consol Energy', 'Allied Waste Inds', 'DR Horton', 'Paychex',
#        'KBR', 'Questar', 'Conseco', 'Huntington Bancshs',
#        'Eastman Chemical', 'Synovus Financial', 'CB Richard Ellis',
#        'Avery Dennison', 'Protective Life', 'Black & Decker',
#        'Analog Devices', 'Temple-Inland', 'Scana', 'Affiliated Computer',
#        'Wyndham Worldwide', 'Smithfield Foods', 'Popular',
#        'Newfield Exploration', 'Expeditors Intl', 'Polo Ralph Lauren',
#        'Community Health Sys', 'Abercrombie & Fitch', 'Dynegy',
#        'Apollo Group', 'CMS Energy', 'Pulte Homes', 'Energy East',
#        'Hormel Foods', 'Pride International', 'Centex', 'Lennar',
#        'American Tower', 'Northeast Utilities', 'Interpublic Group',
#        'UST', 'FMC Technologies', 'Charter Commun', 'Avis Budget Group',
#        'H&R Block', 'Reliance Steel', 'Advanced Micro', 'Intuit',
#        'Health Net', 'CR Bard', 'Crown Castle Intl', 'GameStop',
#        'Washington Post', 'AGCO', 'American Natl Ins', 'Ball',
#        'Steel Dynamics', 'Commercial Metals', 'SPX', 'Old Republic Intl',
#        'Markel', 'MDU Resources', 'Avalonbay Communities', 'KLA-Tencor',
#        'Dean Foods', 'Tenet Healthcare', 'Visteon', 'Jabil Circuit',
#        'Celgene', 'Electronic Arts', 'Pioneer Natural Res', 'Tech Data',
#        'Associated Banc-Corp', 'E-Trade Financial', 'First American',
#        'Wynn Resorts', 'Constellation Brands', 'First Horizon National',
#        'Frontier Oil', 'NII Holdings', 'Expedia', 'VMware',
#        'Grant Prideco', 'Hershey', 'MBIA', 'Brown-Forman', 'Lam Research',
#        'Cognizant Technology', 'Pinnacle West', 'Thornburg Mortgage',
#        'Interactive Brokers Group', 'BorgWarner', 'Ryder System',
#        'Oshkosh Truck', 'Nasdaq OMX Group', 'Raymond James Finl',
#        'Ultra Petroleum', 'IndyMac Bancorp', 'Dana Holding',
#        "People's United Financial", 'Jefferies Group',
#        'World Fuel Services', 'DST Systems', 'Broadcom', 'Phoenix Cos',
#        'Maxim Integrated Prods', 'Nelnet', 'Smurfit-Stone',
#        'Alliant Energy', 'OfficeMax', 'Penske Automotive Gp', 'Manitowoc',
#        'Autodesk', 'CF Industries Holdings', 'Network Appliance',
#        'EW Scripps', 'TCF Financial', 'First Solar', 'Colonial BancGroup',
#        'Quicksilver Resources', 'TECO Energy', 'Circuit City Stores',
#        'Federal-Mogul', 'Whole Foods Market', 'Energizer Holdings',
#        'CenturyTel', 'Ambac Financial Group', 'Shaw Group',
#        'BOK Financial', 'AmeriCredit', 'Henry Schein', 'Xilinx',
#        'Omnicare', 'Amphenol', 'Linear Technology', 'Hologic',
#        'Sealed Air', 'Astoria Financial', 'SanDisk', 'Sanmina-SCI', 'NVR',
#        'Activision', 'Developers Diversified', 'iStar Financial',
#        'Sigma-Aldrich', 'AMB Property', 'YRC Worldwide', 'Flowserve',
#        'HCC Insurance', 'Plains Exploration & Production',
#        'Southwestern Energy', 'Western Refining', "Dillard's", 'Ashland',
#        'Impac Mortgage Holding', 'Level 3 Commun',
#        'IntercontinentalExchange', 'Family Dollar Stores',
#        'Robert Half Intl', 'KKR Financial', "BJ's Wholesale Club",
#        'Joy Global', 'Fidelity National Finl', 'City National',
#        'Microchip Technology', 'Range Resources', 'Holly',
#        'CapitalSource', 'HealthSouth', 'StanCorp Financial',
#        'Stanley Works', 'CarMax', 'United Rentals', "Pilgrim's Pride",
#        'Lexmark International', 'W Holding', 'Sonic Automotive',
#        'Helmerich & Payne', 'Rowan Cos', 'Cintas', 'Owens Corning',
#        'Ross Stores', 'Plum Creek Timber', 'Webster Financial',
#        'First BanCorp', 'Nymex Holdings', 'Intuitive Surgical',
#        'Denbury Resources', 'Harsco', 'Guaranty Financial Group',
#        'Amer Eagle Outfitters', 'Equitable Resources', 'UGI',
#        'First Citizens Bcshs', 'Commerce Bancshs',
#        'American Equity Invest', 'Anixter International', 'Atmos Energy',
#        'RH Donnelley', 'Fulton Financial', 'URS', 'Wesco International',
#        'Flagstar Bancorp'], dtype=object), 2009: array(['General Electric', 'ExxonMobil', 'AT&T', 'Wal-Mart Stores',
#        'Chevron', 'JPMorgan Chase', 'Berkshire Hathaway',
#        'Procter & Gamble', 'Verizon Communications', 'IBM',
#        'Hewlett-Packard', 'Bank of America', 'Johnson & Johnson',
#        'Microsoft', 'Pfizer', 'Wells Fargo', 'Goldman Sachs Group',
#        'Cisco Systems', 'CVS Caremark', 'United Technologies', 'MetLife',
#        'Morgan Stanley', 'Intel', 'Comcast', 'Walt Disney',
#        'UnitedHealth Group', 'Kraft Foods', 'Coca-Cola', 'Apple',
#        'PepsiCo', 'Abbott Laboratories', 'Boeing', 'Merck & Co',
#        'US Bancorp', 'Caterpillar', 'Home Depot', 'Oracle',
#        'Travelers Cos', 'Occidental Petroleum', 'American Express',
#        'Wyeth', 'Marathon Oil', 'Target', 'United Parcel Service',
#        'Philip Morris International', 'WellPoint', 'Lockheed Martin',
#        'Google', 'Archer Daniels', 'Honeywell International',
#        "Lowe's Cos", "McDonald's", 'Exelon', 'Bank of New York Mellon',
#        'Bristol-Myers Squibb', 'Amgen', 'Walgreen', 'Dell', '3M',
#        'EI du Pont de Nemours', 'Hess', 'Anadarko Petroleum',
#        'Southern Co', 'General Dynamics', 'Union Pacific', 'Deere & Co',
#        'Burlington Santa Fe', 'Altria Group', 'Dominion Resources',
#        'FPL Group', 'Schering-Plough', 'State Street', 'Loews', 'Aetna',
#        'Emerson Electric', 'Cardinal Health', 'Medtronic',
#        'Costco Wholesale', 'Chubb', 'Kroger', 'Duke Energy', 'Raytheon',
#        'Qualcomm', 'FedEx', 'PG&E', 'McKesson', 'American Electric',
#        'Aflac', 'BB&T', 'Medco Health', 'Best Buy', 'Kimberly-Clark',
#        'PNC Financial Services', 'EMC', 'FirstEnergy', 'Entergy',
#        'DirecTV Group', 'Monsanto', 'Edison International', 'XTO Energy',
#        'Pub Svc Enterprise', 'Consolidated Edison', 'Dow Chemical',
#        'Baxter International', 'National Oilwell Varco', 'NIKE',
#        'Automatic Data', 'Norfolk Southern', 'General Mills', 'Nucor',
#        'Halliburton', 'Mosaic', 'Apache', 'Illinois Tool Works',
#        'Safeway', 'ConocoPhillips', 'CSX', 'Viacom', 'Danaher',
#        'Waste Management', 'Colgate-Palmolive', 'Chesapeake Energy',
#        'Visa', 'Sempra Energy', 'Texas Instruments', 'Thermo Fisher',
#        'Williams Cos', 'SunTrust Banks', 'Corning', 'Murphy Oil', 'Sysco',
#        'Charles Schwab', 'Time Warner', 'AES', 'Ebay', 'Progress Energy',
#        'Staples', 'Northern Trust', 'Aon', 'Paccar', 'Praxair',
#        'EOG Resources', 'Citigroup', 'Reynolds American', 'Omnicom Group',
#        'Kellogg', 'L-3 Communications', 'PPL', 'Eaton', 'Baker Hughes',
#        'Xcel Energy', "Kohl's", 'Computer Sciences', 'Amazon.com',
#        'News Corp', 'Allstate', 'Qwest Communications',
#        'Prudential Financial', 'Newmont Mining', 'Valero Energy',
#        'Sprint Nextel', 'Ford Motor', 'ConAgra Foods', 'Eli Lilly & Co',
#        'HJ Heinz', 'Air Prods & Chems', 'Sunoco', 'Northrop Grumman',
#        'Spectra Energy', 'NRG Energy', 'Humana', 'US Steel', 'Unum Group',
#        'BlackRock', 'PPG Industries', 'Cigna', 'Devon Energy', 'ITT',
#        'Gap', 'Ameren', 'Express Scripts', 'Parker-Hannifin', 'TJX Cos',
#        'Motorola', 'Gilead Sciences', 'DTE Energy', 'Yahoo', 'CME Group',
#        'Capital One Financial', 'Becton, Dickinson', 'Yum Brands',
#        'Freeport Copper', 'Applied Materials', 'Stryker', 'Alcoa',
#        'Rohm and Haas', 'Smith International', 'Johnson Controls',
#        "Macy's", 'Discover Financial Services', 'Fluor',
#        'Franklin Resources', 'JC Penney', 'CenterPoint Energy',
#        'AmerisourceBergen', 'Principal Financial', 'Sears Holdings',
#        'Peabody Energy', 'Cummins', 'M&T Bank', 'Noble Energy',
#        'Simon Property Group', 'Xerox', 'Campbell Soup', 'Avon Products',
#        'Delta Air Lines', 'Quest Diagnostics', 'DISH Network',
#        'Boston Scientific', 'Precision Castparts', 'Progressive', 'CA',
#        'Coca-Cola Enterprises', 'Biogen Idec', 'Hudson City Bancorp',
#        'Fannie Mae', 'Annaly Capital Mgmt', 'Marriott International',
#        'Marsh & McLennan', 'Constellation Energy', 'Assurant',
#        'General Motors', 'Embarq', 'Supervalu', 'Textron', 'Dover',
#        'Genzyme', 'Pepco Holdings', 'Public Storage',
#        'Ameriprise Financial', 'SAIC', 'VF', 'McGraw-Hill Cos',
#        'AutoZone', 'Liberty Global', 'Western Union',
#        'TD Ameritrade Holding', 'KeyCorp', 'Goodrich', 'Zimmer Holdings',
#        'International Paper', 'Allergan', 'Regions Financial', 'Fiserv',
#        'CBS', 'Whirlpool', 'Oneok', 'Molson Coors Brewing',
#        'Genuine Parts', 'Lincoln National', 'Vornado Realty',
#        'Freddie Mac', 'Agilent Technologies', 'Sherwin-Williams',
#        'Weyerhaeuser', 'American Intl Group', 'Jacobs Engineering',
#        'Southwest Airlines', 'CH Robinson Worldwide',
#        'Hartford Finl Service', 'Fortune Brands', 'Pepsi Bottling Group',
#        'Ecolab', 'Wisconsin Energy', 'Sara Lee',
#        'Dr Pepper Snapple Group', 'Pitney Bowes', 'Bed Bath & Beyond',
#        'SLM', 'Symantec', 'Tyson Foods', 'Lorillard', 'Adobe Systems',
#        'WW Grainger', 'Equity Residential', 'El Paso', 'Clorox',
#        'Genworth Financial', 'Scana', 'Questar', 'AMR', 'Forest Labs',
#        'Western Digital', 'Estee Lauder Cos', 'Sun Microsystems',
#        'DaVita', 'Fifth Third Bancorp', 'Cameron International',
#        'Northeast Utilities', 'Consol Energy', 'Rockwell Collins',
#        'Juniper Networks', 'CMS Energy', 'St Jude Medical', 'GameStop',
#        'WR Berkley', 'Cincinnati Financial', 'HCP', 'Huntsman',
#        'Affiliated Computer', 'Calpine', 'American Tower',
#        'Republic Services', 'UAL', 'Apollo Group', 'Harley-Davidson',
#        'Laboratory Corp Amer', 'Tesoro', 'H&R Block', 'Nasdaq OMX Group',
#        'NiSource', 'Southwestern Energy', 'Ball', 'Hershey',
#        'Darden Restaurants', 'Activision Blizzard', 'Goodyear',
#        'Allegheny Energy', 'Mattel', 'CIT Group', 'Paychex', 'Starbucks',
#        'Expeditors Intl', 'Nordstrom', 'MasterCard',
#        'IntercontinentalExchange', 'Liberty Media-Entertainment',
#        'Coventry Health Care', 'Comerica', 'Harris', 'NYSE Euronext',
#        'Host Hotels & Resorts', 'Discovery Communications', 'Cablevision',
#        "People's United Financial", 'Rite Aid', 'BJ Services',
#        'Integrys Energy Group', 'Hormel Foods', 'Polo Ralph Lauren',
#        'Coach', 'Rockwell Automation', 'Community Health Sys',
#        'Ensco International', 'Ross Stores', 'CR Bard',
#        'Continental Airlines', 'Owens-Illinois', 'Crown Holdings',
#        'Dean Foods', 'Interpublic Group', 'T Rowe Price',
#        'Starwood Hotels', 'Brown-Forman', 'Navistar Intl', 'Mirant',
#        'Intuit', 'Manpower', 'Liberty Media-Interactive',
#        'New York Community', 'Avnet', 'CF Industries Holdings',
#        'MGM Mirage', 'Delphi', 'First Solar', 'Mylan', 'KBR',
#        'Family Dollar Stores', 'Reliance Steel', 'URS', 'Analog Devices',
#        'Hertz Global Holdings', 'Broadcom', 'Cognizant Technology',
#        'Reinsurance Group of America', 'CC Media Holdings',
#        'Pride International', 'Ultra Petroleum', 'Steel Dynamics',
#        'Reliant Energy', 'Marshall & Ilsley', 'Ingram Micro',
#        'FMC Technologies', 'TRW Automotive Hldgs', 'Windstream',
#        'Limited Brands', 'VMware', 'Flowserve', 'Linear Technology',
#        'Xilinx', 'Micron Technology', "Moody's", 'Amphenol', 'AGCO',
#        'Torchmark', 'Range Resources', 'Arrow Electronics',
#        'Avalonbay Communities', 'Henry Schein', 'RR Donnelley & Sons',
#        'Allegheny Technologies', 'MDU Resources', 'ProLogis', 'UGI',
#        'Conseco', 'Altera', 'American Finl Group', 'Omnicare', 'Masco',
#        'Huntington Bancshs', 'Crown Castle Intl', 'Celgene',
#        'Smithfield Foods', 'Vulcan Materials', 'Advance Auto Parts',
#        'Charter Commun', 'Boston Properties', 'CenturyTel', 'Hospira',
#        'Sigma-Aldrich', 'Eastman Kodak', 'Fidelity National Finl',
#        'International Assets Holding', 'Tele & Data Systems',
#        'Virgin Media', 'Ashland', 'Tech Data', 'Pinnacle West',
#        'Zions Bancorp', 'Life Technologies', 'Terra Industries', 'Cintas',
#        'Hasbro', 'Electronic Arts', 'JM Smucker', 'E-Trade Financial',
#        'NStar', 'Alliant Energy', 'Lear', 'US Airways Group',
#        'Eastman Chemical', 'Avery Dennison', 'Dollar Tree',
#        'MEMC Electronic', 'Celanese', 'SL Green Realty',
#        'Commerce Bancshs', 'World Fuel Services', 'Jabil Circuit',
#        'Protective Life', 'Dun & Bradstreet', 'TFS Financial', 'Fastenal',
#        'Popular', 'Denbury Resources', 'First American', 'Pulte Homes',
#        'Cullen/Frost Bankers', 'DR Horton', 'BMC Software',
#        'Tenet Healthcare', 'Avis Budget Group', 'Las Vegas Sands',
#        'Synovus Financial', 'First Horizon National',
#        'Energizer Holdings', 'General Growth Prop', 'Commercial Metals',
#        'HCC Insurance', 'Health Net', 'AutoNation', 'Helmerich & Payne',
#        'Apartment Investment', 'Waters', 'SPX', 'Varian Medical Systems',
#        'Office Depot', 'NII Holdings', 'Raymond James Finl',
#        'BOK Financial', 'MBIA', 'Health Care REIT', 'Roper Industries',
#        'Microchip Technology', 'Interactive Brokers Group',
#        'Constellation Brands', 'Nelnet', 'McCormick & Co', 'Airgas',
#        'Black & Decker', 'Thornburg Mortgage', 'EQT',
#        'Colonial BancGroup', 'Atmos Energy', 'MeadWestvaco',
#        'Phoenix Cos', 'Associated Banc-Corp', 'Dentsply Intl',
#        'Stanley Works', 'Kimco Realty', 'Penske Automotive Gp',
#        'Petrohawk Energy', 'Plum Creek Timber', 'Dana Holding',
#        'Northstar Realty Finance', 'Cephalon', 'MetroPCS Comm', 'UDR',
#        'NV Energy', 'Gannett', 'Cliffs Natural Resources',
#        'Western Refining', 'Washington Post', 'Astoria Financial',
#        "O'Reilly Automotive", 'FMC', 'Robert Half Intl',
#        "BJ's Wholesale Club", 'Fidelity National Info', 'Terex',
#        'Federal-Mogul', 'CarMax', 'Continental Resources', 'Timken',
#        'Visteon', 'Great A&P Tea', 'Jefferies Group', 'Aecom Technology',
#        'NetApp', 'Alliant Techsystems', 'First BanCorp',
#        'OSI Pharmaceuticals', 'Nvidia', 'Old Republic Intl',
#        'YRC Worldwide', 'HLTH', 'CapitalSource', 'Vertex Pharmaceuticals',
#        'ITT Educational Services', 'American Natl Ins', 'Advanced Micro'],
#       dtype=object), 2010: array(['JPMorgan Chase', 'General Electric', 'Bank of America',
#        'ExxonMobil', 'Wells Fargo', 'AT&T', 'Wal-Mart Stores',
#        'Berkshire Hathaway', 'Chevron', 'Goldman Sachs Group',
#        'Procter & Gamble', 'IBM', 'Hewlett-Packard',
#        'Verizon Communications', 'ConocoPhillips', 'Pfizer',
#        'Johnson & Johnson', 'Microsoft', 'Ford Motor', 'Merck & Co',
#        'Apple', 'Cisco Systems', 'CVS Caremark', 'Comcast',
#        'UnitedHealth Group', 'United Technologies', 'Walt Disney',
#        'Intel', 'Prudential Financial', 'Coca-Cola',
#        'Abbott Laboratories', 'PepsiCo', 'Kraft Foods', 'Morgan Stanley',
#        'Oracle', 'American Express', 'WellPoint', 'US Bancorp',
#        'Home Depot', 'Boeing', 'Google', 'Target', 'News Corp',
#        'Travelers Cos', 'Philip Morris International', 'Time Warner',
#        'PNC Financial Services', 'United Parcel Service',
#        'Lockheed Martin', "McDonald's", "Lowe's Cos",
#        'Occidental Petroleum', 'Walgreen', 'Honeywell International',
#        'Caterpillar', 'Amgen', 'Bristol-Myers Squibb', 'Marathon Oil',
#        '3M', 'Exelon', 'EI du Pont de Nemours', 'Altria Group',
#        'General Dynamics', 'Dell', 'Aflac', 'Eli Lilly & Co',
#        'Dow Chemical', 'Allstate', 'Southern Co', 'Union Pacific',
#        'Archer Daniels', 'Northrop Grumman', 'Costco Wholesale',
#        'Medtronic', 'McKesson', 'State Street', 'Capital One Financial',
#        'FPL Group', 'Deere & Co', 'Freeport Copper', 'Raytheon',
#        'Dominion Resources', 'Chubb', 'Aetna', 'Medco Health',
#        'Emerson Electric', 'Qualcomm', 'Duke Energy', 'Time Warner Cable',
#        'BB&T', 'American Electric', 'EMC', 'Hess', 'Kimberly-Clark',
#        'XTO Energy', 'Visa', 'PG&E', 'Best Buy', 'Directv',
#        'Baxter International', 'Johnson Controls', 'Amazon.com',
#        'General Mills', 'Loews', 'Cigna', 'Cardinal Health',
#        'Pub Svc Enterprise', 'Viacom', 'NIKE', 'Entergy', 'Monsanto',
#        'National Oilwell Varco', 'Colgate-Palmolive', 'Automatic Data',
#        'Citigroup', 'Halliburton', 'Ebay', 'FirstEnergy',
#        'Consolidated Edison', 'Danaher', 'CSX', 'Edison International',
#        'Express Scripts', 'Illinois Tool Works', 'Fifth Third Bancorp',
#        'International Paper', 'Waste Management', 'Newmont Mining',
#        'Norfolk Southern', 'Staples', 'Sysco', 'Constellation Energy',
#        'Thermo Fisher', 'Progressive', 'Ameriprise Financial', "Kohl's",
#        'Texas Instruments', 'MetLife', 'Coca-Cola Enterprises', 'Corning',
#        'Sempra Energy', 'Progress Energy', 'Praxair', 'Xerox', 'Kellogg',
#        'Charles Schwab', 'AES', 'Unum Group', 'Principal Financial',
#        'Humana', 'Reynolds American', 'Discover Financial Services',
#        'L-3 Communications', 'Omnicom Group', 'Gilead Sciences',
#        'Murphy Oil', 'BlackRock', 'Computer Sciences', 'Xcel Energy',
#        'Northern Trust', 'AmerisourceBergen', 'TJX Cos', 'Sears Holdings',
#        'Aon', 'Qwest Communications', "Macy's", 'Gap',
#        'Air Prods & Chems', 'ConAgra Foods', 'HJ Heinz', 'Yahoo',
#        'Spectra Energy', 'Hartford Finl Service', 'FedEx',
#        'Republic Services', 'Becton, Dickinson',
#        'Bank of New York Mellon', 'Eaton', 'NRG Energy',
#        'Annaly Capital Mgmt', 'Stryker', 'EOG Resources', 'Yum Brands',
#        'PPL', 'Sprint Nextel', 'Sara Lee', 'Williams Cos', 'Kroger',
#        'CME Group', 'Valero Energy', 'DTE Energy', 'ITT', 'Baker Hughes',
#        'Delta Air Lines', 'Alcoa', 'Mosaic', 'PPG Industries',
#        'Anadarko Petroleum', 'CBS', 'SunTrust Banks', 'Motorola',
#        'MasterCard', 'CenturyTel', 'Franklin Resources', 'Ameren',
#        'DISH Network', 'Fluor', 'Apache', 'Whirlpool', 'SLM',
#        'Marsh & McLennan', 'Cummins', 'Avon Products', 'M&T Bank',
#        'Devon Energy', 'Precision Castparts', 'Simon Property Group',
#        'Starbucks', 'Quest Diagnostics', 'Regions Financial',
#        'Peabody Energy', 'Biogen Idec', 'CA', 'Western Digital',
#        'American Intl Group', 'Lincoln National', 'Chesapeake Energy',
#        'Genworth Financial', 'Safeway', 'JC Penney', 'CenterPoint Energy',
#        'Campbell Soup', 'Liberty Media-Interactive', 'Dollar General',
#        'Hudson City Bancorp', 'Goodrich', 'Parker-Hannifin',
#        'Liberty Global', 'Genzyme', 'Allergan', 'Western Union',
#        'Symantec', 'Assurant', 'Freddie Mac', 'Boston Scientific',
#        'TD Ameritrade Holding', 'McGraw-Hill Cos', 'Fannie Mae',
#        'Dr Pepper Snapple Group', 'St Jude Medical', 'Bed Bath & Beyond',
#        'Oneok', 'Public Storage', 'Nucor', 'New York Community', 'SAIC',
#        'Zimmer Holdings', 'Nordstrom', 'Limited Brands',
#        'Reinsurance Group of America', 'Cameron International',
#        'Estee Lauder Cos', 'AutoZone', 'VF', 'Paccar', 'Cablevision',
#        'Consol Energy', 'KeyCorp', 'Southwest Airlines',
#        'Discovery Communications', 'US Steel', 'Dover', 'Tyson Foods',
#        'Equity Residential', 'Fortune Brands', 'Molson Coors Brewing',
#        'Celgene', 'Clorox', 'CH Robinson Worldwide',
#        'IntercontinentalExchange', 'Ecolab', 'Genuine Parts', 'DaVita',
#        'Lorillard', 'Smith International', 'American Finl Group',
#        'Forest Labs', 'Northeast Utilities', 'Mattel', 'Textron',
#        'JM Smucker', 'Sherwin-Williams', 'Pepco Holdings',
#        'Las Vegas Sands', 'Wisconsin Energy', 'Fiserv', 'Hershey',
#        'Apollo Group', 'NYSE Euronext', 'WW Grainger', 'CIT Group',
#        'Advanced Micro', 'Rockwell Collins', 'NiSource',
#        'Community Health Sys', 'Applied Materials', 'Adobe Systems',
#        'AMR', 'Supervalu', 'Laboratory Corp Amer', 'Pitney Bowes',
#        'Marriott International', 'Cognizant Technology', 'Mylan',
#        'Weyerhaeuser', 'Celanese', 'Cincinnati Financial',
#        'Jacobs Engineering', 'Coach', 'Navistar Intl', 'Ross Stores',
#        'Ball', 'El Paso', 'WR Berkley', 'Polo Ralph Lauren',
#        'Darden Restaurants', 'Transatlantic Holdings', 'American Tower',
#        'NII Holdings', 'Scana', 'MBIA', 'Ashland', 'Coventry Health Care',
#        'Hormel Foods', 'UAL', 'H&R Block', 'Boston Properties', 'Calpine',
#        'Ingram Micro', 'Crown Holdings', 'CMS Energy', 'MGM Mirage',
#        'Questar', 'T Rowe Price', 'Hospira', 'Paychex',
#        'Micron Technology', 'Intuit', 'Jefferies Group', 'Priceline.com',
#        'Vornado Realty', 'Sunoco', 'NetApp', 'First Solar',
#        'Virgin Media', 'Lubrizol', 'Torchmark', 'URS', 'Goodyear',
#        'CareFusion', 'FMC Technologies', 'Henry Schein', 'Comerica',
#        'SanDisk', 'Protective Life', 'Flowserve', 'Family Dollar Stores',
#        'Dean Foods', 'Fidelity National Info', 'Mead Johnson Nutrition',
#        'Avnet', 'Gannett', 'KBR', 'MeadWestvaco', 'Allegheny Energy',
#        'GameStop', 'CR Bard', 'Owens-Illinois', 'Hertz Global Holdings',
#        'Host Hotels & Resorts', 'Leucadia National',
#        'Continental Airlines', 'Brown-Forman', 'Dollar Tree',
#        "O'Reilly Automotive", 'Agilent Technologies', 'CarMax', 'Masco',
#        'Rite Aid', 'Noble Energy', 'Whole Foods Market', 'Analog Devices',
#        'Wyndham Worldwide', 'Intuitive Surgical', 'Expeditors Intl',
#        'VMware', 'RR Donnelley & Sons', 'Charter Commun',
#        'Marshall & Ilsley', 'Joy Global', 'Broadcom', 'Crown Castle Intl',
#        'Starwood Hotels', 'Tech Data', 'Hasbro', 'Windstream',
#        'Newell Rubbermaid', 'Interpublic Group', 'Manpower',
#        'Arrow Electronics', 'Tesoro', 'Juniper Networks', 'BMC Software',
#        "Moody's", 'Liberty Media-Starz', 'Tenet Healthcare',
#        'Nasdaq OMX Group', 'Huntington Bancshs', 'HCP', 'Amphenol',
#        'Conseco', 'Integrys Energy Group', 'Harley-Davidson',
#        'Life Technologies', 'CC Media Holdings', 'Harris',
#        "People's United Financial", 'TRW Automotive Hldgs', 'Mirant',
#        'ProLogis', 'Rockwell Automation', 'Advance Auto Parts',
#        'Fidelity National Finl', 'Expedia', 'First American', 'Xilinx',
#        'Zions Bancorp', 'General Growth Prop', 'Energizer Holdings',
#        'Sigma-Aldrich', 'Varian Medical Systems', 'Scripps Networks',
#        'AutoNation', 'BOK Financial', 'Ventas', 'Altera',
#        'Smithfield Foods', 'Omnicare', 'MF Global', 'Waters',
#        'CF Industries Holdings', 'E-Trade Financial', 'Cephalon', 'UGI',
#        'US Airways Group', 'Clearwire', 'Cliffs Natural Resources',
#        'StanCorp Financial', 'Huntsman', 'Airgas', 'McCormick & Co',
#        'Health Net', 'HCC Insurance', 'Telephone & Data Sys', 'Popular',
#        'Southwestern Energy', 'Pride International', 'Linear Technology',
#        'Citrix Systems', 'Universal Health', 'Bucyrus International',
#        'Synovus Financial', 'Dolby Laboratories', 'Ralcorp Holdings',
#        'Commerce Bancshs', 'RRI Energy', 'Iron Mountain',
#        'Stanley Black & Decker', 'Jabil Circuit', 'PulteGroup',
#        'Eastman Kodak', 'Plum Creek Timber', 'Office Depot',
#        'MFA Financial', 'Dentsply Intl', 'Avalonbay Communities',
#        'Interactive Brokers Group', 'Cullen/Frost Bankers', 'NV Energy',
#        'Kimco Realty', 'NStar', 'Nelnet', 'First Horizon National',
#        'Avis Budget Group', 'Cerner', 'Teradata', 'World Fuel Services',
#        'Alexion Pharmaceuticals', 'Nvidia', 'Phoenix Cos', 'Lear',
#        'Aecom Technology', 'Wynn Resorts', 'Petsmart', 'Roper Industries',
#        'Atmos Energy', 'Urban Outfitters', 'Associated Banc-Corp',
#        "BJ's Wholesale Club", 'Edwards Lifesciences', 'Fastenal',
#        'Symetra Financial', 'Old Republic Intl', 'Markel',
#        'Penske Automotive Gp', 'American Equity Invest',
#        'Church & Dwight', 'City National', 'Great A&P Tea',
#        'East West Bancorp', 'Helmerich & Payne', 'Watson Pharma',
#        'VeriSign', 'Astoria Financial', 'OGE Energy', 'American Natl Ins',
#        'Pioneer Natural Res', 'Ambac Financial Group', 'Sealed Air',
#        'Health Care REIT', 'First BanCorp', 'Mercury General',
#        'Salesforce.com', 'ITT Educational Services',
#        'First Citizens Bcshs', 'Vulcan Materials'], dtype=object), 2011: array(['JPMorgan Chase', 'General Electric', 'ExxonMobil',
#        'Berkshire Hathaway', 'Citigroup', 'Wells Fargo', 'AT&T',
#        'Chevron', 'Wal-Mart Stores', 'ConocoPhillips',
#        'American Intl Group', 'IBM', 'Procter & Gamble', 'Pfizer',
#        'Goldman Sachs Group', 'Hewlett-Packard', 'Apple', 'Microsoft',
#        'Ford Motor', 'Johnson & Johnson', 'General Motors',
#        'Verizon Communications', 'Morgan Stanley', 'MetLife', 'PepsiCo',
#        'Cisco Systems', 'Coca-Cola', 'Intel', 'Comcast', 'Kraft Foods',
#        'UnitedHealth Group', 'Oracle', 'Walt Disney',
#        'United Technologies', 'American Express', 'Prudential Financial',
#        'Boeing', 'CVS Caremark', 'Google', 'Abbott Laboratories',
#        'US Bancorp', 'Caterpillar', 'Dow Chemical', 'Home Depot',
#        'News Corp', 'Marathon Oil', 'PNC Financial Services',
#        'Philip Morris International', 'United Parcel Service', 'Target',
#        'Occidental Petroleum', 'Time Warner', 'Travelers Cos',
#        'WellPoint', 'Merck & Co', 'EI du Pont de Nemours',
#        'Bank of New York Mellon', "McDonald's", 'Dell',
#        'Capital One Financial', 'Aflac', '3M', 'Lockheed Martin',
#        'Honeywell International', 'Archer Daniels', "Lowe's Cos",
#        'Deere & Co', 'Amgen', 'Walgreen', 'Eli Lilly & Co',
#        'Altria Group', 'Union Pacific', 'Exelon', 'Freeport Copper',
#        'General Dynamics', 'Southern Co', 'Hess', 'Bristol-Myers Squibb',
#        'Apache', 'Costco Wholesale', 'Medtronic', 'Qualcomm',
#        'Dominion Resources', 'EMC', 'Hartford Finl Svcs', 'Allstate',
#        'NextEra Energy', 'Northrop Grumman', 'Emerson Electric',
#        'McKesson', 'Johnson Controls', 'FedEx', 'BlackRock',
#        'Time Warner Cable', 'Duke Energy', 'Devon Energy', 'State Street',
#        'Amazon.com', 'Aetna', 'Chubb', 'Loews', 'Directv', 'Visa',
#        'Medco Health', 'Raytheon', 'Halliburton', 'American Electric',
#        'Kimberly-Clark', 'Kroger', 'BB&T', 'NIKE', 'Danaher', 'PG&E',
#        'Anadarko Petroleum', 'Cigna', 'Ameriprise Financial',
#        'HCA Holdings', 'Bank of America', 'National Oilwell Varco',
#        'Chesapeake Energy', 'CSX', 'Cardinal Health', 'Best Buy',
#        'Viacom', 'Newmont Mining', 'Texas Instruments', 'Ebay',
#        'General Mills', 'Illinois Tool Works', 'Pub Svc Enterprise',
#        'Corning', 'Norfolk Southern', 'Automatic Data',
#        'Edison International', 'Baxter International',
#        'Consolidated Edison', 'Baker Hughes', 'Colgate-Palmolive',
#        'Entergy', 'Express Scripts', 'Monsanto', 'FirstEnergy',
#        'Lincoln National', 'Xerox', 'Thermo Fisher', 'Delta Air Lines',
#        'Waste Management', 'Valero Energy', 'CBS', 'Progressive',
#        'Mosaic', 'Praxair', 'Principal Financial', 'Humana',
#        'Progress Energy', 'Eaton', 'Sysco', 'International Paper',
#        'Fifth Third Bancorp', "Kohl's", 'Gilead Sciences', 'Staples',
#        'Discover Financial Services', "Macy's", 'Kellogg', 'PPL', 'Aon',
#        'Omnicom Group', 'Murphy Oil', 'Reynolds American', 'Unum Group',
#        'Sempra Energy', 'Xcel Energy', 'AmerisourceBergen',
#        'Applied Materials', 'TJX Cos', 'Marsh & McLennan', 'Cummins',
#        'Air Prods & Chems', 'PPG Industries', 'Las Vegas Sands', 'Yahoo',
#        'Alcoa', 'Franklin Resources', 'Spectra Energy',
#        'Micron Technology', 'Stryker', 'Yum Brands', 'CenturyTel',
#        'Sprint Nextel', 'HJ Heinz', 'L-3 Communications', 'Safeway',
#        'Charles Schwab', 'Annaly Capital Mgmt', 'SLM', 'Parker-Hannifin',
#        'Becton, Dickinson', 'Computer Sciences',
#        'Liberty Media-Interactive', 'Northern Trust', 'Weyerhaeuser',
#        'Tyson Foods', 'Starbucks', 'Paccar', 'MasterCard', 'ITT',
#        'SunTrust Banks', 'Liberty Global', 'Simon Property Group',
#        'CME Group', 'DISH Network', 'DTE Energy', 'CIT Group', 'Gap',
#        'Peabody Energy', 'M&T Bank', 'KeyCorp', 'ConAgra Foods',
#        'Republic Services', 'United Continental Hldgs', 'Whirlpool',
#        'El Paso', 'Broadcom', 'Sara Lee', 'Southwest Airlines', 'AES',
#        'Precision Castparts', 'JC Penney', 'Sears Holdings',
#        'Kinder Morgan', 'Symantec', 'Fannie Mae',
#        'Marriott International', 'Freddie Mac', 'Williams Cos',
#        'TRW Automotive Hldgs', 'Regions Financial', 'Avon Products',
#        'Dollar General', 'CenterPoint Energy', 'St Jude Medical',
#        'Vornado Realty', 'Estée Lauder Cos', 'Western Digital', 'Celgene',
#        'Dover', 'Agilent Technologies', 'Fluor', 'Nucor', 'Biogen Idec',
#        'EOG Resources', 'Motorola Solutions', 'NRG Energy',
#        'Limited Brands', 'Genworth Financial',
#        'Reinsurance Group of America', 'CA', 'Goodrich',
#        'Quest Diagnostics', 'Fortune Brands', 'SanDisk', 'Western Union',
#        'Bed Bath & Beyond', 'Nordstrom', 'AutoZone', 'Avnet',
#        'Cameron International', 'Campbell Soup', 'Noble Energy', 'Oneok',
#        'McGraw-Hill Cos', 'Juniper Networks', 'NetApp',
#        'New York Community', 'Cliffs Natural Resources',
#        'Boston Scientific', 'Cognizant Technology',
#        'Coca-Cola Enterprises', 'Genzyme', 'NYSE Euronext',
#        'Fidelity National Info', 'TD Ameritrade Holding', 'Adobe Systems',
#        'US Steel', 'Stanley Black & Decker', 'Public Storage', 'VF',
#        'Discovery Communications', 'Starwood Hotels',
#        'CH Robinson Worldwide', 'Constellation Energy',
#        'Arrow Electronics', 'Consol Energy', 'Cablevision', 'Sunoco',
#        'Genuine Parts', 'Coach', 'Polo Ralph Lauren',
#        'IntercontinentalExchange', 'Hudson City Bancorp',
#        'Leucadia National', 'Ecolab', 'Ross Stores', 'SAIC', 'Mylan',
#        'Tenet Healthcare', 'Dr Pepper Snapple Group', 'WW Grainger',
#        'Lorillard', 'Zimmer Holdings', 'Rockwell Automation', 'Mattel',
#        'Textron', 'Hershey', 'Sherwin-Williams', 'AMR',
#        'Molson Coors Brewing', 'American Tower', 'Ameren',
#        'Equity Residential', 'Pioneer Natural Res', 'Assurant',
#        'American Finl Group', 'NiSource', 'General Growth Prop', 'DaVita',
#        'Ingram Micro', 'Wisconsin Energy', 'Northeast Utilities',
#        'Comerica', 'HCP', 'Clorox', 'Whole Foods Market',
#        'Rockwell Collins', 'Community Health Sys', 'T Rowe Price',
#        'Coventry Health Care', 'CMS Energy', 'JM Smucker', 'Supervalu',
#        'Huntington Bancshs', 'Forest Labs', 'Priceline.com', 'LabCorp',
#        'Lear', 'CarMax', 'Altera', 'Hormel Foods', 'Lubrizol',
#        'Hertz Global Holdings', 'Intuit', 'US Airways Group', 'Fiserv',
#        'Calpine', 'Interpublic Group', 'Analog Devices', 'Virgin Media',
#        'Goodyear', 'Expeditors Intl', 'Ball', 'VMware', 'WR Berkley',
#        'Darden Restaurants', 'First Solar', 'Allergan', 'MGM Mirage',
#        'Southwestern Energy', 'Oshkosh', 'Harris',
#        'Host Hotels & Resorts', 'Family Dollar Stores', 'Charter Commun',
#        'Smithfield Foods', 'Celanese', 'Life Technologies', 'Torchmark',
#        'BorgWarner', "O'Reilly Automotive", 'Advanced Micro', 'Scana',
#        'Eastman Chemical', 'Cincinnati Financial', 'Ashland',
#        'CF Industries Holdings', 'NII Holdings', 'FMC Technologies',
#        'Paychex', 'Dollar Tree', 'Crown Holdings', 'Newfield Exploration',
#        'Apollo Group', 'Amphenol', 'Owens Corning', 'Joy Global',
#        'CNO Financial Group', 'Transatlantic Holdings', 'KBR',
#        'Henry Schein', 'Liberty Media-Capital', 'Mead Johnson Nutrition',
#        'Cimarex Energy', 'Xilinx', 'Boston Properties',
#        'Motorola Mobility', 'Frontier Commun', 'Intuitive Surgical',
#        'Harley-Davidson', 'Brown-Forman', 'Jacobs Engineering',
#        'Nasdaq OMX Group', 'Erie Indemnity', 'Windstream',
#        'Navistar Intl', 'Jefferies Group', 'Tesoro', 'GameStop',
#        'Manpower', 'VeriSign', 'Protective Life', 'Hospira', 'Rite Aid',
#        'CR Bard', 'BMC Software', 'Lam Research', 'Wyndham Worldwide',
#        'Jabil Circuit', 'Gannett', 'ProLogis', 'Pepco Holdings',
#        'AutoNation', 'KLA-Tencor', 'Wynn Resorts', 'Linear Technology',
#        'Denbury Resources', 'CC Media Holdings', 'Advance Auto Parts',
#        'Crown Castle Intl', 'Flowserve', "Moody's", 'RR Donnelley & Sons',
#        'Tech Data', 'URS', 'Pitney Bowes', 'Citrix Systems',
#        'Scripps Networks', 'Hasbro', 'Owens-Illinois',
#        'Fidelity National Finl', 'Zions Bancorp', 'Newell Rubbermaid',
#        'Marshall & Ilsley', 'Pinnacle West', 'SL Green Realty',
#        'Varian Medical Systems', 'World Fuel Services', 'Dean Foods',
#        'Ultra Petroleum', 'E-Trade Financial', 'Waters',
#        'First Republic Bank CA', 'Tiffany & Co', 'Masco', 'Sigma-Aldrich',
#        'CB Richard Ellis', 'Nvidia', 'MF Global', 'Avery Dennison',
#        'Huntsman', 'Popular', 'BOK Financial', 'Bucyrus International',
#        'Salesforce.com', 'Raymond James Finl', 'American Water Works',
#        'Health Care REIT', 'Health Net', 'Roper Industries',
#        'Energizer Holdings', 'HealthSouth', 'MBIA', 'Teradata', 'Expedia',
#        'Whiting Petroleum', 'Chimera Investment',
#        "People's United Financial", 'Microchip Technology',
#        'McCormick & Co', 'H&R Block', 'Synovus Financial',
#        'Walter Industries', 'Fastenal', 'Ambac Financial Group',
#        'Office Depot', 'EXCO Resources', 'Interactive Brokers Group',
#        'American Capital Agency Corp.', 'MeadWestvaco',
#        'Avalonbay Communities', "BJ's Wholesale Club", 'AGCO',
#        'American Equity Invest', 'Penske Automotive', 'Old Republic Intl',
#        'Atmel', 'Nelnet', 'Integrys Energy Group', 'Symetra Financial',
#        'QEP Resources', 'Kimco Realty', 'First Horizon National',
#        'Aecom Technology', 'Petsmart', 'Edwards Lifesciences',
#        'Newcastle Investment', 'Avis Budget Group', 'Universal Health',
#        'UGI', 'Ventas', 'Commerce Bancshs', 'Associated Banc-Corp',
#        'American Natl Ins', 'City National', 'Amerigroup', 'Netflix',
#        'First Niagara Financial', 'Phoenix Cos', 'Continental Resources',
#        'Alliant Energy', 'Cerner', 'First Citizens Bcshs',
#        'East West Bancorp', 'Perrigo', 'NStar', 'Concho Resources',
#        'Synnex'], dtype=object), 2012: array(['Exxon Mobil', 'JPMorgan Chase', 'General Electric',
#        'Berkshire Hathaway', 'Wells Fargo', 'Chevron', 'Citigroup',
#        'Wal-Mart Stores', 'Apple', 'ConocoPhillips', 'IBM', 'AT&T',
#        'Pfizer', 'Procter & Gamble', 'American Intl Group', 'Microsoft',
#        'Ford Motor', 'MetLife', 'Johnson & Johnson', 'General Motors',
#        'Verizon Communications', 'Hewlett-Packard', 'Goldman Sachs Group',
#        'Merck & Co', 'Comcast', 'Bank of America', 'Intel', 'Coca-Cola',
#        'PepsiCo', 'Cisco Systems', 'Morgan Stanley', 'Google',
#        'UnitedHealth Group', 'Caterpillar', 'Oracle',
#        'Prudential Financial', 'Boeing', 'American Express',
#        'Kraft Foods', 'CVS Caremark', 'United Technologies',
#        'Walt Disney', 'US Bancorp', 'Abbott Laboratories', 'Dow Chemical',
#        'Home Depot', 'Occidental Petroleum', 'News Corp', 'Target',
#        'EI du Pont de Nemours', 'Philip Morris International',
#        'United Parcel Service', 'Dell', 'Time Warner',
#        'PNC Financial Services', 'Capital One Financial', "McDonald's",
#        'WellPoint', 'Deere & Co', 'Bank of New York Mellon', '3M',
#        'Apache', 'Honeywell International', 'Union Pacific',
#        'Lockheed Martin', 'Qualcomm', 'Eli Lilly & Co', 'Amgen', 'Aflac',
#        'Southern Co', 'Bristol-Myers Squibb', "Lowe's Cos", 'Walgreen',
#        'Exelon', 'Travelers Cos', 'Altria Group', 'EMC',
#        'Freeport-McMoRan Copper', 'Valero Energy', 'Costco Wholesale',
#        'Archer Daniels Midland', 'General Dynamics', 'Medtronic',
#        'McKesson', 'Hess', 'FedEx', 'BlackRock', 'Time Warner Cable',
#        'NextEra Energy', 'Duke Energy', 'Johnson Controls', 'Halliburton',
#        'Aetna', 'Emerson Electric', 'State Street', 'Danaher',
#        'Devon Energy', 'Marathon Petroleum', 'Visa', 'Allstate',
#        'Dominion Resources', 'Marathon Oil', 'Directv', 'Ebay',
#        'American Electric', 'BB&T', 'Chubb', 'National Oilwell Varco',
#        'Amazon.com', 'Raytheon', 'Cigna', 'Northrop Grumman',
#        'Baker Hughes', 'NIKE', 'Texas Instruments', 'Kimberly-Clark',
#        'Loews', 'HCA Holdings', 'Discover Financial Services',
#        'Illinois Tool Works', 'Viacom', 'FirstEnergy', 'Cardinal Health',
#        'Express Scripts', 'Baxter International', 'International Paper',
#        'CSX', 'Chesapeake Energy', 'PPL', 'Monsanto', 'General Mills',
#        'PG&E', 'Norfolk Southern', "Macy's", 'Colgate-Palmolive',
#        'Automatic Data', 'CBS', 'CenturyLink',
#        'Hartford Financial Services', 'Consolidated Edison',
#        'Ameriprise Financial', 'Humana', 'Las Vegas Sands', 'Xerox',
#        'Thermo Fisher Scientific', 'Corning', 'Public Service Enterprise',
#        'Praxair', 'Gilead Sciences', 'Kroger', 'Eaton', 'Entergy',
#        'Mosaic', 'Best Buy', 'EOG Resources', 'Delta Air Lines',
#        'Cummins', 'Sempra Energy', 'Fifth Third Bancorp',
#        'SunTrust Banks', 'Alcoa', 'Aon', 'Paccar', 'Sysco', 'Progressive',
#        'Waste Management', 'United Continental Holdings', 'Omnicom Group',
#        'TJX Cos', 'Reynolds American', 'AmerisourceBergen', 'Xcel Energy',
#        "Kohl's", 'Kinder Morgan', 'Charles Schwab',
#        'Principal Financial Group', 'PPG Industries', 'Marsh & McLennan',
#        'Kellogg', 'Nucor', 'Staples', 'Murphy Oil',
#        'Air Products & Chemicals', 'Franklin Resources',
#        'Applied Materials', 'DISH Network', 'Progress Energy',
#        'Spectra Energy', 'Yum Brands', 'MasterCard', 'Anadarko Petroleum',
#        'MGM Mirage', 'Stryker', 'CME Group', 'HJ Heinz', 'Starbucks',
#        'Simon Property Group', 'Newmont Mining', 'Motorola Solutions',
#        'Liberty Interactive', 'Parker-Hannifin', 'Stanley Black & Decker',
#        'SLM', 'DTE Energy', 'Becton, Dickinson', 'M&T Bank',
#        'Precision Castparts', 'L-3 Communications', 'KeyCorp',
#        'Dollar General', 'Cliffs Natural Resources', 'Sprint Nextel',
#        'Peabody Energy', 'CenterPoint Energy', 'Edison International',
#        'Lincoln National', 'ConAgra Foods', 'Republic Services', 'VF',
#        'Yahoo', 'Northern Trust', 'AES', 'Goodrich', 'Holly',
#        'Tyson Foods', 'Celgene', 'Broadcom', 'Ecolab', 'Safeway',
#        'Estée Lauder Cos', 'Fannie Mae', 'Freddie Mac', 'Gap',
#        'Williams Cos', 'Symantec', 'Fluor', 'Agilent Technologies',
#        'Biogen Idec', 'TRW Automotive Holdings', 'Sears Holdings',
#        'Bed Bath & Beyond', 'American Capital Agency Corp.',
#        'Liberty Global', 'Dover', 'Limited Brands', 'Allergan',
#        'CF Industries Holdings', 'Equity Residential', 'Ameren',
#        'Annaly Capital Management', 'Nordstrom', 'AutoZone',
#        'Boston Scientific', 'Cognizant Technology', 'SanDisk', 'Oneok',
#        'Avnet', 'Vornado Realty', 'CA', 'Regions Financial', 'Unum Group',
#        'Navistar Intl', 'Whirlpool', 'Reinsurance Group of America',
#        'Discovery Communications', 'WW Grainger', 'Western Union',
#        'St Jude Medical', 'Priceline.com', 'IntercontinentalExchange',
#        'Ross Stores', 'Coca-Cola Enterprises', 'HCP', 'Ralph Lauren',
#        'McGraw-Hill Cos', 'Genuine Parts', 'Sara Lee',
#        'Cameron International', 'TD Ameritrade Holding', 'NetApp',
#        'Western Digital', 'VMware', 'Coach', 'Campbell Soup', 'Mylan',
#        'Arrow Electronics', 'Lorillard', 'Consol Energy', 'Noble Energy',
#        'Adobe Systems', 'El Paso', 'Public Storage',
#        'Pioneer Natural Resources', 'Assurant', 'Whole Foods Market',
#        'Fidelity National Info', 'Genworth Financial', 'Mattel', 'Tesoro',
#        'Rockwell Automation', 'Hershey', 'Avon Products', 'Goodyear',
#        'Southwest Airlines', 'Quest Diagnostics', 'CH Robinson Worldwide',
#        'Huntington Bancshares', 'Weyerhaeuser', 'Ventas', 'Comerica',
#        'American Tower', 'Sherwin-Williams', 'Motorola Mobility',
#        'Starwood Hotels', 'JC Penney', 'New York Community',
#        'Dr Pepper Snapple Group', 'Zimmer Holdings', 'NYSE Euronext',
#        'AMR', 'BorgWarner', 'Interpublic Group', 'Wynn Resorts',
#        'CIT Group', 'Celanese', 'DaVita', 'CMS Energy', 'Intuit',
#        'Wisconsin Energy', 'Textron', 'Dollar Tree', 'Eastman Chemical',
#        'Forest Labs', 'General Growth Properties', 'Prologis', 'NiSource',
#        'T Rowe Price', 'Micron Technology', 'Coventry Health Care',
#        'CarMax', "O'Reilly Automotive", 'Calpine', 'Molson Coors Brewing',
#        'Jabil Circuit', 'US Steel', 'Marriott International', 'Lear',
#        'Juniper Networks', 'Hormel Foods', 'Hertz Global Holdings',
#        'Sunoco', 'Altera', 'JM Smucker', 'SL Green Realty',
#        'Liberty Media', 'Analog Devices', 'Intuitive Surgical',
# ...
#        'Markel', 'Universal Health', 'PulteGroup', 'Textron',
#        'Brown-Forman', 'Assurant', 'AES', 'Crown Holdings',
#        'Cadence Design', "Kohl's", 'Agilent Technologies', 'Fastenal',
#        'C.H. Robinson', 'Dover', 'Interpublic Group', 'NVR',
#        'Bio-Rad Laboratories', 'FleetCor Technologies', 'Comerica',
#        'Molson Coors Brewing', 'Ametek', 'NASDAQ', 'LKQ', 'VeriSign',
#        'Ulta Beauty', 'Globe Life', 'Brighthouse Financial',
#        'Campbell Soup', 'McCormick', 'HollyFrontier',
#        'Franklin Resources', 'Expeditors International', 'Xilinx',
#        'Tractor Supply', 'Invesco', 'DXC Technology',
#        'Darden Restaurants', 'Howmet Aerospace', 'Bunge',
#        'Skyworks Solutions', 'Arista Networks', 'Mohawk Industries',
#        'J.B. Hunt Transport Services', 'Zions Bancorp', 'Hess',
#        'Jones Lang LaSalle', 'Annaly Capital Management', 'Realty Income',
#        'Citrix Systems', 'Copart', 'Cerner',
#        'Fidelity National Financial', 'NetApp',
#        'Maxim Integrated Products', 'Signature Bank', 'Penske Automotive',
#        'MSCI', 'Keysight Technologies', 'Ventas', 'SYNNEX',
#        'Westinghouse Air Brake Technologies', 'Church & Dwight',
#        'Alliant Energy', 'Tenet Healthcare', 'East West Bancorp',
#        'Starwood Property Trust', "People's United Financial", 'Celanese',
#        'Jacobs', 'Cincinnati Financial', 'BorgWarner',
#        'Host Hotels & Resorts', 'Weyerhaeuser',
#        'Old Dominion Freight Line', 'Packaging Corp of America',
#        'Match Group', 'SLM', 'Tech Data', 'Aramark', 'ResMed',
#        'Henry Schein', 'Advance Auto Parts',
#        'Norwegian Cruise Line Holdings', 'Burlington Stores',
#        'Vulcan Materials', 'Alaska Air Group', 'XPO Logistics',
#        'Huntington Ingalls Industries', 'Synopsys', 'Avery Dennison',
#        'Mettler-Toledo International', 'SS&C Technologies',
#        'AGNC Investment', 'New Residential Investment',
#        'Verisk Analytics', 'Masco', 'Alexandria Real Estate Equities',
#        'Arrow Electronics', 'AutoNation', 'Caesars Entertainment',
#        'NiSource', 'Western Union', 'Atmos Energy', 'GCI Liberty',
#        'iHeartMedia', 'Navient', 'Teleflex', 'Weatherford International',
#        'Ansys', 'IDEXX Laboratories', 'Nordstrom', 'Synovus Financial',
#        'Pinnacle West', 'Tiffany & Co.', 'Hologic', 'AECOM Technology',
#        'International Flavors & Fragrances', 'Xerox', 'Reliance Steel',
#        'Incyte', 'Chipotle Mexican Grill', 'OneMain Holdings',
#        'Live Nation Entertainment', 'Steel Dynamics', 'US Foods',
#        'Booz Allen Hamilton Holding', 'Akamai Technologies', 'Manpower',
#        'Kansas City Southern', 'Square', 'Wayfair',
#        'Martin Marietta Materials', 'American National Insurance',
#        'Essex Property Trust', 'BOK Financial', 'Jabil Circuit',
#        'IAC/InterActiveCorp', 'Hertz Global Holdings', 'Autodesk',
#        'INTL FCStone', 'World Fuel Services', 'Goodyear',
#        'Qurate Retail Group', 'Zoom Video Communications',
#        'Cooper Companies', 'Gap', 'New York Community Bancorp', 'Workday',
#        'Continental Resources', 'Avis Budget Group', 'SBA Communications',
#        'Waters', 'DexCom', 'Veeva Systems', 'Teradyne',
#        'United Natural Foods,', 'PBF Energy', 'Invitation Homes',
#        'Berry Global Group', 'FMC', 'Interactive Brokers Group',
#        'Tenneco', 'Performance Food Group', "Domino's Pizza", 'Snap',
#        'First Citizens Bank', 'Zebra Technologies',
#        'Community Health Systems', 'Rite Aid', 'Xylem',
#        'American Equity Investment', 'Air Lease', 'Commerce Bank',
#        'CoStar Group', 'Seattle Genetics', 'Liberty Broadband', 'PVH',
#        'News Corp', 'JetBlue Airways', 'Western Alliance Bancorp.',
#        'Broadridge Financial', 'Splunk', 'VICI Properties',
#        'Ares Capital', 'CIT Group', 'Quanta Services', 'Mosaic',
#        'Targa Resources', 'CNO Financial Group', 'Avnet', 'Wynn Resorts',
#        'First Horizon National', 'Ralph Lauren', 'UGI', 'RingCentral',
#        'Fluor', 'Duke Realty', 'Core-Mark Holding', 'Huntsman',
#        'Newell Brands', 'Palo Alto Networks', 'Prosperity Bancshares',
#        'Fortinet', 'DocuSign', 'Okta', 'First American Financial',
#        'TCF Financial', 'Murphy Oil', 'Cullen/Frost Bankers', 'Snap-on',
#        'Spirit AeroSystems', 'IDEX', 'Teledyne Technologies',
#        'Healthpeak Properties', 'Extra Space Storage', 'Chewy',
#        'Stifel Financial', 'Frontier Communications', 'TransUnion',
#        'Westlake Chemical', 'Hasbro', 'Trimble', 'Foot Locker',
#        'Marathon Oil', 'Marketaxess Holdings', 'Medical Properties Trust',
#        'Equifax', 'Chimera Investment', 'BioMarin Pharmaceutical',
#        'Oshkosh', 'Ovintiv', 'Lamb Weston Holdings', 'Murphy USA', 'Coty',
#        'Toll Brothers', 'Amdocs', 'Hyatt Hotels', 'Twilio',
#        'Brown & Brown', 'NCR', 'Roku', 'Wintrust Financial', 'US Steel',
#        'F.N.B.', 'Moderna', 'Sears Holdings', "BJ's Wholesale Club",
#        'Mid-america Apartment Communities', 'Paycom',
#        'Take-Two Interactive Software', 'Valley Natl Bancorp',
#        'Chesapeake Energy', 'Alnylam Pharmaceuticals', 'Cabot Oil & Gas',
#        'L Brands', 'Slack Technologies', 'Diamondback Energy', 'Heico',
#        'W.P. Carey'], dtype=object), 2021: array(['JPMorgan Chase', 'Berkshire Hathaway', 'Apple', 'Bank of America',
#        'Amazon', 'Alphabet', 'Microsoft', 'Citigroup', 'Walmart',
#        'Wells Fargo', 'Verizon Communications', 'UnitedHealth Group',
#        'Comcast', 'Goldman Sachs Group', 'Morgan Stanley', 'Facebook',
#        'Johnson & Johnson', 'Intel', 'CVS Health', 'General Electric',
#        'Procter & Gamble', 'General Motors', 'Cigna', 'Pfizer', 'IBM',
#        'MetLife', 'Home Depot', 'PepsiCo', 'Oracle', 'AbbVie',
#        'Cisco Systems', 'British American Tobacco', 'Merck & Co.',
#        'US Bancorp', 'Anthem', 'Charter Communications',
#        'Dell Technologies', 'American Express', 'Truist Financial',
#        'Coca-Cola', 'Costco Wholesale', 'Capital One',
#        'PNC Financial Services', 'FedEx', 'Abbott Laboratories', 'Visa',
#        'Thermo Fisher Scientific', "Lowe's", 'BlackRock', 'Caterpillar',
#        'Lockheed Martin', 'Target', 'Deere & Company',
#        'Honeywell International', 'Charles Schwab', 'Broadcom', 'Amgen',
#        'Allstate', 'PayPal', 'Danaher', 'NextEra Energy',
#        'Salesforce.com', 'United Parcel Service', 'Progressive',
#        'Southern Company', 'Philip Morris International',
#        'Mondelez International', 'Union Pacific', '3M', 'Exelon',
#        'Eli Lilly', 'Aflac', 'HCA Healthcare', 'Duke Energy',
#        'Bank of New York Mellon', 'Travelers', "McDonald's", 'Nike',
#        'Qualcomm', 'Centene', 'Micron Technology', 'General Dynamics',
#        'Altria Group', 'Humana', 'Netflix', 'Northrop Grumman', 'Kroger',
#        'HP', 'Mastercard', 'Dow', 'Archer Daniels Midland',
#        'American Electric', 'Becton Dickinson',
#        'Automatic Data Processing', 'NVIDIA', 'Tesla', 'Dollar General',
#        'State Street', 'Fiserv', 'Sempra Energy', 'ViacomCBS', 'Adobe',
#        'Fannie Mae', 'Applied Materials', 'IntercontinentalExchange',
#        'AT&T', 'Tyson Foods', 'Marsh & McLennan', 'Ameriprise Financial',
#        'Hartford Financial Services', 'ExxonMobil', 'Freddie Mac', 'CRH',
#        'Stryker', 'CSX', 'Lennar', 'Chevron', 'General Mills',
#        'Newmont Mining', 'Discover Financial Services',
#        'Texas Instruments', 'Cardinal Health', 'Walt Disney',
#        'Principal Financial Group', 'Norfolk Southern',
#        'Synchrony Financial', 'Keurig Dr Pepper', 'L3Harris Technologies',
#        'BAE Systems', 'Waste Management', 'Xcel Energy',
#        'Raytheon Technologies', 'Emerson Electric', 'Boeing',
#        'Sherwin-Williams', 'VMware', 'Ally Financial', 'American Tower',
#        'Ford Motor', 'Starbucks', 'Carrier Global',
#        'Bristol Myers Squibb', 'Cummins', 'D.R. Horton', 'Best Buy',
#        'Prudential Financial', 'Fifth Third Bank', 'CME Group',
#        'Public Service Enterprise Group', 'Consolidated Edison',
#        'Kimberly-Clark', 'Kraft Heinz Company', 'Paccar',
#        'American International Group', 'DTE Energy', 'Colgate-Palmolive',
#        'Biogen', 'DISH Network', 'Walgreens', 'Air Products & Chemicals',
#        'eBay', 'Freeport-McMoRan', 'Citizens Bank (Rhode IsIand)',
#        'Edison International', 'Dollar Tree', 'Entergy', 'Lam Research',
#        'The Estée Lauder Companies', 'Corteva', 'KeyCorp',
#        'Constellation Brands', 'Activision Blizzard',
#        'Marathon Petroleum', 'Illinois Tool Works', 'Eversource Energy',
#        'Parker-Hannifin', 'Stanley Black & Decker', 'Gilead Sciences',
#        'Cognizant', 'PPG ', 'Northern Trust', 'McKesson', 'Prologis',
#        'Regeneron Pharmaceuticals', 'M&T Bank', 'Dominion Energy',
#        'LabCorp', 'Baxter International', 'Regions Financial',
#        'Crown Castle International', 'Phillips 66', 'PPL', 'FirstEnergy',
#        'ConocoPhillips', 'Lincoln National', 'Fox',
#        'Fidelity National Information', 'First Republic Bank',
#        'DuPont de Nemours', 'Valero Energy', 'WEC Energy Group',
#        'Advanced Micro Devices', 'Global Payments', 'CBRE Group',
#        'Discovery', 'Fidelity National Financial', 'AutoZone',
#        'Republic Services', 'TJX Cos', 'AmerisourceBergen',
#        'SVB Financial Group', 'Nucor', 'Bunge', 'Intuit', 'CarMax',
#        'International Paper', 'Omnicom Group', 'Raymond James Financial',
#        'Kellogg', 'Rocket Companies', 'PG&E', 'Albertsons',
#        'Schlumberger', 'Corning', 'Analog Devices', 'Whirlpool',
#        "O'Reilly Automotive", 'Occidental Petroleum', 'S&P Global',
#        'Conagra Brands', 'Kinder Morgan', 'Markel',
#        'Hewlett Packard Enterprise', 'Delta Air Lines',
#        'Simon Property Group', 'Uber', 'Sysco', 'Zoetis',
#        'Huntington Bank', 'Roper Technologies', 'CDW',
#        'Cincinnati Financial', 'Vertex Pharmaceuticals', 'Ball',
#        'Otis Worldwide', 'Amphenol', 'Unum', 'Altice USA',
#        'Equitable Holdings', 'United Rentals', 'United Airlines Holdings',
#        'Gallagher', 'Ameren', 'T Rowe Price', 'Hershey', 'Oneok',
#        'Boston Scientific', 'Fortive', 'Lumen Technologies',
#        'EOG Resources', "Moody's", 'CMS Energy',
#        'American Financial Group', 'KLA', 'Jefferies Financial ',
#        'Reinsurance Group of America', 'Weyerhaeuser',
#        'American Airlines Group', 'Quest Diagnostics', 'Hormel Foods',
#        'Loews', 'Baker Hughes Company', 'Southwest Airlines',
#        'Marriott International', 'IQVIA', 'Viatris', 'Cintas', 'Ecolab',
#        'L Brands', 'Motorola Solutions', 'Equinix', 'NASDAQ', 'Clorox',
#        'PulteGroup', 'WW Grainger', 'AvalonBay Communities',
#        'Digital Realty Trust', 'Celanese', 'Franklin Resources',
#        'Signature Bank', 'Boston Properties', 'Fastenal', 'NVR',
#        'Vistra Energy', 'Ross Stores', 'Halliburton',
#        'Edwards Lifesciences', 'Leidos', 'Bio-Rad Laboratories',
#        'Zoom Video Communications', 'Campbell Soup', 'Assurant', 'Jacobs',
#        'Paychex', 'J.B. Hunt Transport Services', 'Zimmer Biomet',
#        'Zions Bancorp', 'Square', 'C.H. Robinson', 'LKQ',
#        'Tenet Healthcare', 'Cooper Companies', 'Skyworks Solutions',
#        'Brown-Forman', 'McCormick', 'Carnival', 'Illumina', 'Wayfair',
#        'Evergy', 'Dover', 'Synopsys', 'Eastman Chemical',
#        'Brighthouse Financial', 'Ametek', 'Pioneer Natural Resources',
#        'Mohawk Industries', 'Cerner', 'Berry Global Group', 'Hologic',
#        'East West Bancorp', 'BorgWarner', 'PennyMac Financial Services',
#        'Schroders', 'VICI Properties', 'XPO Logistics', 'Comerica',
#        'IDEXX Laboratories', 'Westinghouse Air Brake Technologies',
#        'Royalty Pharma', 'Globe Life', 'Western Alliance Bancorp.',
#        'Masco', 'American Equity Investment', 'Liberty Broadband',
#        'Voya Financial', 'Penske Automotive', 'Cadence Design',
#        'TransDigm Group', 'Verisk Analytics', 'MSCI', 'ResMed', 'Copart',
#        'Ventas', 'Genuine Parts', 'Church & Dwight',
#        'Microchip Technology', 'Genworth Financial', 'VeriSign',
#        'Old Dominion Freight Line', 'Welltower', 'MGM Resorts', 'VF',
#        'Maxim Integrated Products', 'Xilinx', 'CenterPoint Energy',
#        'Quanta Services', 'Realty Income', 'Avery Dennison',
#        'Chipotle Mexican Grill', 'Martin Marietta Materials',
#        'Advance Auto Parts', 'SS&C Technologies', 'SYNNEX',
#        'FleetCor Technologies ', 'Teradyne',
#        'Mettler-Toledo International', "People's United Bank",
#        'Molson Coors Brewing', 'Keysight Technologies', 'Williams-Sonoma',
#        'DexCom', 'Lithia Motors', 'Las Vegas Sands', 'Jabil Circuit',
#        'Seagen', 'Jones Lang LaSalle', 'Arista Networks',
#        'Steel Dynamics', 'Community Health Systems', 'SLM', 'Textron',
#        'Vulcan Materials', 'Popular', 'Interpublic Group',
#        'DXC Technology', 'Alliant Energy', 'Kansas City Southern',
#        'NetApp', 'Annaly Capital Management', 'Fortinet',
#        'Caesars Entertainment', 'Royal Caribbean Group',
#        'New York Community Bancorp', 'International Flavors & Fragrances',
#        'Navient', 'Chewy', 'NRG Energy', 'Zebra Technologies',
#        'Booz Allen Hamilton Holding', 'First Citizens Bank (NC)',
#        'Fortune Brands Home & Security', 'Ansys',
#        'Huntington Ingalls Industries', 'Veeva Systems',
#        'BioMarin Pharmaceutical', 'Old Republic International',
#        'Atmos Energy', "Macy's", 'Coinbase', 'Equifax', 'StoneX Group',
#        'Alleghany', 'Gap', 'AutoNation', 'Essex Property Trust',
#        'Expedia Group', 'AGCO', 'OneMain Holdings', 'News Corp',
#        "BJ's Wholesale Club", 'PerkinElmer', 'Lear', 'DCC', 'ServiceNow',
#        'Broadridge Financial', 'AirBnB', 'Qorvo', 'Prosperity Bancshares',
#        'Hilton', "Kohl's", 'Snap', 'UGI', 'Packaging Corp of America',
#        'BOK Financial', 'Teladoc Health', 'Take-Two Interactive Software',
#        'Henry Schein', 'Akamai Technologies', 'Waters',
#        'Healthpeak Properties', 'Twitter', 'Flagstar Bancorp',
#        'Starwood Property Trust', 'Moderna', "Dick's Sporting Goods",
#        'Snowflake', 'Ubiquiti', 'Synovus Financial', 'Amerco', 'Twilio',
#        'Commerce Bank', 'AGNC Investment', 'Workday',
#        'Extra Space Storage', 'First American Financial',
#        'Citrix Systems', 'Pinnacle West', 'FMC', 'Pinterest', 'US Foods',
#        'Roku', 'CrowdStrike', 'United Natural Foods', 'DoorDash',
#        'Cannae Holdings', 'Etsy', 'Hess', 'Performance Food Group',
#        'Valley Natl Bancorp', 'DocuSign', 'Western Union',
#        'Interactive Brokers Group', 'Westlake Chemical', 'Rite Aid',
#        'Stifel Financial', 'Snap-on', 'Aramark', 'Newell Brands',
#        'LPL Financial Holdings', 'Roblox', 'American National Group',
#        'Air Lease ', 'Medical Properties Trust', 'Trimble',
#        'RPM International', 'Ingersoll Rand', 'Palantir Technologies',
#        "Domino's Pizza", 'Murphy USA', 'Match Group', 'AECOM Technology',
#        'Reliance Steel', 'Goodyear', 'World Fuel Services',
#        'Burlington Stores', 'West Pharmaceutical Services', 'Avantor',
#        'Darden Restaurants', 'EPAM Systems', 'CoStar Group',
#        'Palo Alto Networks', 'Okta', 'W.P. Carey', 'Peloton Interactive',
#        'Ulta Beauty', 'Invitation Homes', 'Manpower', 'Trade Desk',
#        'Carvana', 'Avnet', 'Big Lots', 'Generac Holdings Inc.',
#        'Zillow Group', 'Marvell Technology Group', 'Cullen/Frost Bankers',
#        'Core-Mark Holding', 'Kimco Realty', 'SBA Communications',
#        'Albemarle', 'Brown & Brown', 'CIT Group', 'RingCentral', 'Fluor',
#        'Thor Industries', 'Scotts Miracle-Gro', 'Toll Brothers',
#        'Teledyne Technologies', 'Tenneco', 'Teleflex', 'Amdocs',
#        'Builders FirstSource', 'PBF Energy', 'IDEX', 'Tronox',
#        'Unity Software', 'Datadog', 'Wintrust Financial',
#        'Howmet Aerospace', 'TransUnion ', 'Nexstar Media Group',
#        'Zscaler', 'TCF Financial', 'Charles River Labs',
#        'Slack Technologies', 'Penn National Gaming', 'Pinnacle Bank',
#        'HubSpot', 'Paycom'], dtype=object)}

# %%
# Identifying the unique industries
industries = us["Industry"].unique()

# %%
industries # maybe select a few industries to reduce data for analysis
# Out:
# array(['Conglomerates', 'Banking', 'Oil & Gas Operations',
#        'Diversified Financials', 'Telecommunications Services',
#        'Retailing', 'Insurance', 'Household & Personal Products',
#        'Software & Services', 'Technology Hardware & Equip',
#        'Drugs & Biotechnology', 'Media', 'Food Drink & Tobacco',
#        'Semiconductors', 'Aerospace & Defense',
#        'Health Care Equipment & Svcs', 'Capital Goods', 'Chemicals',
#        'Utilities', 'Materials', 'Hotels, Restaurants & Leisure',
#        'Transportation', 'Consumer Durables', 'Food Markets',
#        'Business Services & Supplies', 'Construction',
#        'Food, Drink & Tobacco', 'Major Banks', 'Investment Services',
#        'Telecommunications services', 'Discount Stores',
#        'Diversified Insurance', 'Computer Services',
#        'Household-Personal Care', 'Pharmaceuticals', 'Computer Hardware',
#        'Software & Programming', 'Auto & Truck Manufacturers',
#        'Medical Equipment & Supplies', 'Beverages',
#        'Communications Equipment', 'Broadcasting & Cable',
#        'Food Processing', 'Managed Health Care',
#        'Consumer Financial Services', 'Life & Health Insurance',
#        'Drug Retail', 'Heavy Equipment', 'Diversified Chemicals',
#        'Home Improvement Retail', 'Regional Banks', 'Tobacco',
#        'Air Courier', 'Property & Casualty Insurance', 'Restaurants',
#        'Biotechs', 'Railroads', 'Electric Utilities',
#        'Diversified Metals & Mining', 'Computer Storage Devices',
#        'Auto & Truck Parts', 'Internet & Catalog Retail',
#        'Oil Services & Equipment', 'Food Retail', 'Apparel-Accessories',
#        'Healthcare Services', 'Computer & Electronics Retail',
#        'Other Industrial Equipment', 'Business & Personal Services',
#        'Specialized Chemicals', 'Business Products & Supplies',
#        'Precision Healthcare Equipment', 'Airline',
#        'Environmental & Waste', 'Paper & Paper Products',
#        'Department Stores', 'Specialty Stores', 'Insurance Brokers',
#        'Advertising', 'Natural Gas Utilities', 'Casinos & Gaming',
#        'Aluminum', 'Real Estate', 'Forest Products',
#        'Apparel-Footwear Retail', 'Household Appliances',
#        'Hotels & Motels', 'Electronics', 'Construction Services',
#        'Iron & Steel', 'Diversified Utilities', 'Printing & Publishing',
#        'Thrifts & Mortgage Finance', 'Electrical Equipment',
#        'Rental & Leasing', 'Containers & Packaging',
#        'Construction Materials', 'Recreational Products',
#        'Household/Personal Care', 'Apparel/Accessories',
#        'Apparel/Footwear Retail', 'Other Tranportation',
#        'Other Transportation', 'Security Systems', 'Trucking',
#        'Furniture & Fixtures', nan, 'Consumer Electronics',
#        'Trading Companies', 'Diversified Media', 'Consumer Discretionary'],
#       dtype=object)

# %%
# Testing a sample on banking industry
banks = us.loc[(us["Industry"] == "Banking") | (us["Industry"] == "Major Banks") | (us["Industry"] == "Regional Banks")]
banks
# Out:
#                         Company        Industry        Country  Market Value  \
# 2               Bank of America         Banking  United States        176.53
# 3                JPMorgan Chase         Banking  United States        136.88
# 23                    Citigroup         Banking  United States        123.44
# 40                  Wells Fargo         Banking  United States         96.37
# 50                     Wachovia         Banking  United States         60.69
# ...                         ...             ...            ...           ...
# 1742  Western Alliance Bancorp.  Regional Banks  United States          3.60
# 1807     First Horizon National  Regional Banks  United States          2.80
# 1860       Cullen/Frost Bankers  Regional Banks  United States          4.50
# 1958         Wintrust Financial  Regional Banks  United States          2.40
# 1970                     F.N.B.  Regional Banks  United States          2.60
#
#       Profits   Assets   Sales    Rank  Year
# 2       14.98  1715.75  119.19     3.0  2008
# 3       15.37  1562.15  116.35     4.0  2008
# 23       3.62  2187.63  159.23    24.0  2008
# 40       8.06   575.44   53.59    41.0  2008
# 50       6.31   782.90   55.53    50.0  2008
# ...       ...      ...     ...     ...   ...
# 1742     0.46    29.20    1.30  1742.0  2020
# 1807     0.35    43.50    1.70  1807.0  2020
# 1860     0.38    34.10    1.30  1861.0  2020
# 1958     0.33    38.80    1.80  1958.0  2020
# 1970     0.34    35.00    1.50  1970.0  2020
#
# [410 rows x 9 columns]

# %%
# Resetting index
banks.reset_index(inplace=True, drop=True)
banks
# Out:
#                        Company        Industry        Country  Market Value  \
# 0              Bank of America         Banking  United States        176.53
# 1               JPMorgan Chase         Banking  United States        136.88
# 2                    Citigroup         Banking  United States        123.44
# 3                  Wells Fargo         Banking  United States         96.37
# 4                     Wachovia         Banking  United States         60.69
# ..                         ...             ...            ...           ...
# 405  Western Alliance Bancorp.  Regional Banks  United States          3.60
# 406     First Horizon National  Regional Banks  United States          2.80
# 407       Cullen/Frost Bankers  Regional Banks  United States          4.50
# 408         Wintrust Financial  Regional Banks  United States          2.40
# 409                     F.N.B.  Regional Banks  United States          2.60
#
#      Profits   Assets   Sales    Rank  Year
# 0      14.98  1715.75  119.19     3.0  2008
# 1      15.37  1562.15  116.35     4.0  2008
# 2       3.62  2187.63  159.23    24.0  2008
# 3       8.06   575.44   53.59    41.0  2008
# 4       6.31   782.90   55.53    50.0  2008
# ..       ...      ...     ...     ...   ...
# 405     0.46    29.20    1.30  1742.0  2020
# 406     0.35    43.50    1.70  1807.0  2020
# 407     0.38    34.10    1.30  1861.0  2020
# 408     0.33    38.80    1.80  1958.0  2020
# 409     0.34    35.00    1.50  1970.0  2020
#
# [410 rows x 9 columns]

# %%
banks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 410 entries, 0 to 409
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company       410 non-null    object
#  1   Industry      410 non-null    object
#  2   Country       410 non-null    object
#  3   Market Value  410 non-null    float64
#  4   Profits       410 non-null    float64
#  5   Assets        410 non-null    float64
#  6   Sales         410 non-null    float64
#  7   Rank          410 non-null    float64
#  8   Year          410 non-null    int64
# dtypes: float64(5), int64(1), object(3)
# memory usage: 29.0+ KB

# %%
# Finding the profit max from all years
bank_highest_profits = banks.loc[banks.groupby("Year")["Profits"].idxmax()]
bank_highest_profits
# Out:
#              Company     Industry        Country  Market Value  Profits  \
# 1     JPMorgan Chase      Banking  United States       136.880   15.370
# 45   Bank of America      Banking  United States        25.290    4.010
# 78       Wells Fargo      Banking  United States       141.690   12.280
# 109   JPMorgan Chase  Major Banks  United States       182.200   17.400
# 137   JPMorgan Chase  Major Banks  United States       170.100   19.000
# 161   JPMorgan Chase  Major Banks  United States       191.400   21.300
# 187      Wells Fargo  Major Banks  United States       261.400   21.900
# 211      Wells Fargo  Major Banks  United States       278.273   23.057
# 238   JPMorgan Chase  Major Banks  United States       234.247   23.548
# 270   JPMorgan Chase  Major Banks  United States       306.616   24.231
# 304   JPMorgan Chase  Major Banks  United States       387.668   26.496
# 339   JPMorgan Chase  Major Banks  United States       368.502   32.738
# 378   JPMorgan Chase  Major Banks  United States       291.700   30.000
#
#        Assets    Sales  Rank  Year
# 1    1562.150  116.350   4.0  2008
# 45   1817.940  113.110  38.0  2009
# 78   1243.650   98.640   7.0  2010
# 109  2117.600  115.500   1.0  2011
# 137  2265.800  110.800   2.0  2012
# 161  2359.100  108.200   3.0  2013
# 187  1543.000   88.700   8.0  2014
# 211  1701.408   90.403  10.0  2015
# 238  2423.808   99.881   5.0  2016
# 270  2512.986  102.494   4.0  2017
# 304  2609.785  118.180   3.0  2018
# 339  2737.188  132.912   2.0  2019
# 378  3139.400  142.900   3.0  2020

# %%
# Finding the profit min from all years
bank_lowest_profits = banks.loc[banks.groupby("Year")["Profits"].idxmin()]
bank_lowest_profits
# Out:
#                        Company        Industry        Country  Market Value  \
# 21           Sovereign Bancorp         Banking  United States         5.300
# 53                   Citigroup         Banking  United States         8.210
# 94          Huntington Bancshs         Banking  United States         3.440
# 116            Bank of America     Major Banks  United States       145.500
# 150          Regions Financial  Regional Banks  United States         9.100
# 185     First Horizon National  Regional Banks  United States         2.700
# 206        SVB Financial Group  Regional Banks  United States         5.900
# 235  First Citizens BancShares  Regional Banks  United States         3.089
# 262               INTL FCStone  Regional Banks  United States         0.539
# 295               INTL FCStone  Regional Banks  United States         0.681
# 312                  Citigroup     Major Banks  United States       185.788
# 365               INTL FCStone  Regional Banks  United States         0.757
# 402               INTL FCStone  Regional Banks  United States         0.770
#
#      Profits    Assets    Sales    Rank  Year
# 21   -1.3500    84.750    5.010  1088.0  2008
# 53  -27.6800  1938.470  106.660   472.0  2009
# 94   -3.0900    51.550    3.430  1474.0  2010
# 116  -2.2000  2264.900  134.200   375.0  2011
# 150  -0.2000   127.000    6.400   912.0  2012
# 185   0.0000    25.500    1.500  1983.0  2013
# 206   0.2000    26.500    1.400  1758.0  2014
# 235   0.1386    30.147    1.117  1922.0  2015
# 262   0.0539     5.217   24.469  1630.0  2016
# 295   0.0511     6.291   17.428  1698.0  2017
# 312  -5.8380  1922.104   90.469   374.0  2018
# 365   0.0790     8.711   26.256  1622.0  2019
# 402   0.0800    10.100   37.600  1588.0  2020

# %%
banks['Company'].unique()
# Out:
# array(['Bank of America', 'JPMorgan Chase', 'Citigroup', 'Wells Fargo',
#        'Wachovia', 'US Bancorp', 'Bank of New York Mellon',
#        'SunTrust Banks', 'PNC Financial Services', 'BB&T',
#        'Regions Financial', 'Fifth Third Bancorp', 'KeyCorp',
#        'Northern Trust', 'Washington Mutual', 'National City', 'M&T Bank',
#        'Comerica', 'Marshall & Ilsley', 'Zions Bancorp',
#        'Hudson City Bancorp', 'Sovereign Bancorp', 'Commerce Bancorp',
#        'New York Community', 'Huntington Bancshs', 'Synovus Financial',
#        'Popular', 'Associated Banc-Corp', 'First Horizon National',
#        'IndyMac Bancorp', "People's United Financial", 'TCF Financial',
#        'Colonial BancGroup', 'BOK Financial', 'Astoria Financial',
#        'City National', 'W Holding', 'Webster Financial', 'First BanCorp',
#        'Guaranty Financial Group', 'First Citizens Bcshs',
#        'Commerce Bancshs', 'Fulton Financial', 'Flagstar Bancorp',
#        'TFS Financial', 'Cullen/Frost Bankers', 'East West Bancorp',
#        'First Republic Bank CA', 'Huntington Bancshares',
#        'Commerce Bancshares', 'First Republic Bank',
#        'SVB Financial Group', 'Signature Bank', 'Navient',
#        'First Citizens BancShares', 'Citizens Financial Group',
#        'INTL FCStone', 'PacWest Bancorp', 'Prosperity Bancshares',
#        'Ally Financial', 'Bankunited', 'Bank of the Ozarks', 'F.N.B.',
#        'Fifth Third Bank', 'Huntington Bank', 'Sterling Bancorp',
#        'First Citizens Bank', 'Commerce Bank',
#        'Western Alliance Bancorp.', 'Wintrust Financial', 'Bank OZK'],
#       dtype=object)

# %%
# JP Morgan frequently highest over the timeframe and Comerica frequently the lowest 
# Maybe plot based on both their profit trends over the years? Line regression? top and bottom
# Based on plots, were they affected by the crises and can we determine the recovery period
# Maybe check their ranks over the years and how it changed
    # Per Forbes: 
       # We compile our Global 2000 list using data from FactSet Research systems to screen for the biggest 
       # public companies in four metric: sales, profits, assets and market value. 
       # We add up all the scores for all four metrics (equally weighted) and compile a composite score 
       # for each company based on their rankings for sales, profits, assets and market value. We sort the companies in
       # descending order by the highest composite score and then apply our Forbes Global 2000 rank. The highest composite
       # score gets the highest rank
# Maybe do the same for other categories like sales, market value and assets

# %%
#Next step
#1. Industry & Sector - loc 
#2. fix Market Value, Profits, Assets, Sales format 
#3. drop Continent
