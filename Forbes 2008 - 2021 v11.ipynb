# %%
# Dependencies
import pandas as pd
import numpy as np
import os
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')

# %%
# Reading csv files
data08 = pd.read_csv('Resources/Forbes Global 2000 - 2008.csv')
data09 = pd.read_csv('Resources/Forbes Global 2000 - 2009.csv')
data10 = pd.read_csv('Resources/Forbes Global 2000 - 2010.csv')
data11 = pd.read_csv('Resources/Forbes Global 2000 - 2011.csv')
data12 = pd.read_csv('Resources/Forbes Global 2000 - 2012.csv')
data13 = pd.read_csv('Resources/Forbes Global 2000 - 2013.csv')
data14 = pd.read_csv('Resources/Forbes Global 2000 - 2014.csv')
data15 = pd.read_csv('Resources/Forbes Global 2000 - 2015.csv')
data16 = pd.read_csv('Resources/Forbes Global 2000 - 2016.csv')
data17 = pd.read_csv('Resources/Forbes Global 2000 - 2017.csv')
data18 = pd.read_csv('Resources/Forbes Global 2000 - 2018.csv', error_bad_lines=False)
data19 = pd.read_csv('Resources/Forbes Global 2000 - 2019.csv')
data20 = pd.read_csv('Resources/Forbes Global 2000 - 2020.csv')
data21 = pd.read_csv('Resources/Forbes Global 2000 - 2021.csv')

# %%
# Removing $ from the values
data20["Sales"] = data20["Sales"].str.replace('$','')
data20["Profits"] = data20["Profits"].str.replace('$','')
data20["Assets"] = data20["Assets"].str.replace('$','')
data20["Market Value"] = data20["Market Value"].str.replace('$','')

# %%
# Convert M values to B and removing the characters
value = {'M':"*0.001",'B':'',',':''}
data20['Sales']= data20['Sales'].replace(value,regex=True).map(pd.eval)
data20['Sales'] = round(data20['Sales'],2)
data20['Profits']= data20['Profits'].replace(value,regex=True).map(pd.eval)
data20['Profits'] = round(data20['Profits'],2)
data20['Assets']= data20['Assets'].replace(value,regex=True).map(pd.eval)
data20['Assets'] = round(data20['Assets'],2)
data20['Market Value']= data20['Market Value'].replace(value,regex=True).map(pd.eval)
data20['Market Value'] = round(data20['Market Value'],2)

# %%
# checking data21 - missing industry 
data21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          2000 non-null   int64
#  1   Name          2000 non-null   object
#  2   Country       2000 non-null   object
#  3   Sales         2000 non-null   object
#  4   Profit        2000 non-null   object
#  5   Assets        1999 non-null   object
#  6   Market Value  2000 non-null   object
#  7   Year          2000 non-null   int64
# dtypes: int64(2), object(6)
# memory usage: 125.1+ KB

# %%
# getting column names for data21
data21.columns
# Out:
# Index(['Rank', 'Name', 'Country', 'Sales', 'Profit', 'Assets', 'Market Value',
#        'Year'],
#       dtype='object')

# %%
# renaming columns for data21
data21.columns = ['Rank', 'Company', 'Country', 'Sales', 'Profits', 'Assets', 'Market Value',
       'Year']

# %%
# Removing $ from the values
data21["Sales"] = data21["Sales"].str.replace('$','')
data21["Profits"] = data21["Profits"].str.replace('$','')
data21["Assets"] = data21["Assets"].str.replace('$','')
data21["Market Value"] = data21["Market Value"].str.replace('$','')

# %%
# Replaced one NaN value with 0 to allow for formatting
data21 = data21.fillna(0)

# %%
# merging data21 with data20 to get industry column
data21_corrected = pd.merge(data21, data20, on="Company", how="left")
data21_corrected.head()
# Out:
#    Rank_x                                   Company        Country  Sales_x  \
# 0       1                                      ICBC          China  190.5 B
# 1       2                            JPMorgan Chase  United States  136.2 B
# 2       3                        Berkshire Hathaway  United States  245.5 B
# 3       4                   China Construction Bank          China  173.5 B
# 4       5  Saudi Arabian Oil Company (Saudi Aramco)   Saudi Arabia  229.7 B
#
#   Profits_x   Assets_x Market Value_x  Year_x  Rank_y Country/Territory  \
# 0    45.8 B  4,914.7 B        249.5 B    2021     1.0             China
# 1    40.4 B  3,689.3 B        464.8 B    2021     3.0     United States
# 2    42.5 B    873.7 B        624.4 B    2021     4.0     United States
# 3    39.3 B  4,301.7 B        210.4 B    2021     2.0             China
# 4    49.3 B    510.3 B      1,897.2 B    2021     5.0      Saudi Arabia
#
#    Sales_y  Profits_y  Assets_y  Market Value_y      Sector  \
# 0    177.2       45.3    4322.5           242.3  Financials
# 1    142.9       30.0    3139.4           291.7  Financials
# 2    254.6       81.4     817.7           455.4  Financials
# 3    162.1       38.9    3822.0           203.8  Financials
# 4    329.8       88.2     398.3          1684.8      Energy
#
#               Industry  Year_y
# 0          Major Banks  2020.0
# 1          Major Banks  2020.0
# 2  Investment Services  2020.0
# 3          Major Banks  2020.0
# 4            Oil & Gas  2020.0

# %%
# grabbing the desired columns for new data21
data21_corrected = data21_corrected[['Rank_x', 'Company', 'Country', 'Sales_x', 'Profits_x', 'Assets_x',
       'Market Value_x', 'Year_x', 'Sector', 'Industry']]

# %%
# renaming columns for data21
data21_corrected.columns = ['Rank', 'Company', 'Country', 'Sales', 'Profits', 'Assets',
       'Market Value', 'Year', 'Sector', 'Industry']

# %%
# reassigning corrected data21 back to data21
data21 = data21_corrected

# %%
# Convert M values to B and removing the characters
value = {'M':"*0.001",'B':'',',':''}
data21['Sales']= data21['Sales'].replace(value,regex=True).map(pd.eval)
data21['Sales'] = round(data21['Sales'],2) # necessary?
data21['Profits']= data21['Profits'].replace(value,regex=True).map(pd.eval)
data21['Profits'] = round(data21['Profits'],2) # necessary?
data21['Assets']= data21['Assets'].replace(value,regex=True).map(pd.eval)
data21['Assets'] = round(data21['Assets'],2) # necessary?
data21['Market Value']= data21['Market Value'].replace(value,regex=True).map(pd.eval)
data21['Market Value'] = round(data21['Market Value'],2) # necessary?

# %%
# Changing 0 back to NaN value in case needed
data21.replace(0,np.nan, inplace=True)

# %%
# rename the columns for concat
data08.columns = ['Company', 'Industry', 'Country', 'Market Value',
       'Profits', 'Assets', 'Sales', 'Rank', 'Year']
data09.columns = ['Company', 'Industry', 'Country', 'Market Value', 'Profits', 'Assets',
       'Sales', 'Rank', 'Year']
data10.columns = ['Company', 'Industry', 'Country', 'Market Value', 'Sales', 'Profits',
       'Assets', 'Rank', 'Year']
data11.columns = ['Company', 'Industry', 'Country', 'Market Value', 'Sales', 'Profits',
       'Assets', 'Rank', 'Year']
data15.columns = ['Company', 'Market Value', 'Sales', 'Profits', 'Assets', 'Rank', 'Sector',
       'Industry', 'Continent', 'Country', 'Year']
data16.columns = ['Company', 'Market Value', 'Sales', 'Profits', 'Assets', 'Rank', 'Sector',
       'Industry', 'Continent', 'Country', 'Year']
data17.columns = ['Company', 'Market Value', 'Sales', 'Profits', 'Assets', 'Rank', 'Sector',
       'Industry', 'Continent', 'Country', 'Year']
data18.columns = ['Company', 'Market Value', 'Sales', 'Profits', 'Assets', 'Rank', 'Sector',
       'Industry', 'Continent', 'Country', 'Year']
data19.columns = ['Company', 'Market Value', 'Sales', 'Profits', 'Assets', 'Rank', 'Sector',
       'Industry', 'Continent', 'Country', 'Year']
data20.columns = ['Rank', 'Company', 'Country', 'Sales', 'Profits', 'Assets',
       'Market Value', 'Sector', 'Industry', 'Year']

# %%
#combine the dataset together 
frames = [data08, data09, data10, data11, data12, data13, data14, data15, data16, data17, data18, data19, data20, data21]

result = pd.concat(frames)

# %%
# Displaying new df
result
# Out:
#                         Company                       Industry  \
# 0                 HSBC Holdings                        Banking
# 1              General Electric                  Conglomerates
# 2               Bank of America                        Banking
# 3                JPMorgan Chase                        Banking
# 4                    ExxonMobil           Oil & Gas Operations
# ...                         ...                            ...
# 1995                      JTEKT             Auto & Truck Parts
# 1996  Insurance Australia Group  Property & Casualty Insurance
# 1997          Sumec Corporation                            NaN
# 1998                Gold Fields                            NaN
# 1999                     Paycom                            NaN
#
#              Country  Market Value  Profits   Assets   Sales    Rank  Year  \
# 0     United Kingdom        180.81    19.13  2348.98  146.50     1.0  2008
# 1      United States        330.93    22.21   795.34  172.74     2.0  2008
# 2      United States        176.53    14.98  1715.75  119.19     3.0  2008
# 3      United States        136.88    15.37  1562.15  116.35     4.0  2008
# 4      United States        465.51    40.61   242.08  358.60     5.0  2008
# ...              ...           ...      ...      ...     ...     ...   ...
# 1995           Japan          3.50    -0.03    25.00   13.10  1996.0  2021
# 1996       Australia          9.30    -0.21     7.10    5.40  1997.0  2021
# 1997           China          1.30     0.08     7.50   13.00  1997.0  2021
# 1998    South Africa          8.90     0.72     2.60    3.90  1999.0  2021
# 1999   United States         24.00     0.14      NaN    0.84  1999.0  2021
#
#                       Sector Continent
# 0                        NaN       NaN
# 1                        NaN       NaN
# 2                        NaN       NaN
# 3                        NaN       NaN
# 4                        NaN       NaN
# ...                      ...       ...
# 1995  Consumer Discretionary       NaN
# 1996              Financials       NaN
# 1997                     NaN       NaN
# 1998                     NaN       NaN
# 1999                     NaN       NaN
#
# [28002 rows x 11 columns]

# %%
# find US data
us = result.loc[result["Country"] == "United States"]

# %%
# Removing columns
us.drop(columns=['Sector','Continent'], inplace=True)

# %%
# checking info on us df
us.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7882 entries, 1 to 1999
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company       7882 non-null   object
#  1   Industry      7600 non-null   object
#  2   Country       7882 non-null   object
#  3   Market Value  7882 non-null   float64
#  4   Profits       7875 non-null   float64
#  5   Assets        7881 non-null   float64
#  6   Sales         7880 non-null   float64
#  7   Rank          7882 non-null   float64
#  8   Year          7882 non-null   int64
# dtypes: float64(5), int64(1), object(3)
# memory usage: 615.8+ KB

# %%
# dropping null values
us.dropna(inplace = True)

# %%
# checking null values were successfully removed
us.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7591 entries, 1 to 1930
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company       7591 non-null   object
#  1   Industry      7591 non-null   object
#  2   Country       7591 non-null   object
#  3   Market Value  7591 non-null   float64
#  4   Profits       7591 non-null   float64
#  5   Assets        7591 non-null   float64
#  6   Sales         7591 non-null   float64
#  7   Rank          7591 non-null   float64
#  8   Year          7591 non-null   int64
# dtypes: float64(5), int64(1), object(3)
# memory usage: 593.0+ KB

# %%
# create another df for correlation
us2 = us
us2 = us2.drop(columns = ['Rank', 'Year',])
us2
# Out:
#                  Company                Industry        Country  Market Value  \
# 1       General Electric           Conglomerates  United States        330.93
# 2        Bank of America                 Banking  United States        176.53
# 3         JPMorgan Chase                 Banking  United States        136.88
# 4             ExxonMobil    Oil & Gas Operations  United States        465.51
# 9     Berkshire Hathaway  Diversified Financials  United States        216.65
# ...                  ...                     ...            ...           ...
# 1892               Fluor   Construction Services  United States          3.20
# 1897       Toll Brothers   Construction Services  United States          7.50
# 1901             Tenneco      Auto & Truck Parts  United States          0.94
# 1912          PBF Energy    Oil & Gas Operations  United States          1.70
# 1930  Wintrust Financial          Regional Banks  United States          4.50
#
#       Profits   Assets   Sales
# 1       22.21   795.34  172.74
# 2       14.98  1715.75  119.19
# 3       15.37  1562.15  116.35
# 4       40.61   242.08  358.60
# 9       13.21   273.16  118.25
# ...       ...      ...     ...
# 1892    -0.44     7.30   15.70
# 1897     0.49    10.90    7.30
# 1901    -1.50    11.90   15.40
# 1912    -1.40    10.50   15.10
# 1930     0.29    45.10    1.90
#
# [7591 rows x 7 columns]

# %%
# correlation matrix and find the strongest positive and negative correlations for us. 
us_corr = us2.corr()
display(us_corr)
# Out:
#               Market Value   Profits    Assets     Sales
# Market Value      1.000000  0.676520  0.236755  0.562013
# Profits           0.676520  1.000000  0.335688  0.533418
# Assets            0.236755  0.335688  1.000000  0.354140
# Sales             0.562013  0.533418  0.354140  1.000000

# %%
# Marc will do the same for assets and sales

# %%
# plot profit YOY

plt.bar(us["Year"], us["Profits"], linewidth=1, color=(us['Profits'] > 0).map({True: 'g', False: 'r'}))
plt.title("Overall Profit YoY across Industries")
plt.xlabel("Year")
plt.ylabel("Profits") 
plt.xticks([x for x in us["Year"].unique()], rotation = 45)
plt.savefig("Output/overall_profit_yoy.png")
plt.show()

# %% [raw]
# Impact of housing crisis vs covid on profits
# The bar chart above show the profits across all industries yoy. 2009 had the highest profit loss followed by 2010 and 2008. 2020 was the second highest profit gain year throughout the years which proved that housing crisis had a bigger impact on all insdustries where covid had less impact in terms of profits.

# %%
# find the mean of each year
mean_val = us.groupby("Year").mean()
mean_val
# Out:
#       Market Value   Profits      Assets      Sales        Rank
# Year
# 2008     21.151711  1.141779   51.916611  17.105268  982.988255
# 2009     12.657122  0.300619   49.997905  18.271439  979.919854
# 2010     20.036717  0.840619   52.368649  16.767073  936.069418
# 2011     23.521528  1.410107   62.253138  18.760463  937.169776
# 2012     25.576864  1.648375   65.348566  20.739771  930.147228
# 2013     27.384715  1.613076   66.004972  20.701105  943.766114
# 2014     32.695636  2.067636   66.965818  20.779636  933.178182
# 2015     35.210011  1.817571   68.490333  21.221367  929.143885
# 2016     34.396000  1.556317   68.941546  20.211852  932.427046
# 2017     38.202078  1.640453   71.467413  20.396835  926.308511
# 2018     44.338933  1.963946   75.161648  22.363519  940.468240
# 2019     45.635639  2.147210   76.307032  23.137093  938.846975
# 2020     48.119062  2.301660   88.880664  25.327363  902.136719
# 2021     77.853987  2.078040  105.611233  26.763260  804.284141

# %%
mean_val2 = mean_val
mean_val_corr = mean_val2.corr()
display(mean_val_corr)
# Out:
#               Market Value   Profits    Assets     Sales      Rank
# Market Value      1.000000  0.745310  0.971401  0.912535 -0.881798
# Profits           0.745310  1.000000  0.785189  0.805788 -0.555580
# Assets            0.971401  0.785189  1.000000  0.964387 -0.889958
# Sales             0.912535  0.805788  0.964387  1.000000 -0.783729
# Rank             -0.881798 -0.555580 -0.889958 -0.783729  1.000000

# %%
# Add to below using the raw cell

# %% [raw]
# Add comments/analysis of correlation

# %%
# maybe remove?
# plot market value vs Sales
fig, ax = plt.subplots()
bar1 = plt.bar(mean_val.index, mean_val["Assets"], linewidth=1)
plt.bar_label(bar1, fmt = "%.0f", padding = 2)


plt.plot(mean_val.index,mean_val["Sales"], marker="o", color="red", linewidth=1)
for x,y in zip(mean_val.index, mean_val["Sales"]):
    label = "{:.0f}".format(y)
    plt.annotate(label, (x, y), textcoords = "offset points" , xytext = (0, 5), ha = "center")


plt.ylim(top = max(mean_val["Assets"]) + 10)
plt.xticks([x for x in mean_val.index], rotation = 45)
plt.title("Average Assets vs Sales YOY")
plt.xlabel("Year")
plt.legend(['Sales','Assets'], loc="upper left")
plt.savefig("Output/average_assets_vs_sales_yoy.png")
plt.show()

# %%
# plot market value vs Assets
fig, ax = plt.subplots()
bar2 = plt.bar(mean_val.index, mean_val["Market Value"], linewidth=1)
plt.bar_label(bar2, fmt = "%.0f")
plt.xlim(min(mean_val.index)-.5, 2021+.5)
plt.xticks([x for x in mean_val.index], rotation = 45)

plt.plot(mean_val.index,mean_val["Assets"], marker="o", color="red", linewidth=1)
for x,y in zip(mean_val.index, mean_val["Assets"]):
    label = "{:.0f}".format(y)
    plt.annotate(label, (x, y), textcoords = "offset points" , xytext = (0, 5), ha = "center")
plt.title("Average Market Value vs Assets YOY")
plt.xlabel("Year")
plt.ylim(top = max(mean_val["Assets"]) + 10)
plt.legend([ "Assets", 'Market Value'], loc="upper left")
plt.savefig("Output/average__market_value_vs_assets_yoy.png")
plt.show()

# %% [markdown]
# Correlation between Market Value and Assets
# There is a strong correlation between market value and assets (0.97). Also showing on the above combo chart that market value grow as assets go up. Market value declined on 2009 then assets declined. After the housing crises, both market value and assets are trending upward.

# %%
# do comparison of 2008 to 2009 and 2020 to 2021

# %%
# look for 2008 data
us08 = us.loc[us["Year"] == 2008]
us08
# Out:
#                   Company                Industry        Country  \
# 1        General Electric           Conglomerates  United States
# 2         Bank of America                 Banking  United States
# 3          JPMorgan Chase                 Banking  United States
# 4              ExxonMobil    Oil & Gas Operations  United States
# 9      Berkshire Hathaway  Diversified Financials  United States
# ...                   ...                     ...            ...
# 1985         RH Donnelley                   Media  United States
# 1988     Fulton Financial                 Banking  United States
# 1990                  URS            Construction  United States
# 1992  Wesco International           Capital Goods  United States
# 1993     Flagstar Bancorp                 Banking  United States
#
#       Market Value  Profits   Assets   Sales    Rank  Year
# 1           330.93    22.21   795.34  172.74     2.0  2008
# 2           176.53    14.98  1715.75  119.19     3.0  2008
# 3           136.88    15.37  1562.15  116.35     4.0  2008
# 4           465.51    40.61   242.08  358.60     5.0  2008
# 9           216.65    13.21   273.16  118.25    10.0  2008
# ...            ...      ...      ...     ...     ...   ...
# 1985          0.51     0.05    16.09    2.68  1984.0  2008
# 1988          2.02     0.15    15.92    1.09  1989.0  2008
# 1990          3.36     0.13     6.93    5.38  1990.0  2008
# 1992          1.76     0.24     2.88    6.00  1993.0  2008
# 1993          0.43    -0.04    15.79    1.04  1994.0  2008
#
# [596 rows x 9 columns]

# %%
# group by industry and find the mean of each in 2008
groupbyind = us08.groupby(["Industry"])
mean_ind = groupbyind["Profits"].mean()
df08 = pd.DataFrame(mean_ind)

# %%
# sort by profit
df08.sort_values(by=['Profits'], ascending=False, inplace=True)
df08
# Out:
#                                 Profits
# Industry
# Conglomerates                  3.921000
# Oil & Gas Operations           2.854884
# Drugs & Biotechnology          2.446111
# Software & Services            2.252105
# Aerospace & Defense            1.810000
# Banking                        1.532500
# Food Drink & Tobacco           1.498077
# Technology Hardware & Equip    1.441250
# Household & Personal Products  1.406250
# Insurance                      1.211429
# Retailing                      1.166154
# Media                          1.044286
# Chemicals                      0.911333
# Capital Goods                  0.910588
# Health Care Equipment & Svcs   0.858571
# Semiconductors                 0.823333
# Utilities                      0.822955
# Hotels, Restaurants & Leisure  0.809000
# Transportation                 0.804286
# Diversified Financials         0.791607
# Food Markets                   0.784000
# Materials                      0.706667
# Business Services & Supplies   0.364800
# Construction                  -0.319231
# Telecommunications Services   -0.630833
# Consumer Durables             -2.320588

# %%
# find the top 5
top5 = df08.head()
top5
# Out:
#                         Profits
# Industry
# Conglomerates          3.921000
# Oil & Gas Operations   2.854884
# Drugs & Biotechnology  2.446111
# Software & Services    2.252105
# Aerospace & Defense    1.810000

# %%
# plot top 5 2008
fig, ax = plt.subplots()
bar3 = plt.bar(top5.index, top5["Profits"], linewidth=1, color = "green")
plt.bar_label(bar3, fmt = "%.1f")
plt.xticks(rotation=45)
plt.title("Top 5 Average Profits Industry in 2008")
plt.xlabel("Industry")
plt.ylabel("Profits")
plt.ylim(top = max(top5["Profits"])+1)
plt.savefig("Output/top5_average_profit_2008.png")
plt.show() 

# This chart tells us which industry still remain profitable in 2008

# %%
# find the bottom5
bottom5 = df08.tail()
bottom5
# Out:
#                                Profits
# Industry
# Materials                     0.706667
# Business Services & Supplies  0.364800
# Construction                 -0.319231
# Telecommunications Services  -0.630833
# Consumer Durables            -2.320588

# %%
# plot bottom 5 2008
fig, ax = plt.subplots()
bar4 = plt.bar(bottom5.index, bottom5["Profits"], linewidth=1, color=(bottom5["Profits"] > 0).map({True:'g' , False: 'r'}))
plt.bar_label(bar4, fmt = "%.1f")
plt.xticks(rotation=45)
plt.title("Bottom 5 Average Profits Industry in 2008")
plt.xlabel("Industry")
plt.ylabel("Profits")
plt.ylim(top = max(bottom5["Profits"])+0.5, bottom = min(bottom5["Profits"])-0.5)
plt.savefig("Output/bottom5_average_profit_2008.png")
plt.show() 

# This chart tells us which industry took the biggest loss in 2008

# %%
# look for 2020 data
us20 = us.loc[us["Year"] == 2020]
us20
# Out:
#                   Company                     Industry        Country  \
# 2          JPMorgan Chase                  Major Banks  United States
# 3      Berkshire Hathaway          Investment Services  United States
# 7         Bank of America                  Major Banks  United States
# 8                   Apple            Computer Hardware  United States
# 10                   AT&T  Telecommunications services  United States
# ...                   ...                          ...            ...
# 1974  BJ's Wholesale Club              Discount Stores  United States
# 1982    Chesapeake Energy         Oil & Gas Operations  United States
# 1989      Cabot Oil & Gas         Oil & Gas Operations  United States
# 1992             L Brands      Apparel/Footwear Retail  United States
# 1994   Diamondback Energy         Oil & Gas Operations  United States
#
#       Market Value  Profits  Assets  Sales    Rank  Year
# 2           291.70    30.00  3139.4  142.9     3.0  2020
# 3           455.40    81.40   817.7  254.6     4.0  2020
# 7           208.60    24.10  2620.0  112.1     8.0  2020
# 8          1285.50    57.20   320.4  267.7     9.0  2020
# 10          218.60    14.40   545.4  179.2    11.0  2020
# ...            ...      ...     ...    ...     ...   ...
# 1974          3.60     0.19     5.3   13.2  1975.0  2020
# 1982          0.17    -0.31    16.2    8.6  1983.0  2020
# 1989          8.60     0.47     4.5    1.7  1990.0  2020
# 1992          3.30    -0.37    10.1   12.9  1990.0  2020
# 1994          6.90     0.24    23.5    4.0  1995.0  2020
#
# [512 rows x 9 columns]

# %%
# group by industry and find the mean of each in 2020
groupbyind20 = us20.groupby(["Industry"])
mean_ind20 = groupbyind20["Profits"].mean()
df20 = pd.DataFrame(mean_ind20)

# %%
# sort by profit
df20.sort_values(by=['Profits'], ascending=False, inplace=True)
df20
# Out:
#                             Profits
# Industry
# Computer Hardware         16.500000
# Computer Services         11.081667
# Major Banks               10.509000
# Investment Services        6.229565
# Managed Health Care        4.613333
# ...                             ...
# Auto & Truck Parts         0.190000
# Trading Companies          0.060000
# Diversified Media          0.000000
# Security Systems          -0.170000
# Oil Services & Equipment  -3.450000
#
# [81 rows x 1 columns]

# %%
# find the top 5
top5_20 = df20.head()
top5_20
# Out:
#                        Profits
# Industry
# Computer Hardware    16.500000
# Computer Services    11.081667
# Major Banks          10.509000
# Investment Services   6.229565
# Managed Health Care   4.613333

# %%
# plot top 5 2020

fig, ax = plt.subplots()
bar5 = plt.bar(top5_20.index, top5_20["Profits"], linewidth=1, color = "green")
plt.bar_label(bar5, fmt = "%.1f")
plt.xticks(rotation=45)
plt.title("Top 5 Average Profits Industry in 2020")
plt.xlabel("Industry")
plt.ylabel("Profits")
plt.ylim(top = max(top5_20["Profits"])+2)
plt.savefig("Output/top5_average_profit_2020.png")
plt.show() 

# This chart tells us which industry still remain profitable in 2020

# %%
# find the bottom5 in 2020
bottom5_20 = df20.tail()
bottom5_20
# Out:
#                           Profits
# Industry
# Auto & Truck Parts           0.19
# Trading Companies            0.06
# Diversified Media            0.00
# Security Systems            -0.17
# Oil Services & Equipment    -3.45

# %%
# plot bottom 5 in 2020
fig, ax = plt.subplots()
bar6 = plt.bar(bottom5_20.index, bottom5_20["Profits"], linewidth=1, color=(bottom5_20["Profits"] > 0).map({True:'g' , False: 'r'}))
plt.bar_label(bar6, fmt = "%.1f")
plt.xticks(rotation=45)
plt.title("Bottom 5 Average Profits Industry in 2020")
plt.xlabel("Industry")
plt.ylabel("Profits")
plt.ylim(top = max(bottom5_20["Profits"])+0.5, bottom = min(bottom5_20["Profits"])-0.5)
plt.savefig("Output/bottom5_average_profit_2020.png")
plt.show() 

# This chart tells us which industry took the biggest loss in 2020

# %%
# Marc- this is the end for the part you're matching Jiamin

# %%
# Identifying unique companies
companies = us["Company"].unique()

# %%
# Grouping by years for companies
years = us.groupby("Year")["Company"].unique()

# %%
# Identifying the unique industries
industries = us["Industry"].unique()

# %%
industries # maybe select a few industries to reduce data for analysis
# Out:
# array(['Conglomerates', 'Banking', 'Oil & Gas Operations',
#        'Diversified Financials', 'Telecommunications Services',
#        'Retailing', 'Insurance', 'Household & Personal Products',
#        'Software & Services', 'Technology Hardware & Equip',
#        'Drugs & Biotechnology', 'Media', 'Food Drink & Tobacco',
#        'Semiconductors', 'Aerospace & Defense',
#        'Health Care Equipment & Svcs', 'Capital Goods', 'Chemicals',
#        'Utilities', 'Materials', 'Hotels, Restaurants & Leisure',
#        'Transportation', 'Consumer Durables', 'Food Markets',
#        'Business Services & Supplies', 'Construction',
#        'Food, Drink & Tobacco', 'Major Banks', 'Investment Services',
#        'Telecommunications services', 'Discount Stores',
#        'Diversified Insurance', 'Computer Services',
#        'Household-Personal Care', 'Pharmaceuticals', 'Computer Hardware',
#        'Software & Programming', 'Auto & Truck Manufacturers',
#        'Medical Equipment & Supplies', 'Beverages',
#        'Communications Equipment', 'Broadcasting & Cable',
#        'Food Processing', 'Managed Health Care',
#        'Consumer Financial Services', 'Life & Health Insurance',
#        'Drug Retail', 'Heavy Equipment', 'Diversified Chemicals',
#        'Home Improvement Retail', 'Regional Banks', 'Tobacco',
#        'Air Courier', 'Property & Casualty Insurance', 'Restaurants',
#        'Biotechs', 'Railroads', 'Electric Utilities',
#        'Diversified Metals & Mining', 'Computer Storage Devices',
#        'Auto & Truck Parts', 'Internet & Catalog Retail',
#        'Oil Services & Equipment', 'Food Retail', 'Apparel-Accessories',
#        'Healthcare Services', 'Computer & Electronics Retail',
#        'Other Industrial Equipment', 'Business & Personal Services',
#        'Specialized Chemicals', 'Business Products & Supplies',
#        'Precision Healthcare Equipment', 'Airline',
#        'Environmental & Waste', 'Paper & Paper Products',
#        'Department Stores', 'Specialty Stores', 'Insurance Brokers',
#        'Advertising', 'Natural Gas Utilities', 'Casinos & Gaming',
#        'Aluminum', 'Real Estate', 'Forest Products',
#        'Apparel-Footwear Retail', 'Household Appliances',
#        'Hotels & Motels', 'Electronics', 'Construction Services',
#        'Iron & Steel', 'Diversified Utilities', 'Printing & Publishing',
#        'Thrifts & Mortgage Finance', 'Electrical Equipment',
#        'Rental & Leasing', 'Containers & Packaging',
#        'Construction Materials', 'Recreational Products',
#        'Household/Personal Care', 'Apparel/Accessories',
#        'Apparel/Footwear Retail', 'Other Tranportation',
#        'Other Transportation', 'Security Systems', 'Trucking',
#        'Furniture & Fixtures', 'Consumer Electronics',
#        'Trading Companies', 'Diversified Media', 'Consumer Discretionary'],
#       dtype=object)

# %%
# Assigning bin labels for profit ranges and cutting into df
profit_bins = [-100, 0, 5, 10, 100] # need to sort out size for profit amounts
labels = ["Profit Loss/No Profit", "Less than $5 bil", "Between $5-10 bil", "Above $10 bil"]
us["Profit Range"] = pd.cut(us['Profits'], profit_bins, labels=labels)
us
# Out:
#                  Company                Industry        Country  Market Value  \
# 1       General Electric           Conglomerates  United States        330.93
# 2        Bank of America                 Banking  United States        176.53
# 3         JPMorgan Chase                 Banking  United States        136.88
# 4             ExxonMobil    Oil & Gas Operations  United States        465.51
# 9     Berkshire Hathaway  Diversified Financials  United States        216.65
# ...                  ...                     ...            ...           ...
# 1892               Fluor   Construction Services  United States          3.20
# 1897       Toll Brothers   Construction Services  United States          7.50
# 1901             Tenneco      Auto & Truck Parts  United States          0.94
# 1912          PBF Energy    Oil & Gas Operations  United States          1.70
# 1930  Wintrust Financial          Regional Banks  United States          4.50
#
#       Profits   Assets   Sales    Rank  Year           Profit Range
# 1       22.21   795.34  172.74     2.0  2008          Above $10 bil
# 2       14.98  1715.75  119.19     3.0  2008          Above $10 bil
# 3       15.37  1562.15  116.35     4.0  2008          Above $10 bil
# 4       40.61   242.08  358.60     5.0  2008          Above $10 bil
# 9       13.21   273.16  118.25    10.0  2008          Above $10 bil
# ...       ...      ...     ...     ...   ...                    ...
# 1892    -0.44     7.30   15.70  1893.0  2021  Profit Loss/No Profit
# 1897     0.49    10.90    7.30  1898.0  2021       Less than $5 bil
# 1901    -1.50    11.90   15.40  1902.0  2021  Profit Loss/No Profit
# 1912    -1.40    10.50   15.10  1913.0  2021  Profit Loss/No Profit
# 1930     0.29    45.10    1.90  1931.0  2021       Less than $5 bil
#
# [7591 rows x 10 columns]

# %%
# Xiaolin will do the same for petroleum

# %%
# Grabbing the desired rows with industries in financial sector
financials = us.loc[(us["Industry"] == "Banking") | (us["Industry"] == "Major Banks") | (us["Industry"] == "Regional Banks")
              | (us["Industry"] == "Diversified Financials") | (us["Industry"] == "Investment Services")
              | (us["Industry"] == "Consumer Financial Services") | (us["Industry"] == "Diversified Insurance") 
              | (us["Industry"] == "Insurance Brokers") | (us["Industry"] == "Life & Health Insurance")  
              | (us["Industry"] == "Property & Casualty Insurance") | (us["Industry"] == "Insurance Brokers") 
              | (us["Industry"] == "Real Estate") | (us["Industry"] == "Rental & Leasing") 
              | (us["Industry"] == "Thrifts & Mortgage Finance") | (us["Industry"] == "Rental & Leasing") 
]

financials
# Out:
#                         Company                     Industry        Country  \
# 2               Bank of America                      Banking  United States
# 3                JPMorgan Chase                      Banking  United States
# 9            Berkshire Hathaway       Diversified Financials  United States
# 22          Goldman Sachs Group       Diversified Financials  United States
# 23                    Citigroup                      Banking  United States
# ...                         ...                          ...            ...
# 1615        Extra Space Storage                  Real Estate  United States
# 1702  Interactive Brokers Group          Investment Services  United States
# 1860       Cullen/Frost Bankers               Regional Banks  United States
# 1888                  CIT Group  Consumer Financial Services  United States
# 1930         Wintrust Financial               Regional Banks  United States
#
#       Market Value  Profits   Assets   Sales    Rank  Year  \
# 2           176.53    14.98  1715.75  119.19     3.0  2008
# 3           136.88    15.37  1562.15  116.35     4.0  2008
# 9           216.65    13.21   273.16  118.25    10.0  2008
# 22           67.16    11.60  1119.80   87.97    23.0  2008
# 23          123.44     3.62  2187.63  159.23    24.0  2008
# ...            ...      ...      ...     ...     ...   ...
# 1615         19.10     0.47     9.40    1.30  1616.0  2021
# 1702          7.00     0.20    95.70    2.50  1703.0  2021
# 1860          7.30     0.33    42.40    1.50  1861.0  2021
# 1888          5.20    -0.62    58.10    3.10  1889.0  2021
# 1930          4.50     0.29    45.10    1.90  1931.0  2021
#
#                Profit Range
# 2             Above $10 bil
# 3             Above $10 bil
# 9             Above $10 bil
# 22            Above $10 bil
# 23         Less than $5 bil
# ...                     ...
# 1615       Less than $5 bil
# 1702       Less than $5 bil
# 1860       Less than $5 bil
# 1888  Profit Loss/No Profit
# 1930       Less than $5 bil
#
# [1564 rows x 10 columns]

# %%
# Resetting index
financials.reset_index(inplace=True, drop=True)
financials
# Out:
#                         Company                     Industry        Country  \
# 0               Bank of America                      Banking  United States
# 1                JPMorgan Chase                      Banking  United States
# 2            Berkshire Hathaway       Diversified Financials  United States
# 3           Goldman Sachs Group       Diversified Financials  United States
# 4                     Citigroup                      Banking  United States
# ...                         ...                          ...            ...
# 1559        Extra Space Storage                  Real Estate  United States
# 1560  Interactive Brokers Group          Investment Services  United States
# 1561       Cullen/Frost Bankers               Regional Banks  United States
# 1562                  CIT Group  Consumer Financial Services  United States
# 1563         Wintrust Financial               Regional Banks  United States
#
#       Market Value  Profits   Assets   Sales    Rank  Year  \
# 0           176.53    14.98  1715.75  119.19     3.0  2008
# 1           136.88    15.37  1562.15  116.35     4.0  2008
# 2           216.65    13.21   273.16  118.25    10.0  2008
# 3            67.16    11.60  1119.80   87.97    23.0  2008
# 4           123.44     3.62  2187.63  159.23    24.0  2008
# ...            ...      ...      ...     ...     ...   ...
# 1559         19.10     0.47     9.40    1.30  1616.0  2021
# 1560          7.00     0.20    95.70    2.50  1703.0  2021
# 1561          7.30     0.33    42.40    1.50  1861.0  2021
# 1562          5.20    -0.62    58.10    3.10  1889.0  2021
# 1563          4.50     0.29    45.10    1.90  1931.0  2021
#
#                Profit Range
# 0             Above $10 bil
# 1             Above $10 bil
# 2             Above $10 bil
# 3             Above $10 bil
# 4          Less than $5 bil
# ...                     ...
# 1559       Less than $5 bil
# 1560       Less than $5 bil
# 1561       Less than $5 bil
# 1562  Profit Loss/No Profit
# 1563       Less than $5 bil
#
# [1564 rows x 10 columns]

# %%
# checking info 
financials.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1564 entries, 0 to 1563
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company       1564 non-null   object
#  1   Industry      1564 non-null   object
#  2   Country       1564 non-null   object
#  3   Market Value  1564 non-null   float64
#  4   Profits       1564 non-null   float64
#  5   Assets        1564 non-null   float64
#  6   Sales         1564 non-null   float64
#  7   Rank          1564 non-null   float64
#  8   Year          1564 non-null   int64
#  9   Profit Range  1564 non-null   category
# dtypes: category(1), float64(5), int64(1), object(3)
# memory usage: 111.8+ KB

# %%
# Finding the profit max from all years
financials_highest_profits = financials.loc[financials.groupby("Year")["Profits"].idxmax()]
financials_highest_profits
# Out:
#                   Company                Industry        Country  \
# 1          JPMorgan Chase                 Banking  United States
# 101    Berkshire Hathaway  Diversified Financials  United States
# 186   Goldman Sachs Group  Diversified Financials  United States
# 261        JPMorgan Chase             Major Banks  United States
# 379        JPMorgan Chase             Major Banks  United States
# 489        JPMorgan Chase             Major Banks  United States
# 625            Fannie Mae     Investment Services  United States
# 714           Wells Fargo             Major Banks  United States
# 832    Berkshire Hathaway     Investment Services  United States
# 958        JPMorgan Chase             Major Banks  United States
# 1083   Berkshire Hathaway     Investment Services  United States
# 1210       JPMorgan Chase             Major Banks  United States
# 1340   Berkshire Hathaway     Investment Services  United States
# 1460   Berkshire Hathaway     Investment Services  United States
#
#       Market Value  Profits    Assets    Sales   Rank  Year      Profit Range
# 1          136.880   15.370  1562.150  116.350    4.0  2008     Above $10 bil
# 101        122.110    4.990   267.400  107.790   19.0  2009  Less than $5 bil
# 186         84.950   13.390   849.000   51.670   25.0  2010     Above $10 bil
# 261        182.200   17.400  2117.600  115.500    1.0  2011     Above $10 bil
# 379        170.100   19.000  2265.800  110.800    2.0  2012     Above $10 bil
# 489        191.400   21.300  2359.100  108.200    3.0  2013     Above $10 bil
# 625          4.600   84.000  3270.100  122.900  355.0  2014     Above $10 bil
# 714        278.273   23.057  1701.408   90.403   10.0  2015     Above $10 bil
# 832        360.145   24.083   561.068  210.821    4.0  2016     Above $10 bil
# 958        306.616   24.231  2512.986  102.494    4.0  2017     Above $10 bil
# 1083       491.888   39.742   702.651  235.165    4.0  2018     Above $10 bil
# 1210       368.502   32.738  2737.188  132.912    2.0  2019     Above $10 bil
# 1340       455.400   81.400   817.700  254.600    4.0  2020     Above $10 bil
# 1460       624.400   42.500   873.700  245.500    3.0  2021     Above $10 bil

# %%
# Finding the profit min from all years
financials_lowest_profits = financials.loc[financials.groupby("Year")["Profits"].idxmin()]
financials_lowest_profits
# Out:
#                            Company                     Industry  \
# 20                   Merrill Lynch       Diversified Financials
# 125                     Fannie Mae       Diversified Financials
# 217                     Fannie Mae       Diversified Financials
# 307                     Fannie Mae          Investment Services
# 422                     Fannie Mae          Investment Services
# 565                      CIT Group  Consumer Financial Services
# 630           Prudential Financial      Life & Health Insurance
# 787             Genworth Financial        Diversified Insurance
# 911             Genworth Financial        Diversified Insurance
# 1046                     CIT Group  Consumer Financial Services
# 1115  American International Group        Diversified Insurance
# 1315         Hertz Global Holdings             Rental & Leasing
# 1420     Annaly Capital Management                  Real Estate
# 1495  American International Group        Diversified Insurance
#
#             Country  Market Value  Profits    Assets    Sales    Rank  Year  \
# 20    United States        48.020  -7.7800  1020.050   62.680   431.0  2008
# 125   United States         0.460 -58.3000   912.400   43.120   824.0  2009
# 217   United States         1.100 -71.9700   869.140   29.070   849.0  2010
# 307   United States         0.464 -14.0000  3222.000  154.300   790.0  2011
# 422   United States         1.800 -16.9000  3211.500  137.700   795.0  2012
# 565   United States         9.000  -0.6000    44.000    4.000  1265.0  2013
# 630   United States        39.700  -0.7000   731.800   48.700   433.0  2014
# 787   United States         3.852  -1.2440   111.358    9.629  1119.0  2015
# 911   United States         1.490  -0.6150   106.431    8.833  1142.0  2016
# 1046  United States         8.799  -0.8609    64.170    4.351  1272.0  2017
# 1115  United States        47.443  -6.3310   499.143   50.275   452.0  2018
# 1315  United States         1.457  -0.2250    21.382    9.504  1584.0  2019
# 1420  United States         8.900  -5.0000    96.900    2.300  1258.0  2020
# 1495  United States        40.600  -5.9000   512.900   43.700   439.0  2021
#
#                Profit Range
# 20    Profit Loss/No Profit
# 125   Profit Loss/No Profit
# 217   Profit Loss/No Profit
# 307   Profit Loss/No Profit
# 422   Profit Loss/No Profit
# 565   Profit Loss/No Profit
# 630   Profit Loss/No Profit
# 787   Profit Loss/No Profit
# 911   Profit Loss/No Profit
# 1046  Profit Loss/No Profit
# 1115  Profit Loss/No Profit
# 1315  Profit Loss/No Profit
# 1420  Profit Loss/No Profit
# 1495  Profit Loss/No Profit

# %%
# Creating a list of years
years = [2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021]

# %%
# Using for loop to plot the profit ranges in pie and bar for all years
for year in years:
    profit_year = financials[financials['Year'] == year]
    ranges = profit_year.groupby('Profit Range')['Profit Range'].count()
    plt.pie(ranges.values,labels=ranges.index.values,autopct=lambda p: '{:.1f}%'.format(round(p)) if p > 0 else '',radius=1,textprops={'fontsize': 7})
    plt.title(f"Financial Sector Profit Ranges for {year}", pad=5)
    plt.legend(bbox_to_anchor=(-0.15, .5), fontsize=8)
    plt.show()
    ranges.plot.bar()
    plt.xticks(rotation=45, ha='center')
    plt.ylabel('Number of Companies')
    plt.xlabel('Profit Range')
    plt.show()    
    info = profit_year.aggregate({'Profits':["mean",
                                "median", "var", "std", "sem", "min", "max"]})    
    print(ranges)
    print(info)
# Out:
# Profit Range
# Profit Loss/No Profit    16
# Less than $5 bil         78
# Between $5-10 bil         2
# Above $10 bil             4
# Name: Profit Range, dtype: int64
#           Profits
# mean     1.117600
# median   0.375000
# var      9.612352
# std      3.100379
# sem      0.310038
# min     -7.780000
# max     15.370000
# Profit Range
# Profit Loss/No Profit    24
# Less than $5 bil         58
# Between $5-10 bil         0
# Above $10 bil             0
# Name: Profit Range, dtype: int64
#           Profits
# mean    -1.333293
# median   0.245000
# var     82.767882
# std      9.097686
# sem      1.004671
# min    -58.300000
# max      4.990000
# Profit Range
# Profit Loss/No Profit    20
# Less than $5 bil         54
# Between $5-10 bil         2
# Above $10 bil             3
# Name: Profit Range, dtype: int64
#           Profits
# mean    -0.307848
# median   0.270000
# var     80.499479
# std      8.972150
# sem      1.009446
# min    -71.970000
# max     13.390000
# Profit Range
# Profit Loss/No Profit    17
# Less than $5 bil         95
# Between $5-10 bil         2
# Above $10 bil             4
# Name: Profit Range, dtype: int64
#           Profits
# mean     0.986236
# median   0.425750
# var     11.298581
# std      3.361336
# sem      0.309436
# min    -14.000000
# max     17.400000
# Profit Range
# Profit Loss/No Profit    13
# Less than $5 bil         91
# Between $5-10 bil         1
# Above $10 bil             5
# Name: Profit Range, dtype: int64
#           Profits
# mean     1.320909
# median   0.500000
# var     14.071577
# std      3.751210
# sem      0.357664
# min    -16.900000
# max     19.000000
# Profit Range
# Profit Loss/No Profit     9
# Less than $5 bil         96
# Between $5-10 bil         4
# Above $10 bil             4
# Name: Profit Range, dtype: int64
#           Profits
# mean     1.641593
# median   0.600000
# var     10.891022
# std      3.300155
# sem      0.310452
# min     -0.600000
# max     21.300000
# Profit Range
# Profit Loss/No Profit     4
# Less than $5 bil         94
# Between $5-10 bil         5
# Above $10 bil             7
# Name: Profit Range, dtype: int64
#           Profits
# mean     3.126364
# median   0.600000
# var     94.048565
# std      9.697864
# sem      0.924655
# min     -0.700000
# max     84.000000
# Profit Range
# Profit Loss/No Profit      5
# Less than $5 bil         103
# Between $5-10 bil          8
# Above $10 bil              4
# Name: Profit Range, dtype: int64
#           Profits
# mean     1.966472
# median   0.657350
# var     14.407036
# std      3.795660
# sem      0.346495
# min     -1.244000
# max     23.057000
# Profit Range
# Profit Loss/No Profit      4
# Less than $5 bil         109
# Between $5-10 bil          6
# Above $10 bil              6
# Name: Profit Range, dtype: int64
#           Profits
# mean     2.044406
# median   0.614900
# var     17.499091
# std      4.183192
# sem      0.374156
# min     -0.615000
# max     24.083000
# Profit Range
# Profit Loss/No Profit      6
# Less than $5 bil         107
# Between $5-10 bil          6
# Above $10 bil              6
# Name: Profit Range, dtype: int64
#           Profits
# mean     2.045546
# median   0.682000
# var     17.857976
# std      4.225870
# sem      0.377973
# min     -0.860900
# max     24.231000
# Profit Range
# Profit Loss/No Profit      5
# Less than $5 bil         113
# Between $5-10 bil          6
# Above $10 bil              4
# Name: Profit Range, dtype: int64
#           Profits
# mean     2.110394
# median   0.780250
# var     25.499496
# std      5.049703
# sem      0.446335
# min     -6.331000
# max     39.742000
# Profit Range
# Profit Loss/No Profit      3
# Less than $5 bil         111
# Between $5-10 bil          9
# Above $10 bil              6
# Name: Profit Range, dtype: int64
#           Profits
# mean     2.439891
# median   0.858000
# var     23.860183
# std      4.884689
# sem      0.430073
# min     -0.225000
# max     32.738000
# Profit Range
# Profit Loss/No Profit     7
# Less than $5 bil         99
# Between $5-10 bil         7
# Above $10 bil             7
# Name: Profit Range, dtype: int64
#           Profits
# mean     2.998917
# median   0.920000
# var     71.637843
# std      8.463914
# sem      0.772646
# min     -5.000000
# max     81.400000
# Profit Range
# Profit Loss/No Profit     9
# Less than $5 bil         79
# Between $5-10 bil         9
# Above $10 bil             8
# Name: Profit Range, dtype: int64
#           Profits
# mean     2.872286
# median   0.860000
# var     42.516037
# std      6.520432
# sem      0.636329
# min     -5.900000
# max     42.500000

# %% [raw]
# The above pie plots show that during the 2008 Housing Crisis, there weren't any companies in the financial sector that made over $5 billion and the percentage of companies that experienced no profit or a profit loss doubled in 2009.  While in 2020, during the Covid19 Pandemic, it shows a decrease in companies with less than $5 billion in profit and an increase for companies that made more than $5 billion.  It appears that the 2008 Housing Crisis had a negative impact on the financial sector, while the Covid19 Pandemic had a positive impact.

# %%
# Creating empty lists for line plot of profit ranges
loss = []
less = []
between = []
above = []

# Using for loop to grab the data to append the lists
for year in years:
    profits = financials[financials['Year'] == year]
    range = profits.groupby('Profit Range')['Profit Range'].count()
    loss.append(range.iloc[0])
    less.append(range.iloc[1])
    between.append(range.iloc[2])
    above.append(range.iloc[3])

# %%
# Multiline plot for profit ranges 
plt.plot(years, loss, label = 'Profit Loss/No Profit', linestyle = '-')
plt.plot(years, less, label = 'Less than $5 billion', linestyle = '--')
plt.plot(years, between, label = 'Between $5-10 billion', linestyle = 'dotted')
plt.plot(years, above, label = 'Above $10 billion', linestyle = 'dashdot')
plt.xticks()
plt.ylabel('Number of Companies')
plt.xlabel('Year')
plt.title('Financial Sector Profit Ranges Over the Years')
plt.legend(bbox_to_anchor=(-0.15, .5), fontsize=8)

# %%
# Grabbing the desired rows with industries in technology sector
tech = us.loc[(us["Industry"] == 'Software & Services') | (us["Industry"] == 'Technology Hardware & Equip') 
              | (us["Industry"] == 'Computer Services') | (us["Industry"] == 'Computer Hardware') 
              | (us["Industry"] == 'Computer Storage Devices') | (us["Industry"] == 'Computer & Electronics Retail') 
              | (us["Industry"] == 'Electronics') | (us["Industry"] == 'Consumer Electronics') 
              | (us["Industry"] == 'Telecommunications Services') | (us["Industry"] == 'Semiconductors') 
              | (us["Industry"] == 'Communications Equipment')]
tech
# Out:
#                        Company                     Industry        Country  \
# 11                        AT&T  Telecommunications Services  United States
# 36                         IBM          Software & Services  United States
# 47      Verizon Communications  Telecommunications Services  United States
# 52             Hewlett-Packard  Technology Hardware & Equip  United States
# 62                   Microsoft          Software & Services  United States
# ...                        ...                          ...            ...
# 1349           Arista Networks     Communications Equipment  United States
# 1382                    NetApp     Computer Storage Devices  United States
# 1422        Zebra Technologies                  Electronics  United States
# 1840                     Avnet                  Electronics  United States
# 1858  Marvell Technology Group               Semiconductors  United States
#
#       Market Value  Profits  Assets   Sales    Rank  Year  \
# 11          210.22    11.95  275.64  118.93    12.0  2008
# 36          157.62    10.42  120.43   98.79    37.0  2008
# 47          104.27     5.65  186.96   93.47    48.0  2008
# 52          122.04     7.85   88.57  107.67    53.0  2008
# 62          253.15    16.96   67.34   57.90    63.0  2008
# ...            ...      ...     ...     ...     ...   ...
# 1349         24.20     0.63    4.70    2.30  1349.0  2021
# 1382         17.30     0.59    8.70    5.60  1382.0  2021
# 1422         27.50     0.50    5.40    4.50  1423.0  2021
# 1840          4.40    -0.08    8.30   17.90  1841.0  2021
# 1858         32.40    -0.28   10.80    3.00  1857.0  2021
#
#                Profit Range
# 11            Above $10 bil
# 36            Above $10 bil
# 47        Between $5-10 bil
# 52        Between $5-10 bil
# 62            Above $10 bil
# ...                     ...
# 1349       Less than $5 bil
# 1382       Less than $5 bil
# 1422       Less than $5 bil
# 1840  Profit Loss/No Profit
# 1858  Profit Loss/No Profit
#
# [669 rows x 10 columns]

# %%
# Resetting index
tech.reset_index(inplace=True, drop=True)
tech
# Out:
#                       Company                     Industry        Country  \
# 0                        AT&T  Telecommunications Services  United States
# 1                         IBM          Software & Services  United States
# 2      Verizon Communications  Telecommunications Services  United States
# 3             Hewlett-Packard  Technology Hardware & Equip  United States
# 4                   Microsoft          Software & Services  United States
# ..                        ...                          ...            ...
# 664           Arista Networks     Communications Equipment  United States
# 665                    NetApp     Computer Storage Devices  United States
# 666        Zebra Technologies                  Electronics  United States
# 667                     Avnet                  Electronics  United States
# 668  Marvell Technology Group               Semiconductors  United States
#
#      Market Value  Profits  Assets   Sales    Rank  Year  \
# 0          210.22    11.95  275.64  118.93    12.0  2008
# 1          157.62    10.42  120.43   98.79    37.0  2008
# 2          104.27     5.65  186.96   93.47    48.0  2008
# 3          122.04     7.85   88.57  107.67    53.0  2008
# 4          253.15    16.96   67.34   57.90    63.0  2008
# ..            ...      ...     ...     ...     ...   ...
# 664         24.20     0.63    4.70    2.30  1349.0  2021
# 665         17.30     0.59    8.70    5.60  1382.0  2021
# 666         27.50     0.50    5.40    4.50  1423.0  2021
# 667          4.40    -0.08    8.30   17.90  1841.0  2021
# 668         32.40    -0.28   10.80    3.00  1857.0  2021
#
#               Profit Range
# 0            Above $10 bil
# 1            Above $10 bil
# 2        Between $5-10 bil
# 3        Between $5-10 bil
# 4            Above $10 bil
# ..                     ...
# 664       Less than $5 bil
# 665       Less than $5 bil
# 666       Less than $5 bil
# 667  Profit Loss/No Profit
# 668  Profit Loss/No Profit
#
# [669 rows x 10 columns]

# %%
# Finding the profit max from all years 
tech_highest_profits = tech.loc[tech.groupby("Year")["Profits"].idxmax()]
tech_highest_profits
# Out:
#        Company             Industry        Country  Market Value  Profits  \
# 4    Microsoft  Software & Services  United States       253.150   16.960
# 74   Microsoft  Software & Services  United States       143.580   17.230
# 137  Microsoft  Software & Services  United States       254.520   16.260
# 198      Apple    Computer Hardware  United States       324.300   16.600
# 246      Apple    Computer Hardware  United States       546.000   33.000
# 291      Apple    Computer Hardware  United States       416.600   41.700
# 332      Apple    Computer Hardware  United States       483.100   37.000
# 377      Apple    Computer Hardware  United States       741.782   44.462
# 421      Apple    Computer Hardware  United States       585.951   53.731
# 472      Apple    Computer Hardware  United States       752.039   45.217
# 512      Apple    Computer Hardware  United States       926.946   53.318
# 554      Apple    Computer Hardware  United States       961.257   59.431
# 597      Apple    Computer Hardware  United States      1285.500   57.200
# 635      Apple    Computer Hardware  United States      2252.300   63.900
#
#       Assets    Sales  Rank  Year   Profit Range
# 4     67.340   57.900  63.0  2008  Above $10 bil
# 74    65.790   61.980  49.0  2009  Above $10 bil
# 137   82.100   58.690  49.0  2010  Above $10 bil
# 198   86.700   76.300  47.0  2011  Above $10 bil
# 246  138.700  127.800  22.0  2012  Above $10 bil
# 291  196.100  164.700  15.0  2013  Above $10 bil
# 332  225.200  173.800  15.0  2014  Above $10 bil
# 377  261.894  199.378  12.0  2015  Above $10 bil
# 421  293.284  233.273   8.0  2016  Above $10 bil
# 472  331.141  217.481   9.0  2017  Above $10 bil
# 512  367.502  247.535   8.0  2018  Above $10 bil
# 554  373.719  261.705   6.0  2019  Above $10 bil
# 597  320.400  267.700   9.0  2020  Above $10 bil
# 635  354.100  294.000   6.0  2021  Above $10 bil

# %%
# Finding the profit min from all years 
tech_lowest_profits = tech.loc[tech.groupby("Year")["Profits"].idxmin()]
tech_lowest_profits
# Out:
#                         Company                     Industry        Country  \
# 17                Sprint Nextel  Telecommunications Services  United States
# 95                     Symantec          Software & Services  United States
# 151               Sprint Nextel  Telecommunications Services  United States
# 233           Motorola Mobility     Communications Equipment  United States
# 275           Computer Sciences            Computer Services  United States
# 300             Hewlett-Packard            Computer Hardware  United States
# 370                    LinkedIn            Computer Services  United States
# 413                    LinkedIn            Computer Services  United States
# 439                       Yahoo            Computer Services  United States
# 487           Dell Technologies            Computer Hardware  United States
# 525                    Qualcomm               Semiconductors  United States
# 566           Dell Technologies            Computer Hardware  United States
# 618             Western Digital     Computer Storage Devices  United States
# 655  Hewlett Packard Enterprise            Computer Hardware  United States
#
#      Market Value  Profits   Assets    Sales    Rank  Year  \
# 17         20.220 -29.5800   64.110   40.150   578.0  2008
# 95         11.350  -6.2900   10.840    6.220  1011.0  2009
# 151        10.120  -2.4400   55.420   32.260   595.0  2010
# 233         7.500  -0.0860    6.200   11.500  1421.0  2011
# 275         4.900  -3.9000   11.100   16.000  1349.0  2012
# 300        43.100 -12.9000  106.700  118.700   438.0  2013
# 370        22.700   0.0000    3.400    1.500  1700.0  2014
# 413        31.193  -0.0157    5.427    2.219  1620.0  2015
# 439        35.487  -4.4795   44.156    4.832   925.0  2016
# 487        13.475  -3.6910  118.206   61.948   608.0  2017
# 525        81.885  -4.5560   64.126   22.605   560.0  2018
# 566        45.183  -2.3100  111.820   90.396   470.0  2019
# 618        13.800  -0.6000   25.500   16.100   918.0  2020
# 655        20.800  -0.4300   53.500   26.900   709.0  2021
#
#               Profit Range
# 17   Profit Loss/No Profit
# 95   Profit Loss/No Profit
# 151  Profit Loss/No Profit
# 233  Profit Loss/No Profit
# 275  Profit Loss/No Profit
# 300  Profit Loss/No Profit
# 370  Profit Loss/No Profit
# 413  Profit Loss/No Profit
# 439  Profit Loss/No Profit
# 487  Profit Loss/No Profit
# 525  Profit Loss/No Profit
# 566  Profit Loss/No Profit
# 618  Profit Loss/No Profit
# 655  Profit Loss/No Profit

# %%
# Using for loop to plot the profit ranges in pie and bar for all years
for year in years:
    profit_year = tech[tech['Year'] == year]
    ranges = profit_year.groupby('Profit Range')['Profit Range'].count()
    plt.pie(ranges.values,labels=ranges.index.values,autopct=lambda p: '{:.1f}%'.format(round(p)) if p > 0 else '',radius=1,textprops={'fontsize': 7})
    plt.title(f" Technology Sector Profit Ranges for {year}", pad=5)
    plt.legend(bbox_to_anchor=(-0.15, .5), fontsize=8)
    plt.show()
    ranges.plot.bar()
    plt.xticks(rotation=45, ha='center')
    plt.ylabel('Number of Companies')
    plt.xlabel('Profit Range')
    plt.show()    
    info = profit_year.aggregate({'Profits':["mean",
                                "median", "var", "std", "sem", "min", "max"]})    
    print(ranges)
    print(info)
# Out:
# Profit Range
# Profit Loss/No Profit     8
# Less than $5 bil         55
# Between $5-10 bil         4
# Above $10 bil             3
# Name: Profit Range, dtype: int64
#           Profits
# mean     1.173714
# median   0.455000
# var     23.970108
# std      4.895928
# sem      0.585175
# min    -29.580000
# max     16.960000
# Profit Range
# Profit Loss/No Profit    14
# Less than $5 bil         40
# Between $5-10 bil         6
# Above $10 bil             3
# Name: Profit Range, dtype: int64
#           Profits
# mean     1.415873
# median   0.410000
# var     14.403344
# std      3.795174
# sem      0.478147
# min     -6.290000
# max     17.230000
# Profit Range
# Profit Loss/No Profit    10
# Less than $5 bil         45
# Between $5-10 bil         5
# Above $10 bil             3
# Name: Profit Range, dtype: int64
#           Profits
# mean     1.628571
# median   0.330000
# var     12.292087
# std      3.506007
# sem      0.441715
# min     -2.440000
# max     16.260000
# Profit Range
# Profit Loss/No Profit     1
# Less than $5 bil         43
# Between $5-10 bil         3
# Above $10 bil             3
# Name: Profit Range, dtype: int64
#           Profits
# mean     2.148310
# median   0.648400
# var     13.811406
# std      3.716370
# sem      0.525574
# min     -0.086000
# max     16.600000
# Profit Range
# Profit Loss/No Profit     3
# Less than $5 bil         36
# Between $5-10 bil         3
# Above $10 bil             3
# Name: Profit Range, dtype: int64
#           Profits
# mean     2.580000
# median   0.700000
# var     33.400727
# std      5.779336
# sem      0.861533
# min     -3.900000
# max     33.000000
# Profit Range
# Profit Loss/No Profit     5
# Less than $5 bil         30
# Between $5-10 bil         2
# Above $10 bil             4
# Name: Profit Range, dtype: int64
#           Profits
# mean     2.670732
# median   0.600000
# var     57.572122
# std      7.587630
# sem      1.184989
# min    -12.900000
# max     41.700000
# Profit Range
# Profit Loss/No Profit     1
# Less than $5 bil         37
# Between $5-10 bil         4
# Above $10 bil             3
# Name: Profit Range, dtype: int64
#           Profits
# mean     2.786667
# median   0.600000
# var     38.934364
# std      6.239741
# sem      0.930166
# min      0.000000
# max     37.000000
# Profit Range
# Profit Loss/No Profit     1
# Less than $5 bil         36
# Between $5-10 bil         3
# Above $10 bil             4
# Name: Profit Range, dtype: int64
#           Profits
# mean     3.284405
# median   0.662550
# var     52.401757
# std      7.238906
# sem      1.091306
# min     -0.015700
# max     44.462000
# Profit Range
# Profit Loss/No Profit     3
# Less than $5 bil         43
# Between $5-10 bil         0
# Above $10 bil             5
# Name: Profit Range, dtype: int64
#           Profits
# mean     2.805996
# median   0.566500
# var     65.796013
# std      8.111474
# sem      1.135834
# min     -4.479500
# max     53.731000
# Profit Range
# Profit Loss/No Profit     4
# Less than $5 bil         30
# Between $5-10 bil         2
# Above $10 bil             4
# Name: Profit Range, dtype: int64
#           Profits
# mean     3.410947
# median   0.755900
# var     63.861403
# std      7.991333
# sem      1.263541
# min     -3.691000
# max     45.217000
# Profit Range
# Profit Loss/No Profit     8
# Less than $5 bil         27
# Between $5-10 bil         2
# Above $10 bil             5
# Name: Profit Range, dtype: int64
#           Profits
# mean     3.324948
# median   0.575700
# var     82.814251
# std      9.100234
# sem      1.404197
# min     -4.556000
# max     53.318000
# Profit Range
# Profit Loss/No Profit     3
# Less than $5 bil         31
# Between $5-10 bil         3
# Above $10 bil             6
# Name: Profit Range, dtype: int64
#            Profits
# mean      5.010465
# median    1.066000
# var     116.772896
# std      10.806151
# sem       1.647923
# min      -2.310000
# max      59.431000
# Profit Range
# Profit Loss/No Profit     4
# Less than $5 bil         28
# Between $5-10 bil         1
# Above $10 bil             5
# Name: Profit Range, dtype: int64
#            Profits
# mean      5.231053
# median    1.150000
# var     127.065631
# std      11.272339
# sem       1.828615
# min      -0.600000
# max      57.200000
# Profit Range
# Profit Loss/No Profit     3
# Less than $5 bil         23
# Between $5-10 bil         3
# Above $10 bil             5
# Name: Profit Range, dtype: int64
#            Profits
# mean      6.503235
# median    1.600000
# var     177.941295
# std      13.339464
# sem       2.287699
# min      -0.430000
# max      63.900000

# %%
# Creating empty lists
loss = []
less = []
between = []
above = []

# using for loop to grab data to append to empty lists
for year in years:
    profits = tech[tech['Year'] == year]
    range = profits.groupby('Profit Range')['Profit Range'].count()
    loss.append(range.iloc[0])
    less.append(range.iloc[1])
    between.append(range.iloc[2])
    above.append(range.iloc[3])

# %%
# Multiline plot for profit ranges 
plt.plot(years, loss, label = 'Profit Loss/No Profit', linestyle = '-')
plt.plot(years, less, label = 'Less than $5 billion', linestyle = '--')
plt.plot(years, between, label = 'Between $5-10 billion', linestyle = 'dotted')
plt.plot(years, above, label = 'Above $10 billion', linestyle = 'dashdot')
plt.xticks()
plt.ylabel('Number of Companies')
plt.xlabel('Year')
plt.title('Technology Sector Profit Ranges Over the Years')
plt.legend(bbox_to_anchor=(-0.15, .5), fontsize=8)

# %%
# Creating subsets for financials highest and lowest
financials_highest_profits[["Year","Profits"]]
financials_lowest_profits[["Year","Profits"]]
# Out:
#       Year  Profits
# 20    2008  -7.7800
# 125   2009 -58.3000
# 217   2010 -71.9700
# 307   2011 -14.0000
# 422   2012 -16.9000
# 565   2013  -0.6000
# 630   2014  -0.7000
# 787   2015  -1.2440
# 911   2016  -0.6150
# 1046  2017  -0.8609
# 1115  2018  -6.3310
# 1315  2019  -0.2250
# 1420  2020  -5.0000
# 1495  2021  -5.9000

# %%
# Assigning variables for x and y values
year1 = financials_highest_profits['Year']
highs = financials_highest_profits['Profits']
year2 = financials_lowest_profits['Year']
lows = financials_lowest_profits['Profits']

# %%
# Plotting multiline for the min and max of financial profits over the years
plt.plot(year1, highs, label = 'Highest Profit', linestyle = '-')
plt.plot(year2, lows, label = 'Lowest Profit', linestyle = '--')
plt.ylabel('Profits (billions)')
plt.xlabel('Year')
plt.xticks( [x for x in year1], rotation = 45)
plt.title('Financials Highest and Lowest Profits over the Years')
plt.legend(bbox_to_anchor=(-0.15, .5), fontsize=8)

# %%
# Creating subset for technology highest and lowest
tech_highest_profits[["Year","Profits"]]
tech_lowest_profits[["Year","Profits"]]
# Out:
#      Year  Profits
# 17   2008 -29.5800
# 95   2009  -6.2900
# 151  2010  -2.4400
# 233  2011  -0.0860
# 275  2012  -3.9000
# 300  2013 -12.9000
# 370  2014   0.0000
# 413  2015  -0.0157
# 439  2016  -4.4795
# 487  2017  -3.6910
# 525  2018  -4.5560
# 566  2019  -2.3100
# 618  2020  -0.6000
# 655  2021  -0.4300

# %%
# Assigning variables for x and y values
year1 = tech_highest_profits['Year']
highs = tech_highest_profits['Profits']
year2 = tech_lowest_profits['Year']
lows = tech_lowest_profits['Profits']

# %%
# Plotting multiline for the min and max of technology profits over the years
plt.plot(year1, highs, label = 'Highest Profit', linestyle = '-')
plt.plot(year2, lows, label = 'Lowest Profit', linestyle = '--')
plt.ylabel('Profits (billions)')
plt.xlabel('Year')
plt.title('Technology Highest and Lowest Profits over the Years')
plt.legend(bbox_to_anchor=(-0.15, .5), fontsize=8)

# %%
# Xiaolin - end of petroleum match here

# %%
# Petroleum Sector
# Select the data in petroleum Sector
petroleum = us.loc[(us["Industry"] == 'Oil & Gas Operations')|(us["Industry"] == 'Oil Services & Equipment')
                |(us["Industry"] == 'Natural Gas Utilities')]
petroleum
# Out:
#                         Company               Industry        Country  \
# 4                    ExxonMobil   Oil & Gas Operations  United States
# 16                      Chevron   Oil & Gas Operations  United States
# 21               ConocoPhillips   Oil & Gas Operations  United States
# 143               Valero Energy   Oil & Gas Operations  United States
# 156                Marathon Oil   Oil & Gas Operations  United States
# ...                         ...                    ...            ...
# 1147  Pioneer Natural Resources   Oil & Gas Operations  United States
# 1466               Atmos Energy  Natural Gas Utilities  United States
# 1545                        UGI  Natural Gas Utilities  United States
# 1679                       Hess   Oil & Gas Operations  United States
# 1912                 PBF Energy   Oil & Gas Operations  United States
#
#       Market Value  Profits  Assets   Sales    Rank  Year  \
# 4           465.51    40.61  242.08  358.60     5.0  2008
# 16          179.97    18.69  148.79  203.97    17.0  2008
# 21          129.15    11.89  177.76  171.50    22.0  2008
# 143          31.80     5.23   41.86   94.53   144.0  2008
# 156          37.76     3.96   42.75   57.64   157.0  2008
# ...            ...      ...     ...     ...     ...   ...
# 1147         32.10    -0.13   20.90    7.00  1148.0  2021
# 1466         13.00     0.64   16.50    2.90  1467.0  2021
# 1545          9.20     0.62   14.70    6.50  1545.0  2021
# 1679         21.30    -3.10   18.80    4.20  1678.0  2021
# 1912          1.70    -1.40   10.50   15.10  1913.0  2021
#
#                Profit Range
# 4             Above $10 bil
# 16            Above $10 bil
# 21            Above $10 bil
# 143       Between $5-10 bil
# 156        Less than $5 bil
# ...                     ...
# 1147  Profit Loss/No Profit
# 1466       Less than $5 bil
# 1545       Less than $5 bil
# 1679  Profit Loss/No Profit
# 1912  Profit Loss/No Profit
#
# [522 rows x 10 columns]

# %%
# Resetting index
petroleum.reset_index(inplace=True, drop=True)
petroleum
# Out:
#                        Company               Industry        Country  \
# 0                   ExxonMobil   Oil & Gas Operations  United States
# 1                      Chevron   Oil & Gas Operations  United States
# 2               ConocoPhillips   Oil & Gas Operations  United States
# 3                Valero Energy   Oil & Gas Operations  United States
# 4                 Marathon Oil   Oil & Gas Operations  United States
# ..                         ...                    ...            ...
# 517  Pioneer Natural Resources   Oil & Gas Operations  United States
# 518               Atmos Energy  Natural Gas Utilities  United States
# 519                        UGI  Natural Gas Utilities  United States
# 520                       Hess   Oil & Gas Operations  United States
# 521                 PBF Energy   Oil & Gas Operations  United States
#
#      Market Value  Profits  Assets   Sales    Rank  Year  \
# 0          465.51    40.61  242.08  358.60     5.0  2008
# 1          179.97    18.69  148.79  203.97    17.0  2008
# 2          129.15    11.89  177.76  171.50    22.0  2008
# 3           31.80     5.23   41.86   94.53   144.0  2008
# 4           37.76     3.96   42.75   57.64   157.0  2008
# ..            ...      ...     ...     ...     ...   ...
# 517         32.10    -0.13   20.90    7.00  1148.0  2021
# 518         13.00     0.64   16.50    2.90  1467.0  2021
# 519          9.20     0.62   14.70    6.50  1545.0  2021
# 520         21.30    -3.10   18.80    4.20  1678.0  2021
# 521          1.70    -1.40   10.50   15.10  1913.0  2021
#
#               Profit Range
# 0            Above $10 bil
# 1            Above $10 bil
# 2            Above $10 bil
# 3        Between $5-10 bil
# 4         Less than $5 bil
# ..                     ...
# 517  Profit Loss/No Profit
# 518       Less than $5 bil
# 519       Less than $5 bil
# 520  Profit Loss/No Profit
# 521  Profit Loss/No Profit
#
# [522 rows x 10 columns]

# %%
petroleum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 522 entries, 0 to 521
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company       522 non-null    object
#  1   Industry      522 non-null    object
#  2   Country       522 non-null    object
#  3   Market Value  522 non-null    float64
#  4   Profits       522 non-null    float64
#  5   Assets        522 non-null    float64
#  6   Sales         522 non-null    float64
#  7   Rank          522 non-null    float64
#  8   Year          522 non-null    int64
#  9   Profit Range  522 non-null    category
# dtypes: category(1), float64(5), int64(1), object(3)
# memory usage: 37.5+ KB

# %%
# Analyze sales data in financial sector, technology sector and petroleum sector
# (Create new dataframes for financials and tech to prevent conflict for further use.)
finance = financials
Tech = tech

# Create a column 'Sector' for each dataframe
finance["Sector"] = "Finance"
Tech["Sector"] = "Tech"
petroleum["Sector"] = "Petroleum"

#three_sector = pd.concat([finance, Tech, petroleum])
#three_sector

# %%
# Average sales of each sector for all years
average_sales_finance = finance.groupby(["Year"])["Sales"].mean()
average_sales_tech = Tech.groupby(["Year"])["Sales"].mean()
average_sales_petroleum = petroleum.groupby(["Year"])["Sales"].mean()

# Create a dataframe of the average sales in these three sector
average_sales = pd.DataFrame({"Finance Average Sales":average_sales_finance,
                              "Technology Average Sales":average_sales_tech,
                              "Petroleum Average Sales":average_sales_petroleum})
average_sales
# Out:
#       Finance Average Sales  Technology Average Sales  Petroleum Average Sales
# Year
# 2008              14.355400                 16.153857                27.463023
# 2009              12.373780                 17.883810                40.221667
# 2010              13.169241                 16.968413                30.810333
# 2011              14.490602                 17.336000                28.820195
# 2012              15.042727                 21.222222                36.230952
# 2013              15.066372                 23.575610                33.733333
# 2014              15.392727                 21.195556                32.337500
# 2015              14.548150                 22.956841                33.470773
# 2016              14.171920                 21.277784                24.925158
# 2017              14.502000                 25.113850                21.656972
# 2018              15.163398                 27.716524                25.852342
# 2019              16.270155                 29.432651                32.362529
# 2020              18.276583                 33.852632                36.050000
# 2021              18.923238                 37.697059                33.668421

# %%
# Plotting multiple lines graph
plt.plot(years, average_sales_finance, marker="s", color="Red", linewidth=1, label="Finance" )
plt.plot(years, average_sales_tech, marker="+", color="blue", linewidth=1, label="Technology" )
plt.plot(years, average_sales_petroleum, marker="^", color="orange", linewidth=1, label="Petroleum" )
plt.xticks()
plt.ylabel('Average Sales of the sector')
plt.xlabel('Year')
plt.title('Average Sales Over the Years')
plt.legend(bbox_to_anchor=(-0.15, .5), fontsize=8)

# %% [raw]
# This multiple lines plot shows that the average sales in financial sector slowly increased from 2008 to 2021. It slowly recovered from the negative impact of 2008 Housing Crisis. The line of tech shows that the technology sector was fast growing in these year, especially after 2016. It also indicates the fact of into the information age. In petroleum sector, average sales surged to a high in 2009 since investors pouring money into crude markets as a hedge against inflation. 2017 was aother volatile year for oil markets. The average sales in petroleum sector was least stable.

# %%
# Find highest sales for all years in financial sector
finance_highest_sales = finance.loc[finance.groupby("Year")["Sales"].idxmax()]
finance_highest_sales
# Out:
#                  Company             Industry        Country  Market Value  \
# 4              Citigroup              Banking  United States       123.440
# 102      Bank of America              Banking  United States        25.290
# 183      Bank of America              Banking  United States       167.630
# 307           Fannie Mae  Investment Services  United States         0.464
# 380   Berkshire Hathaway  Investment Services  United States       202.200
# 490   Berkshire Hathaway  Investment Services  United States       252.800
# 603   Berkshire Hathaway  Investment Services  United States       309.100
# 712   Berkshire Hathaway  Investment Services  United States       354.813
# 832   Berkshire Hathaway  Investment Services  United States       360.145
# 957   Berkshire Hathaway  Investment Services  United States       409.908
# 1083  Berkshire Hathaway  Investment Services  United States       491.888
# 1214  Berkshire Hathaway  Investment Services  United States       516.407
# 1340  Berkshire Hathaway  Investment Services  United States       455.400
# 1460  Berkshire Hathaway  Investment Services  United States       624.400
#
#       Profits    Assets    Sales   Rank  Year           Profit Range   Sector
# 4       3.620  2187.630  159.230   24.0  2008       Less than $5 bil  Finance
# 102     4.010  1817.940  113.110   38.0  2009       Less than $5 bil  Finance
# 183     6.280  2223.300  150.450    3.0  2010      Between $5-10 bil  Finance
# 307   -14.000  3222.000  154.300  790.0  2011  Profit Loss/No Profit  Finance
# 380    10.300   392.600  143.700    8.0  2012          Above $10 bil  Finance
# 490    14.800   427.500  162.500    9.0  2013          Above $10 bil  Finance
# 603    19.500   493.400  178.800    5.0  2014          Above $10 bil  Finance
# 712    19.872   534.618  194.673    5.0  2015          Above $10 bil  Finance
# 832    24.083   561.068  210.821    4.0  2016          Above $10 bil  Finance
# 957    24.074   620.854  222.935    3.0  2017          Above $10 bil  Finance
# 1083   39.742   702.651  235.165    4.0  2018          Above $10 bil  Finance
# 1214    4.021   707.794  247.837   26.0  2019       Less than $5 bil  Finance
# 1340   81.400   817.700  254.600    4.0  2020          Above $10 bil  Finance
# 1460   42.500   873.700  245.500    3.0  2021          Above $10 bil  Finance

# %%
# Find highest sales for all years in technology sector
Tech_highest_sales = Tech.loc[Tech.groupby("Year")["Sales"].idxmax()]
Tech_highest_sales
# Out:
#              Company                     Industry        Country  \
# 0               AT&T  Telecommunications Services  United States
# 70              AT&T  Telecommunications Services  United States
# 133             AT&T  Telecommunications Services  United States
# 197  Hewlett-Packard            Computer Hardware  United States
# 246            Apple            Computer Hardware  United States
# 291            Apple            Computer Hardware  United States
# 332            Apple            Computer Hardware  United States
# 377            Apple            Computer Hardware  United States
# 421            Apple            Computer Hardware  United States
# 472            Apple            Computer Hardware  United States
# 512            Apple            Computer Hardware  United States
# 554            Apple            Computer Hardware  United States
# 597            Apple            Computer Hardware  United States
# 635            Apple            Computer Hardware  United States
#
#      Market Value  Profits   Assets    Sales  Rank  Year       Profit Range  \
# 0         210.220   11.950  275.640  118.930  12.0  2008      Above $10 bil
# 70        140.080   12.870  265.250  124.030   7.0  2009      Above $10 bil
# 133       147.550   12.540  268.750  123.020  13.0  2010      Above $10 bil
# 197        90.300    9.100  119.900  127.200  42.0  2011  Between $5-10 bil
# 246       546.000   33.000  138.700  127.800  22.0  2012      Above $10 bil
# 291       416.600   41.700  196.100  164.700  15.0  2013      Above $10 bil
# 332       483.100   37.000  225.200  173.800  15.0  2014      Above $10 bil
# 377       741.782   44.462  261.894  199.378  12.0  2015      Above $10 bil
# 421       585.951   53.731  293.284  233.273   8.0  2016      Above $10 bil
# 472       752.039   45.217  331.141  217.481   9.0  2017      Above $10 bil
# 512       926.946   53.318  367.502  247.535   8.0  2018      Above $10 bil
# 554       961.257   59.431  373.719  261.705   6.0  2019      Above $10 bil
# 597      1285.500   57.200  320.400  267.700   9.0  2020      Above $10 bil
# 635      2252.300   63.900  354.100  294.000   6.0  2021      Above $10 bil
#
#     Sector
# 0     Tech
# 70    Tech
# 133   Tech
# 197   Tech
# 246   Tech
# 291   Tech
# 332   Tech
# 377   Tech
# 421   Tech
# 472   Tech
# 512   Tech
# 554   Tech
# 597   Tech
# 635   Tech

# %%
# Find highest sales for all years in petroleum sector
petroleum_highest_sales = petroleum.loc[petroleum.groupby("Year")["Sales"].idxmax()]
petroleum_highest_sales
# Out:
#          Company              Industry        Country  Market Value  Profits  \
# 0     ExxonMobil  Oil & Gas Operations  United States       465.510    40.61
# 43    ExxonMobil  Oil & Gas Operations  United States       335.540    45.22
# 79    ExxonMobil  Oil & Gas Operations  United States       308.770    19.28
# 109   ExxonMobil  Oil & Gas Operations  United States       407.200    30.50
# 150  Exxon Mobil  Oil & Gas Operations  United States       407.400    41.10
# 192  Exxon Mobil  Oil & Gas Operations  United States       400.400    44.90
# 237  Exxon Mobil  Oil & Gas Operations  United States       422.300    32.60
# 285  Exxon Mobil  Oil & Gas Operations  United States       357.094    32.52
# 329   ExxonMobil  Oil & Gas Operations  United States       363.270    16.15
# 367   ExxonMobil  Oil & Gas Operations  United States       343.165     7.84
# 403   ExxonMobil  Oil & Gas Operations  United States       344.126    20.35
# 441   ExxonMobil  Oil & Gas Operations  United States       343.431    20.84
# 475   ExxonMobil  Oil & Gas Operations  United States       196.600    14.30
# 504   ExxonMobil  Oil & Gas Operations  United States       239.900   -22.40
#
#       Assets    Sales   Rank  Year           Profit Range     Sector
# 0    242.080  358.600    5.0  2008          Above $10 bil  Petroleum
# 43   228.050  425.700    4.0  2009          Above $10 bil  Petroleum
# 79   233.320  275.560    4.0  2010          Above $10 bil  Petroleum
# 109  302.500  341.600    4.0  2011          Above $10 bil  Petroleum
# 150  331.100  433.500    1.0  2012          Above $10 bil  Petroleum
# 192  333.800  420.700    5.0  2013          Above $10 bil  Petroleum
# 237  346.800  394.000    6.0  2014          Above $10 bil  Petroleum
# 285  349.493  376.240    7.0  2015          Above $10 bil  Petroleum
# 329  336.758  236.810    9.0  2016          Above $10 bil  Petroleum
# 367  330.314  197.518   13.0  2017      Between $5-10 bil  Petroleum
# 403  348.826  230.055   13.0  2018          Above $10 bil  Petroleum
# 441  346.196  279.209   11.0  2019          Above $10 bil  Petroleum
# 475  362.600  256.000   13.0  2020          Above $10 bil  Petroleum
# 504  332.800  178.200  317.0  2021  Profit Loss/No Profit  Petroleum

# %% [raw]
# The max sales dataframes in financial, technology and petroleum sector shows that the companies in technology sector had max sales in these years all gained positive profit in these years. However, there were max sales companies in financials and petroleum sector had profit loss or no profit.

# %%
# Find lowest sales for all years in financial sector
finance_lowest_sales = finance.loc[finance.groupby("Year")["Sales"].idxmin()]
finance_lowest_sales
# Out:
#                             Company                Industry        Country  \
# 86         IntercontinentalExchange  Diversified Financials  United States
# 176        Northstar Realty Finance  Diversified Financials  United States
# 247                   MFA Financial  Diversified Financials  United States
# 360   American Capital Agency Corp.             Real Estate  United States
# 481                            MBIA   Diversified Insurance  United States
# 599                     Alexander's             Real Estate  United States
# 692          Two Harbors Investment             Real Estate  United States
# 793       Annaly Capital Management             Real Estate  United States
# 929           Ambac Financial Group   Diversified Insurance  United States
# 1070         Two Harbors Investment             Real Estate  United States
# 1179        Starwood Property Trust             Real Estate  United States
# 1334                VICI Properties             Real Estate  United States
# 1432                AGNC Investment     Investment Services  United States
# 1558                AGNC Investment     Investment Services  United States
#
#       Market Value  Profits  Assets  Sales    Rank  Year  \
# 86           9.140   0.2400   2.800  0.570  1865.0  2008
# 176          0.130   0.7200   3.940  0.370  1841.0  2009
# 247          2.050   0.2700   9.630  0.510  1800.0  2010
# 360          2.800   0.2881  14.500  0.253  1827.0  2011
# 481          1.900  -1.3000  26.900 -1.600  1926.0  2012
# 599          1.700   0.7000   1.500  0.200  1990.0  2013
# 692          3.800   0.6000  17.200  0.600  1543.0  2014
# 793          9.970  -0.8421  88.355 -0.115  1235.0  2015
# 929          0.761   0.4934  24.359  0.638  1492.0  2016
# 1070         3.360   0.3533  20.112  0.741  1866.0  2017
# 1179         5.635   0.3953  61.127  0.943  1530.0  2018
# 1334         8.873   0.5240  11.333  0.898  1916.0  2019
# 1432         7.100  -2.0000  85.100 -1.200  1430.0  2020
# 1558         9.300  -0.2700  81.800  0.340  1603.0  2021
#
#                Profit Range   Sector
# 86         Less than $5 bil  Finance
# 176        Less than $5 bil  Finance
# 247        Less than $5 bil  Finance
# 360        Less than $5 bil  Finance
# 481   Profit Loss/No Profit  Finance
# 599        Less than $5 bil  Finance
# 692        Less than $5 bil  Finance
# 793   Profit Loss/No Profit  Finance
# 929        Less than $5 bil  Finance
# 1070       Less than $5 bil  Finance
# 1179       Less than $5 bil  Finance
# 1334       Less than $5 bil  Finance
# 1432  Profit Loss/No Profit  Finance
# 1558  Profit Loss/No Profit  Finance

# %%
# Find lowest sales for all years in technology sector
Tech_lowest_sales = Tech.loc[Tech.groupby("Year")["Sales"].idxmin()]
Tech_lowest_sales
# Out:
#                        Company                     Industry        Country  \
# 59                 First Solar  Technology Hardware & Equip  United States
# 128       Microchip Technology               Semiconductors  United States
# 185                  Clearwire  Telecommunications Services  United States
# 238          Linear Technology               Semiconductors  United States
# 290                F5 Networks            Computer Services  United States
# 330                   LinkedIn            Computer Services  United States
# 364          Linear Technology               Semiconductors  United States
# 411          Linear Technology               Semiconductors  United States
# 470        Palo Alto Networks,     Communications Equipment  United States
# 510                F5 Networks            Computer Services  United States
# 553                     Splunk            Computer Services  United States
# 593                     Splunk            Computer Services  United States
# 626  Maxim Integrated Products               Semiconductors  United States
# 664            Arista Networks     Communications Equipment  United States
#
#      Market Value  Profits  Assets  Sales    Rank  Year  \
# 59         16.140   0.1600   1.370  0.500  1717.0  2008
# 128         3.420   0.3000   2.450  0.990  1754.0  2009
# 185         6.330  -0.3300  11.270  0.270  1657.0  2010
# 238         7.600   0.5061   1.400  1.400  1551.0  2011
# 290        10.400   0.3000   1.700  1.200  1950.0  2012
# 330        19.100   0.0000   1.400  1.000  1736.0  2013
# 364        11.900   0.4000   2.300  1.300  1563.0  2014
# 411        11.060   0.5004   1.729  1.437  1597.0  2015
# 470        13.125  -0.1931   2.317  1.150  1995.0  2016
# 510         8.878   0.3704   2.397  2.022  1979.0  2017
# 553        16.826  -0.2591   2.044  1.271  1941.0  2018
# 593        19.222  -0.2760   4.500  1.803  1869.0  2019
# 626        14.800   0.8200   3.500  2.200  1298.0  2020
# 664        24.200   0.6300   4.700  2.300  1349.0  2021
#
#               Profit Range Sector
# 59        Less than $5 bil   Tech
# 128       Less than $5 bil   Tech
# 185  Profit Loss/No Profit   Tech
# 238       Less than $5 bil   Tech
# 290       Less than $5 bil   Tech
# 330  Profit Loss/No Profit   Tech
# 364       Less than $5 bil   Tech
# 411       Less than $5 bil   Tech
# 470  Profit Loss/No Profit   Tech
# 510       Less than $5 bil   Tech
# 553  Profit Loss/No Profit   Tech
# 593  Profit Loss/No Profit   Tech
# 626       Less than $5 bil   Tech
# 664       Less than $5 bil   Tech

# %%
# Find lowest sales for all years in petroleum sector
petroleum_lowest_sales = petroleum.loc[petroleum.groupby("Year")["Sales"].idxmin()]
petroleum_lowest_sales
# Out:
#                      Company               Industry        Country  \
# 34     Quicksilver Resources   Oil & Gas Operations  United States
# 78     Continental Resources   Oil & Gas Operations  United States
# 106      Pride International   Oil & Gas Operations  United States
# 145           EXCO Resources   Oil & Gas Operations  United States
# 191                Rowan Cos   Oil & Gas Operations  United States
# 231          Cabot Oil & Gas   Oil & Gas Operations  United States
# 278          Cabot Oil & Gas   Oil & Gas Operations  United States
# 322          Range Resources   Oil & Gas Operations  United States
# 366  Columbia Pipeline Group   Oil & Gas Operations  United States
# 399            Penn Virginia   Oil & Gas Operations  United States
# 439         Chaparral Energy   Oil & Gas Operations  United States
# 472          Cabot Oil & Gas   Oil & Gas Operations  United States
# 501          Cabot Oil & Gas   Oil & Gas Operations  United States
# 518             Atmos Energy  Natural Gas Utilities  United States
#
#      Market Value  Profits  Assets  Sales    Rank  Year      Profit Range  \
# 34          5.450   0.4800   2.780  0.560  1721.0  2008  Less than $5 bil
# 78          2.690   0.3200   2.220  0.960  1929.0  2009  Less than $5 bil
# 106         4.890   0.2900   6.140  1.590  1725.0  2010  Less than $5 bil
# 145         4.400   0.6719   3.500  0.515  1817.0  2011  Less than $5 bil
# 191         4.600   0.7000   6.600  0.900  1793.0  2012  Less than $5 bil
# 231        14.100   0.1000   4.600  1.200  1869.0  2013  Less than $5 bil
# 278        14.300   0.3000   5.000  1.700  1811.0  2014  Less than $5 bil
# 322         9.234   0.6237   8.747  2.169  1578.0  2015  Less than $5 bil
# 366        10.254   0.2672  10.363  1.335  1920.0  2016  Less than $5 bil
# 399         0.732   1.0493   0.292  0.132  1771.0  2017  Less than $5 bil
# 439         0.988   0.9231   1.201  0.294  1963.0  2018  Less than $5 bil
# 472        11.063   0.5570   4.424  2.144  1708.0  2019  Less than $5 bil
# 501         8.600   0.4700   4.500  1.700  1990.0  2020  Less than $5 bil
# 518        13.000   0.6400  16.500  2.900  1467.0  2021  Less than $5 bil
#
#         Sector
# 34   Petroleum
# 78   Petroleum
# 106  Petroleum
# 145  Petroleum
# 191  Petroleum
# 231  Petroleum
# 278  Petroleum
# 322  Petroleum
# 366  Petroleum
# 399  Petroleum
# 439  Petroleum
# 472  Petroleum
# 501  Petroleum
# 518  Petroleum

# %% [raw]
# The companies with lowest sales in petroleum sector did not have profit loss or no profit in these years.
